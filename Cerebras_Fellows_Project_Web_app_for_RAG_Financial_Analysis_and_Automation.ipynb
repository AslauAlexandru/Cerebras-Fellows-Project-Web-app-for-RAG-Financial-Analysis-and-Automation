# %% [markdown]
# <a href="https://colab.research.google.com/github/AslauAlexandru/Cerebras-Fellows-Project-Web-app-for-RAG-Financial-Analysis-and-Automation/blob/main/Cerebras_Fellows_Project_Web_app_for_RAG_Financial_Analysis_and_Automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: Financial Analysis & Automation with LLMs Project and Part 2: Web app for RAG Financial Analysis & Automation with Streamlit

# %% [markdown]
# # Part 1: Financial Analysis & Automation with LLMs Project

# %% [markdown]
# # Install Libraries

# %%
! pip install yfinance langchain_pinecone openai python-dotenv langchain-community sentence_transformers
! pip install httpx
! pip install cerebras_cloud_sdk
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.50)
# Collecting langchain_pinecone
#   Downloading langchain_pinecone-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.12-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Collecting aiohttp<3.10,>=3.9.5 (from langchain_pinecone)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /usr/local/lib/python3.10/dist-packages (from langchain_pinecone) (0.3.24)
# Collecting pinecone-client<6.0.0,>=5.0.0 (from langchain_pinecone)
#   Downloading pinecone_client-5.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.36)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain<0.4.0,>=0.3.12 (from langchain-community)
#   Downloading langchain-0.3.12-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4,>=0.3 (from langchain_pinecone)
#   Downloading langchain_core-0.3.25-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.3)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.7.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.46.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.26.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.18.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (4.0.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Collecting langchain-text-splitters<0.4.0,>=0.3.3 (from langchain<0.4.0,>=0.3.12->langchain-community)
#   Downloading langchain_text_splitters-0.3.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Collecting pinecone-plugin-inference<2.0.0,>=1.0.3 (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone)
#   Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (2.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain_pinecone) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<3.10,>=3.9.5->langchain_pinecone) (0.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Downloading langchain_pinecone-0.2.0-py3-none-any.whl (11 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading langchain_community-0.3.12-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 18.2 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.7 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain-0.3.12-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.5 MB/s eta 0:00:00
# Downloading langchain_core-0.3.25-py3-none-any.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.2/411.2 kB 15.8 MB/s eta 0:00:00
# Downloading pinecone_client-5.0.1-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 6.5 MB/s eta 0:00:00
# Downloading pydantic_settings-2.7.0-py3-none-any.whl (29 kB)
# Downloading langchain_text_splitters-0.3.3-py3-none-any.whl (27 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.9 MB/s eta 0:00:00
# Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.4 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, pinecone-plugin-interface, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pinecone-plugin-inference, pydantic-settings, pinecone-client, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain_pinecone, langchain, langchain-community
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.10
#     Uninstalling aiohttp-3.11.10:
#       Successfully uninstalled aiohttp-3.11.10
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.24
#     Uninstalling langchain-core-0.3.24:
#       Successfully uninstalled langchain-core-0.3.24
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.2
#     Uninstalling langchain-text-splitters-0.3.2:
#       Successfully uninstalled langchain-text-splitters-0.3.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.11
#     Uninstalling langchain-0.3.11:
#       Successfully uninstalled langchain-0.3.11
# Successfully installed aiohttp-3.9.5 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.12 langchain-community-0.3.12 langchain-core-0.3.25 langchain-text-splitters-0.3.3 langchain_pinecone-0.2.0 marshmallow-3.23.1 mypy-extensions-1.0.0 pinecone-client-5.0.1 pinecone-plugin-inference-1.1.0 pinecone-plugin-interface-0.0.7 pydantic-settings-2.7.0 python-dotenv-1.0.1 typing-inspect-0.9.0
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx) (1.2.2)
# Collecting cerebras_cloud_sdk
#   Downloading cerebras_cloud_sdk-1.14.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->cerebras_cloud_sdk) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->cerebras_cloud_sdk) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->cerebras_cloud_sdk) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->cerebras_cloud_sdk) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->cerebras_cloud_sdk) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->cerebras_cloud_sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->cerebras_cloud_sdk) (2.27.1)
# Downloading cerebras_cloud_sdk-1.14.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: cerebras_cloud_sdk
# Successfully installed cerebras_cloud_sdk-1.14.0

# %%
from langchain_pinecone import PineconeVectorStore
from openai import OpenAI
import dotenv
import json
import yfinance as yf
import concurrent.futures
from langchain_community.embeddings import HuggingFaceEmbeddings
from google.colab import userdata
from langchain.schema import Document
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone
import numpy as np
import requests
import os
from cerebras.cloud.sdk import Cerebras

# %%
def get_stock_info(symbol: str) -> dict:
    """
    Retrieves and formats detailed information about a stock from Yahoo Finance.

    Args:
        symbol (str): The stock ticker symbol to look up.

    Returns:
        dict: A dictionary containing detailed stock information, including ticker, name,
              business summary, city, state, country, industry, and sector.
    """
    data = yf.Ticker(symbol)
    stock_info = data.info

    properties = {
        "Ticker": stock_info.get('symbol', 'Information not available'),
        'Name': stock_info.get('longName', 'Information not available'),
        'Business Summary': stock_info.get('longBusinessSummary'),
        'City': stock_info.get('city', 'Information not available'),
        'State': stock_info.get('state', 'Information not available'),
        'Country': stock_info.get('country', 'Information not available'),
        'Industry': stock_info.get('industry', 'Information not available'),
        'Sector': stock_info.get('sector', 'Information not available')
    }

    return properties

# %%
data = yf.Ticker("NVDA")
stock_info = data.info
print(stock_info)
# Out:
# {'address1': '2788 San Tomas Expressway', 'city': 'Santa Clara', 'state': 'CA', 'zip': '95051', 'country': 'United States', 'phone': '408 486 2000', 'website': 'https://www.nvidia.com', 'industry': 'Semiconductors', 'industryKey': 'semiconductors', 'industryDisp': 'Semiconductors', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': "NVIDIA Corporation provides graphics and compute and networking solutions in the United States, Taiwan, China, Hong Kong, and internationally. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating metaverse and 3D internet applications. The Compute & Networking segment comprises Data Center computing platforms and end-to-end networking platforms, including Quantum for InfiniBand and Spectrum for Ethernet; NVIDIA DRIVE automated-driving platform and automotive development agreements; Jetson robotics and other embedded platforms; NVIDIA AI Enterprise and other software; and DGX Cloud software and services. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.", 'fullTimeEmployees': 29600, 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Jen-Hsun  Huang', 'age': 60, 'title': 'Co-Founder, CEO, President & Director', 'yearBorn': 1963, 'fiscalYear': 2024, 'totalPay': 7491487, 'exercisedValue': 217327152, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Colette M. Kress', 'age': 56, 'title': 'Executive VP & CFO', 'yearBorn': 1967, 'fiscalYear': 2024, 'totalPay': 1510765, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Debora  Shoquist', 'age': 68, 'title': 'Executive Vice President of Operations', 'yearBorn': 1955, 'fiscalYear': 2024, 'totalPay': 1371266, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Timothy S. Teter J.D.', 'age': 56, 'title': 'Executive VP, General Counsel & Secretary', 'yearBorn': 1967, 'fiscalYear': 2024, 'totalPay': 1360939, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Ajay K. Puri', 'age': 68, 'title': 'Executive Vice President of Worldwide Field Operations', 'yearBorn': 1955, 'fiscalYear': 2024, 'totalPay': 2295097, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Chris A. Malachowsky', 'title': 'Co-Founder', 'fiscalYear': 2024, 'totalPay': 320000, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Donald F. Robertson Jr.', 'age': 54, 'title': 'VP & Chief Accounting Officer', 'yearBorn': 1969, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Prof. William J. Dally Ph.D.', 'age': 62, 'title': 'Chief Scientist & Senior VP of Research', 'yearBorn': 1961, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Mylene  Mangalindan', 'title': 'VP of Corporate Communications', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Tommy  Lee', 'title': 'Senior Vice President of Systems Engineering & Application', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}], 'auditRisk': 7, 'boardRisk': 10, 'compensationRisk': 5, 'shareHolderRightsRisk': 6, 'overallRisk': 8, 'governanceEpoc ...

# %%
def get_huggingface_embeddings(text, model_name="sentence-transformers/all-mpnet-base-v2"):
    """
    Generates embeddings for the given text using a specified Hugging Face model.

    Args:
        text (str): The input text to generate embeddings for.
        model_name (str): The name of the Hugging Face model to use.
                          Defaults to "sentence-transformers/all-mpnet-base-v2".

    Returns:
        np.ndarray: The generated embeddings as a NumPy array.
    """
    model = SentenceTransformer(model_name)
    return model.encode(text)


def cosine_similarity_between_sentences(sentence1, sentence2):
    """
    Calculates the cosine similarity between two sentences.

    Args:
        sentence1 (str): The first sentence for similarity comparison.
        sentence2 (str): The second sentence for similarity comparison.

    Returns:
        float: The cosine similarity score between the two sentences,
               ranging from -1 (completely opposite) to 1 (identical).

    Notes:
        Prints the similarity score to the console in a formatted string.
    """
    # Get embeddings for both sentences
    embedding1 = np.array(get_huggingface_embeddings(sentence1))
    embedding2 = np.array(get_huggingface_embeddings(sentence2))

    # Reshape embeddings for cosine_similarity function
    embedding1 = embedding1.reshape(1, -1)
    embedding2 = embedding2.reshape(1, -1)

    # Calculate cosine similarity
    similarity = cosine_similarity(embedding1, embedding2)
    similarity_score = similarity[0][0]
    print(f"Cosine similarity between the two sentences: {similarity_score:.4f}")
    return similarity_score


# Example usage
sentence1 = "I like walking to the park"
sentence2 = "I like running to the office"

similarity = cosine_similarity_between_sentences(sentence1, sentence2)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Cosine similarity between the two sentences: 0.6133

# %%
aapl_info = get_stock_info('AAPL')
print(aapl_info)
# Out:
# {'Ticker': 'AAPL', 'Name': 'Apple Inc.', 'Business Summary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.', 'City': 'Cupertino', 'State': 'CA', 'Country': 'United States', 'Industry': 'Consumer Electronics', 'Sector': 'Technology'}

# %%
aapl_description = aapl_info['Business Summary']

company_description = "I want to find companies that make smartphones and are headquarted in California"

similarity = cosine_similarity_between_sentences(aapl_description, company_description)
# Out:
# Cosine similarity between the two sentences: 0.3635

# %% [markdown]
# # Get all the Stocks in the Stock Market

# %% [markdown]
# First, we need to get the symbols (also known as tickers) of all the stocks in the stock market

# %%
def get_company_tickers():
    """
    Downloads and parses the Stock ticker symbols from the GitHub-hosted SEC company tickers JSON file.

    Returns:
        dict: A dictionary containing company tickers and related information.

    Notes:
        The data is sourced from the official SEC website via a GitHub repository:
        https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json
    """
    # URL to fetch the raw JSON file from GitHub
    url = "https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json"

    # Making a GET request to the URL
    response = requests.get(url)

    # Checking if the request was successful
    if response.status_code == 200:
        # Parse the JSON content directly
        company_tickers = json.loads(response.content.decode('utf-8'))

        # Optionally save the content to a local file for future use
        with open("company_tickers.json", "w", encoding="utf-8") as file:
            json.dump(company_tickers, file, indent=4)

        print("File downloaded successfully and saved as 'company_tickers.json'")
        return company_tickers
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
        return None

company_tickers = get_company_tickers()
# Out:
# File downloaded successfully and saved as 'company_tickers.json'

# %%
company_tickers
# Out:
# {'0': {'cik_str': 1045810, 'ticker': 'NVDA', 'title': 'NVIDIA CORP'},
#  '1': {'cik_str': 320193, 'ticker': 'AAPL', 'title': 'Apple Inc.'},
#  '2': {'cik_str': 789019, 'ticker': 'MSFT', 'title': 'MICROSOFT CORP'},
#  '3': {'cik_str': 1018724, 'ticker': 'AMZN', 'title': 'AMAZON COM INC'},
#  '4': {'cik_str': 1652044, 'ticker': 'GOOGL', 'title': 'Alphabet Inc.'},
#  '5': {'cik_str': 1326801, 'ticker': 'META', 'title': 'Meta Platforms, Inc.'},
#  '6': {'cik_str': 1318605, 'ticker': 'TSLA', 'title': 'Tesla, Inc.'},
#  '7': {'cik_str': 1067983,
#   'ticker': 'BRK-B',
#   'title': 'BERKSHIRE HATHAWAY INC'},
#  '8': {'cik_str': 1046179,
#   'ticker': 'TSM',
#   'title': 'TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD'},
#  '9': {'cik_str': 1730168, 'ticker': 'AVGO', 'title': 'Broadcom Inc.'},
#  '10': {'cik_str': 59478, 'ticker': 'LLY', 'title': 'ELI LILLY & Co'},
#  '11': {'cik_str': 19617, 'ticker': 'JPM', 'title': 'JPMORGAN CHASE & CO'},
#  '12': {'cik_str': 104169, 'ticker': 'WMT', 'title': 'Walmart Inc.'},
#  '13': {'cik_str': 1403161, 'ticker': 'V', 'title': 'VISA INC.'},
#  '14': {'cik_str': 731766, 'ticker': 'UNH', 'title': 'UNITEDHEALTH GROUP INC'},
#  '15': {'cik_str': 884394, 'ticker': 'SPY', 'title': 'SPDR S&P 500 ETF TRUST'},
#  '16': {'cik_str': 34088, 'ticker': 'XOM', 'title': 'EXXON MOBIL CORP'},
#  '17': {'cik_str': 1341439, 'ticker': 'ORCL', 'title': 'ORACLE CORP'},
#  '18': {'cik_str': 1141391, 'ticker': 'MA', 'title': 'Mastercard Inc'},
#  '19': {'cik_str': 353278, 'ticker': 'NVO', 'title': 'NOVO NORDISK A S'},
#  '20': {'cik_str': 354950, 'ticker': 'HD', 'title': 'HOME DEPOT, INC.'},
#  '21': {'cik_str': 909832,
#   'ticker': 'COST',
#   'title': 'COSTCO WHOLESALE CORP /NEW'},
#  '22': {'cik_str': 80424, 'ticker': 'PG', 'title': 'PROCTER & GAMBLE Co'},
#  '23': {'cik_str': 200406, 'ticker': 'JNJ', 'title': 'JOHNSON & JOHNSON'},
#  '24': {'cik_str': 70858,
#   'ticker': 'BAC',
#   'title': 'BANK OF AMERICA CORP /DE/'},
#  '25': {'cik_str': 1065280, 'ticker': 'NFLX', 'title': 'NETFLIX INC'},
#  '26': {'cik_str': 1108524, 'ticker': 'CRM', 'title': 'Salesforce, Inc.'},
#  '27': {'cik_str': 1551152, 'ticker': 'ABBV', 'title': 'AbbVie Inc.'},
#  '28': {'cik_str': 2008670, 'ticker': 'RCIT', 'title': 'REELCAUSE INC'},
#  '29': {'cik_str': 93410, 'ticker': 'CVX', 'title': 'CHEVRON CORP'},
#  '30': {'cik_str': 1283699, 'ticker': 'TMUS', 'title': 'T-Mobile US, Inc.'},
#  '31': {'cik_str': 1000184, 'ticker': 'SAP', 'title': 'SAP SE'},
#  '32': {'cik_str': 21344, 'ticker': 'KO', 'title': 'COCA COLA CO'},
#  '33': {'cik_str': 937966, 'ticker': 'ASML', 'title': 'ASML HOLDING NV'},
#  '34': {'cik_str': 72971,
#   'ticker': 'WFC',
#   'title': 'WELLS FARGO & COMPANY/MN'},
#  '35': {'cik_str': 310158, 'ticker': 'MRK', 'title': 'Merck & Co., Inc.'},
#  '36': {'cik_str': 858877, 'ticker': 'CSCO', 'title': 'CISCO SYSTEMS, INC.'},
#  '37': {'cik_str': 1094517, 'ticker': 'TM', 'title': 'TOYOTA MOTOR CORP/'},
#  '38': {'cik_str': 796343, 'ticker': 'ADBE', 'title': 'ADOBE INC.'},
#  '39': {'cik_str': 1467373, 'ticker': 'ACN', 'title': 'Accenture plc'},
#  '40': {'cik_str': 1393818, 'ticker': 'BX', 'title': 'Blackstone Inc.'},
#  '41': {'cik_str': 77476, 'ticker': 'PEP', 'title': 'PEPSICO INC'},
#  '42': {'cik_str': 2488,
#   'ticker': 'AMD',
#   'title': 'ADVANCED MICRO DEVICES INC'},
#  '43': {'cik_str': 895421, 'ticker': 'MS', 'title': 'MORGAN STANLEY'},
#  '44': {'cik_str': 1707925, 'ticker': 'LIN', 'title': 'LINDE PLC'},
#  '45': {'cik_str': 1577552,
#   'ticker': 'BABA',
#   'title': 'Alibaba Group Holding Ltd'},
#  '46': {'cik_str': 63908, 'ticker': 'MCD', 'title': 'MCDONALDS CORP'},
#  '47': {'cik_str': 1114448, 'ticker': 'NVS', 'title': 'NOVARTIS AG'},
#  '48': {'cik_str': 1373715, 'ticker': 'NOW', 'title': 'ServiceNow, Inc.'},
#  '49': {'cik_str': 1744489, 'ticker': 'DIS', 'title': 'Walt Disney Co'},
#  '50': {'cik_str': 4962, 'ticker': 'AXP', 'title': 'AMERICAN EXPRESS CO'},
#  '51': {'cik_str': 1413329,
#   'ticker': 'PM',
#   'title': 'Philip Morris International Inc.'},
#  '52': {'cik_str': 1800, 'ticker': 'ABT', 'title': 'ABBOTT LABORATORIES'},
#  '53': {'cik_str': 1306965, 'ticker': 'SHEL', 'title': 'Shell plc'},
#  '54': {'cik_str': 901832, 'ticker': 'AZN', 'title': 'ASTRAZENECA PLC'},
#  '55': {'cik_str': 97745,
#   'ticker': 'TMO',
#   'title': 'THERMO FISHER SCIENTIFIC INC.'},
#  '56': {'cik_str': 1067839,
#   'ticker': 'QQQ',
#   'title': 'INVESCO QQQ TRUST, SERIES 1'},
#  '57': {'cik_str': 896878, 'ticker': 'INTU', 'title': 'INTUIT INC.'},
#  '58': {'cik_str': 40545, 'ticker': 'GE', 'title': 'GENERAL ELECTRIC CO'},
#  '59': {'cik_str': 51143,
#   'ticker': 'IBM',
#   'title': 'INTERNATIONAL BUSINESS MACHINES CORP'},
#  '60': {'cik_str': 1035267,
#   'ticker': 'ISRG',
#   'title': 'INTUITIVE SURGICAL INC'},
#  '61': {'cik_str': 886982, 'ticker': 'GS', 'title': 'GOLDMAN SACHS GROUP INC'},
#  '62': {'cik_str': 18230, 'ticker': 'CAT', 'title': 'CATERPILLAR INC'},
#  '63': {'cik_str': 97476, 'ticker': 'TXN', 'title': 'TEXAS INSTRUMENTS INC'},
#  '64': {'cik_str': 804328, 'ticker': 'QCOM', 'title': 'QUALCOMM INC/DE'},
#  '65': {'cik_str': 732712,
#   'ticker': 'VZ',
#   'title': 'VERIZON COMMUNICATIONS INC'},
#  '66': {'cik_str': 1000275, 'ticker': 'RY', 'title': 'ROYAL BANK OF CANADA'},
#  '67': {'cik_str': 313616, 'ticker': 'DHR', 'title': 'DANAHER CORP /DE/'},
#  '68': {'cik_str': 1089113, 'ticker': 'HSBC', 'title': 'HSBC HOLDINGS PLC'},
#  '69': {'cik_str': 1075531,
#   'ticker': 'BKNG',
#   'title': 'Booking Holdings Inc.'},
#  '70': {'cik_str': 1061736,
#   'ticker': 'FMX',
#   'title': 'MEXICAN ECONOMIC DEVELOPMENT INC'},
#  '71': {'cik_str': 1166691, 'ticker': 'CMCSA', 'title': 'COMCAST CORP'},
#  '72': {'cik_str': 732717, 'ticker': 'T', 'title': 'AT&T INC.'},
#  '73': {'cik_str': 1737806, 'ticker': 'PDD', 'title': 'PDD Holdings Inc.'},
#  '74': {'cik_str': 1144967, 'ticker': 'HDB', 'title': 'HDFC BANK LTD'},
#  '75': {'cik_str': 753308, 'ticker': 'NEE', 'title': 'NEXTERA ENERGY INC'},
#  '76': {'cik_str': 101829, 'ticker': 'RTX', 'title': 'RTX Corp'},
#  '77': {'cik_str': 64040, 'ticker': 'SPGI', 'title': 'S&P Global Inc.'},
#  '78': {'cik_str': 2012383, 'ticker': 'BLK', 'title': 'BlackRock, Inc.'},
#  '79': {'cik_str': 1543151,
#   'ticker': 'UBER',
#   'title': 'Uber Technologies, Inc'},
#  '80': {'cik_str': 60667, 'ticker': 'LOW', 'title': 'LOWES COMPANIES INC'},
#  '81': {'cik_str': 318154, 'ticker': 'AMGN', 'title': 'AMGEN INC'},
#  '82': {'cik_str': 80661, 'ticker': 'PGR', 'title': 'PROGRESSIVE CORP/OH/'},
#  '83': {'cik_str': 773840,
#   'ticker': 'HON',
#   'title': 'HONEYWELL INTERNATIONAL INC'},
#  '84': {'cik_str': 310764, 'ticker': 'SYK', 'title': 'STRYKER CORP'},
#  '85': {'cik_str': 316709, 'ticker': 'SCHW', 'title': 'SCHWAB CHARLES CORP'},
#  '86': {'cik_str': 1321655,
#   'ticker': 'PLTR',
#   'title': 'Palantir Technologies Inc.'},
#  '87': {'cik_str': 100885, 'ticker': 'UNP', 'title': 'UNION PACIFIC CORP'},
#  '88': {'cik_str': 217410, 'ticker': 'UL', 'title': 'UNILEVER PLC'},
#  '89': {'cik_str': 1551182, 'ticker': 'ETN', 'title': 'Eaton Corp plc'},
#  '90': {'cik_str': 78003, 'ticker': 'PFE', 'title': 'PFIZER INC'},
#  '91': {'cik_str': 6951,
#   'ticker': 'AMAT',
#   'title': 'APPLIED MATERIALS INC /DE'},
#  '92': {'cik_str': 1594805, 'ticker': 'SHOP', 'title': 'SHOPIFY INC.'},
#  '93': {'cik_str': 879764, 'ticker': 'TTE', 'title': 'TotalEnergies SE'},
#  '94': {'cik_str': 1404912, 'ticker': 'KKR', 'title': 'KKR & Co. Inc.'},
#  '95': {'cik_str': 67088,
#   'ticker': 'MUFG',
#   'title': 'MITSUBISHI UFJ FINANCIAL GROUP INC'},
#  '96': {'cik_str': 109198, 'ticker': 'TJX', 'title': 'TJX COMPANIES INC /DE/'},
#  '97': {'cik_str': 1973239, 'ticker': 'ARM', 'title': 'ARM HOLDINGS PLC /UK'},
#  '98': {'cik_str': 811809, 'ticker': 'BHP', 'title': 'BHP Group Ltd'},
#  '99': {'cik_str': 831001, 'ticker': 'C', 'title': 'CITIGROUP INC'},
#  '100': {'cik_str': 1163165, 'ticker': 'COP', 'title': 'CONOCOPHILLIPS'},
#  '101': {'cik_str': 885725,
#   'ticker': 'BSX',
#   'title': 'BOSTON SCIENTIFIC CORP'},
#  '102': {'cik_str': 1327567,
#   'ticker': 'PANW',
#   'title': 'Palo Alto Networks Inc'},
#  '103': {'cik_str': 936468, 'ticker': 'LMT', 'title': 'LOCKHEED MARTIN CORP'},
#  '104': {'cik_str': 1121404, 'ticker': 'SNY', 'title': 'Sanofi'},
#  '105': {'cik_str': 8670,
#   'ticker': 'ADP',
#   'title': 'AUTOMATIC DATA PROCESSING INC'},
#  '106': {'cik_str': 887028, 'ticker': 'RTNTF', 'title': 'RIO TINTO LTD'},
#  '107': {'cik_str': 798354, 'ticker': 'FI', 'title': 'FISERV INC'},
#  '108': {'cik_str': 875320,
#   'ticker': 'VRTX',
#   'title': 'VERTEX PHARMACEUTICALS INC / MA'},
#  '109': {'cik_str': 1596532,
#   'ticker': 'ANET',
#   'title': 'Arista Networks, Inc.'},
#  '110': {'cik_str': 896159, 'ticker': 'CB', 'title': 'Chubb Ltd'},
#  '111': {'cik_str': 1378580, 'ticker': 'EADSY', 'title': 'Airbus SE/ADR'},
#  '112': {'cik_str': 320187, 'ticker': 'NKE', 'title': 'NIKE, Inc.'},
#  '113': {'cik_str': 14272,
#   'ticker': 'BMY',
#   'title': 'BRISTOL MYERS SQUIBB CO'},
#  '114': {'cik_str': 1090727,
#   'ticker': 'UPS',
#   'title': 'UNITED PARCEL SERVICE INC'},
#  '115': {'cik_str': 829224, 'ticker': 'SBUX', 'title': 'STARBUCKS CORP'},
#  '116': {'cik_str': 313838, 'ticker': 'SONY', 'title': 'Sony Group Corp'},
#  '117': {'cik_str': 1613103, 'ticker': 'MDT', 'title': 'Medtronic plc'},
#  '118': {'cik_str': 882095,
#   'ticker': 'GILD',
#   'title': 'GILEAD SCIENCES, INC.'},
#  '119': {'cik_str': 1668717,
#   'ticker': 'BUD',
#   'title': 'Anheuser-Busch InBev SA/NV'},
#  '120': {'cik_str': 315189, 'ticker': 'DE', 'title': 'DEERE & CO'},
#  '121': {'cik_str': 62709,
#   'ticker': 'MMC',
#   'title': 'MARSH & MCLENNAN COMPANIES, INC.'},
#  '122': {'cik_str': 723125, 'ticker': 'MU', 'title': 'MICRON TECHNOLOGY INC'},
#  '123': {'cik_str': 50863, 'ticker': 'INTC', 'title': 'INTEL CORP'},
#  '124': {'cik_str': 1045609, 'ticker': 'PLD', 'title': 'Prologis, Inc.'},
#  '125': {'cik_str': 12927, 'ticker': 'BA', 'title': 'BOEING CO'},
#  '126': {'cik_str': 1103838, 'ticker': 'IBN', 'title': 'ICICI BANK LTD'},
#  '127': {'cik_str': 6281, 'ticker': 'ADI', 'title': 'ANALOG DEVICES INC'},
#  '128': {'cik_str': 1610520, 'ticker': 'UBS', 'title': 'UBS Group AG'},
#  '129': {'cik_str': 863064, 'ticker': 'RIO', 'title': 'RIO TINTO PLC'},
#  '130': {'cik_str': 947263, 'ticker': 'TD', 'title': 'TORONTO DOMINION BANK'},
#  '131': {'cik_str': 1161167,
#   'ticker': 'AIQUY',
#   'title': 'L AIR LIQUIDE SA /FI'},
#  '132': {'cik_str': 92122, 'ticker': 'SO', 'title': 'SOUTHERN CO'},
#  '133': {'cik_str': 89800, 'ticker': 'SHW', 'title': 'SHERWIN WILLIAMS CO'},
#  '134': {'cik_str': 1751008, 'ticker': 'APP', 'title': 'AppLovin Corp'},
#  '135': {'cik_str': 764180, 'ticker': 'MO', 'title': 'ALTRIA GROUP, INC.'},
#  '136': {'cik_str': 1099590, 'ticker': 'MELI', 'title': 'MERCADOLIBRE INC'},
#  '137': {'cik_str': 1156039,
#   'ticker': 'ELV',
#   'title': 'Elevance Health, Inc.'},
#  '138': {'cik_str': 1639920,
#   'ticker': 'SPOT',
#   'title': 'Spotify Technology S.A.'},
#  '139': {'cik_str': 895728, 'ticker': 'ENB', 'title': 'ENBRIDGE INC'},
#  '140': {'cik_str': 1571996,
#   'ticker': 'DELL',
#   'title': 'Dell Technologies Inc.'},
#  '141': {'cik_str': 1996810, 'ticker': 'GEV', 'title': 'GE Vernova Inc.'},
#  '142': {'cik_str': 1858681,
#   'ticker': 'APO',
#   'title': 'Apollo Global Management, Inc.'},
#  '143': {'cik_str': 1466258,
#   'ticker': 'TT',
#   'title': 'Trane Technologies plc'},
#  '144': {'cik_str': 1053507,
#   'ticker': 'AMT',
#   'title': 'AMERICAN TOWER CORP /MA/'},
#  '145': {'cik_str': 1022837,
#   'ticker': 'SMFG',
#   'title': 'SUMITOMO MITSUI FINANCIAL GROUP, INC.'},
#  '146': {'cik_str': 707549, 'ticker': 'LRCX', 'title': 'LAM RESEARCH CORP'},
#  '147': {'cik_str': 1067491, 'ticker': 'INFY', 'title': 'Infosys Ltd'},
#  '148': {'cik_str': 76334, 'ticker': 'PH', 'title': 'PARKER HANNIFIN CORP'},
#  '149': {'cik_str': 1571949,
#   'ticker': 'ICE',
#   'title': 'Intercontinental Exchange, Inc.'},
#  '150': {'cik_str': 1739940, 'ticker': 'CI', 'title': 'Cigna Group'},
#  '151': {'cik_str': 823768, 'ticker': 'WM', 'title': 'WASTE MANAGEMENT INC'},
#  '152': {'cik_str': 1119639,
#   'ticker': 'PBR',
#   'title': 'PETROBRAS - PETROLEO BRASILEIRO SA'},
#  '153': {'cik_str': 1101239, 'ticker': 'EQIX', 'title': 'EQUINIX INC'},
#  '154': {'cik_str': 723254, 'ticker': 'CTAS', 'title': 'CINTAS CORP'},
#  '155': {'cik_str': 860730, 'ticker': 'HCA', 'title': 'HCA Healthcare, Inc.'},
#  '156': {'cik_str': 1326160, 'ticker': 'DUK', 'title': 'Duke Energy CORP'},
#  '157': {'cik_str': 1103982,
#   'ticker': 'MDLZ',
#   'title': 'Mondelez International, Inc.'},
#  '158': {'cik_str': 1001085, 'ticker': 'BN', 'title': 'BROOKFIELD Corp /ON/'},
#  '159': {'cik_str': 1633917,
#   'ticker': 'PYPL',
#   'title': 'PayPal Holdings, Inc.'},
#  '160': {'cik_str': 1059556, 'ticker': 'MCO', 'title': 'MOODYS CORP /DE/'},
#  '161': {'cik_str': 820313, 'ticker': 'APH', 'title': 'AMPHENOL CORP /DE/'},
#  '162': {'cik_str': 766704, 'ticker': 'WELL', 'title': 'WELLTOWER INC.'},
#  '163': {'cik_str': 872589,
#   'ticker': 'REGN',
#   'title': 'REGENERON PHARMACEUTICALS, INC.'},
#  '164': {'cik_str': 1559720, 'ticker': 'ABNB', 'title': 'Airbnb, Inc.'},
#  '165': {'cik_str': 319201, 'ticker': 'KLAC', 'title': 'KLA CORP'},
#  '166': {'cik_str': 929869, 'ticker': 'RELX', 'title': 'RELX PLC'},
#  '167': {'cik_str': 713676,
#   'ticker': 'PNC',
#   'title': 'PNC FINANCIAL SERVICES GROUP, INC.'},
#  '168': {'cik_str': 1535527,
#   'ticker': 'CRWD',
#   'title': 'CrowdStrike Holdings, Inc.'},
#  '169': {'cik_str': 68505,
#   'ticker': 'MSI',
#   'title': 'Motorola Solutions, Inc.'},
#  '170': {'cik_str': 315293, 'ticker': 'AON', 'title': 'Aon plc'},
#  '171': {'cik_str': 1156375, 'ticker': 'CME', 'title': 'CME GROUP INC.'},
#  '172': {'cik_str': 883241, 'ticker': 'SNPS', 'title': 'SYNOPSYS INC'},
#  '173': {'cik_str': 1058090,
#   'ticker': 'CMG',
#   'title': 'CHIPOTLE MEXICAN GRILL INC'},
#  '174': {'cik_str': 948401,
#   'ticker': 'CFRUY',
#   'title': 'COMPAGNIE FINANCIERE RICHEMONT AG /FI'},
#  '175': {'cik_str': 49826,
#   'ticker': 'ITW',
#   'title': 'ILLINOIS TOOL WORKS INC'},
#  '176': {'cik_str': 1303523,
#   'ticker': 'BTI',
#   'title': 'British American Tobacco p.l.c.'},
#  '177': {'cik_str': 813672,
#   'ticker': 'CDNS',
#   'title': 'CADENCE DESIGN SYSTEMS INC'},
#  '178': {'cik_str': 40533, 'ticker': 'GD', 'title': 'GENERAL DYNAMICS CORP'},
#  '179': {'cik_str': 1555280, 'ticker': 'ZTS', 'title': 'Zoetis Inc.'},
#  '180': {'cik_str': 1001838,
#   'ticker': 'SCCO',
#   'title': 'SOUTHERN COPPER CORP/'},
#  '181': {'cik_str': 36104, 'ticker': 'USB', 'title': 'US BANCORP \\DE\\'},
#  '182': {'cik_str': 1648416, 'ticker': 'RACE', 'title': 'Ferrari N.V.'},
#  '183': {'cik_str': 1048286,
#   'ticker': 'MAR',
#   'title': 'MARRIOTT INTERNATIONAL INC /MD/'},
#  '184': {'cik_str': 927653, 'ticker': 'MCK', 'title': 'MCKESSON CORP'},
#  '185': {'cik_str': 21665, 'ticker': 'CL', 'title': 'COLGATE PALMOLIVE CO'},
#  '186': {'cik_str': 1835632,
#   'ticker': 'MRVL',
#   'title': 'Marvell Technology, Inc.'},
#  '187': {'cik_str': 313807, 'ticker': 'BP', 'title': 'BP PLC'},
#  '188': {'cik_str': 1381197,
#   'ticker': 'IBKR',
#   'title': 'Interactive Brokers Group, Inc.'},
#  '189': {'cik_str': 821189, 'ticker': 'EOG', 'title': 'EOG RESOURCES INC'},
#  '190': {'cik_str': 1679788,
#   'ticker': 'COIN',
#   'title': 'Coinbase Global, Inc.'},
#  '191': {'cik_str': 891478, 'ticker': 'SAN', 'title': 'Banco Santander, S.A.'},
#  '192': {'cik_str': 1075124,
#   'ticker': 'TRI',
#   'title': 'THOMSON REUTERS CORP /CAN/'},
#  '193': {'cik_str': 32604, 'ticker': 'EMR', 'title': 'EMERSON ELECTRIC CO'},
#  '194': {'cik_str': 1262039, 'ticker': 'FTNT', 'title': 'Fortinet, Inc.'},
#  '195': {'cik_str': 1133421,
#   'ticker': 'NOC',
#   'title': 'NORTHROP GRUMMAN CORP /DE/'},
#  '196': {'cik_str': 1048911, 'ticker': 'FDX', 'title': 'FEDEX CORP'},
#  '197': {'cik_str': 1442651,
#   'ticker': 'SHECY',
#   'title': 'Shin-Etsu Chemical Co., Ltd.'},
#  '198': {'cik_str': 66740, 'ticker': 'MMM', 'title': '3M CO'},
#  '199': {'cik_str': 1050446, 'ticker': 'MSTR', 'title': 'MICROSTRATEGY Inc'},
#  '200': {'cik_str': 1792789, 'ticker': 'DASH', 'title': 'DoorDash, Inc.'},
#  '201': {'cik_str': 1017413,
#   'ticker': 'CNQ',
#   'title': 'CANADIAN NATURAL RESOURCES LTD'},
#  '202': {'cik_str': 27419, 'ticker': 'TGT', 'title': 'TARGET CORP'},
#  '203': {'cik_str': 2969,
#   'ticker': 'APD',
#   'title': 'Air Products & Chemicals, Inc.'},
#  '204': {'cik_str': 927628,
#   'ticker': 'COF',
#   'title': 'CAPITAL ONE FINANCIAL CORP'},
#  '205': {'cik_str': 1260221, 'ticker': 'TDG', 'title': 'TransDigm Group INC'},
#  '206': {'cik_str': 898173,
#   'ticker': 'ORLY',
#   'title': 'O REILLY AUTOMOTIVE INC'},
#  '207': {'cik_str': 1868275,
#   'ticker': 'CEG',
#   'title': 'Constellation Energy Corp'},
#  '208': {'cik_str': 16875,
#   'ticker': 'CP',
#   'title': 'CANADIAN PACIFIC KANSAS CITY LTD/CN'},
#  '209': {'cik_str': 31462, 'ticker': 'ECL', 'title': 'ECOLAB INC.'},
#  '210': {'cik_str': 16868,
#   'ticker': 'CNI',
#   'title': 'CANADIAN NATIONAL RAILWAY CO'},
#  '211': {'cik_str': 1131399, 'ticker': 'GSK', 'title': 'GSK plc'},
#  '212': {'cik_str': 1327811, 'ticker': 'WDAY', 'title': 'Workday, Inc.'},
#  '213': {'cik_str': 927971,
#   'ticker': 'BMO',
#   'title': 'BANK OF MONTREAL /CAN/'},
#  '214': {'cik_str': 107263,
#   'ticker': 'WMB',
#   'title': 'WILLIAMS COMPANIES, INC.'},
#  '215': {'cik_str': 277948, 'ticker': 'CSX', 'title': 'CSX CORP'},
#  '216': {'cik_str': 1063761,
#   'ticker': 'SPG',
#   'title': 'SIMON PROPERTY GROUP INC /DE/'},
#  '217': {'cik_str': 1061219,
#   'ticker': 'EPD',
#   'title': 'ENTERPRISE PRODUCTS PARTNERS L.P.'},
#  '218': {'cik_str': 1691493, 'ticker': 'NU', 'title': 'Nu Holdings Ltd.'},
#  '219': {'cik_str': 9631, 'ticker': 'BNS', 'title': 'BANK OF NOVA SCOTIA'},
#  '220': {'cik_str': 849395, 'ticker': 'CRH', 'title': 'CRH PUBLIC LTD CO'},
#  '221': {'cik_str': 64803, 'ticker': 'CVS', 'title': 'CVS HEALTH Corp'},
#  '222': {'cik_str': 1783180, 'ticker': 'CARR', 'title': 'CARRIER GLOBAL Corp'},
#  '223': {'cik_str': 835403, 'ticker': 'DEO', 'title': 'DIAGEO PLC'},
#  '224': {'cik_str': 1140625, 'ticker': 'EQNR', 'title': 'EQUINOR ASA'},
#  '225': {'cik_str': 10795, 'ticker': 'BDX', 'title': 'BECTON DICKINSON & CO'},
#  '226': {'cik_str': 1060391,
#   'ticker': 'RSG',
#   'title': 'REPUBLIC SERVICES, INC.'},
#  '227': {'cik_str': 354190,
#   'ticker': 'AJG',
#   'title': 'Arthur J. Gallagher & Co.'},
#  '228': {'cik_str': 769397, 'ticker': 'ADSK', 'title': 'Autodesk, Inc.'},
#  '229': {'cik_str': 1039684, 'ticker': 'OKE', 'title': 'ONEOK INC /NEW/'},
#  '230': {'cik_str': 1443276, 'ticker': 'TOELY', 'title': 'Tokyo Electron LTD'},
#  '231': {'cik_str': 1947559,
#   'ticker': 'ANZGY',
#   'title': 'ANZ GROUP HOLDINGS LIMITED/ADR'},
#  '232': {'cik_str': 1467858, 'ticker': 'GM', 'title': 'General Motors Co'},
#  '233': {'cik_str': 1650372, 'ticker': 'TEAM', 'title': 'Atlassian Corp'},
#  '234': {'cik_str': 884887,
#   'ticker': 'RCL',
#   'title': 'ROYAL CARIBBEAN CRUISES LTD'},
#  '235': {'cik_str': 4977, 'ticker': 'AFL', 'title': 'AFLAC INC'},
#  '236': {'cik_str': 1222333, 'ticker': 'GLD', 'title': 'SPDR GOLD TRUST'},
#  '237': {'cik_str': 92230, 'ticker': 'TFC', 'title': 'TRUIST FINANCIAL CORP'},
#  '238': {'cik_str': 1335730,
#   'ticker': 'MFG',
#   'title': 'MIZUHO FINANCIAL GROUP INC'},
#  '239': {'cik_str': 831259, 'ticker': 'FCX', 'title': 'FREEPORT-MCMORAN INC'},
#  '240': {'cik_str': 1004315, 'ticker': 'NGG', 'title': 'NATIONAL GRID PLC'},
#  '241': {'cik_str': 87347,
#   'ticker': 'SLB',
#   'title': 'SCHLUMBERGER LIMITED/NV'},
#  '242': {'cik_str': 1297996,
#   'ticker': 'DLR',
#   'title': 'DIGITAL REALTY TRUST, INC.'},
#  '243': {'cik_str': 1585689,
#   'ticker': 'HLT',
#   'title': 'Hilton Worldwide Holdings Inc.'},
#  '244': {'cik_str': 1506307, 'ticker': 'KMI', 'title': 'KINDER MORGAN, INC.'},
#  '245': {'cik_str': 1045520,
#   'ticker': 'CM',
#   'title': 'CANADIAN IMPERIAL BANK OF COMMERCE /CAN/'},
#  '246': {'cik_str': 1067318, 'ticker': 'MBGYY', 'title': 'DAIMLER AG'},
#  '247': {'cik_str': 702165, 'ticker': 'NSC', 'title': 'NORFOLK SOUTHERN CORP'},
#  '248': {'cik_str': 1276187, 'ticker': 'ET', 'title': 'Energy Transfer LP'},
#  '249': {'cik_str': 86312,
#   'ticker': 'TRV',
#   'title': 'TRAVELERS COMPANIES, INC.'},
#  '250': {'cik_str': 882835,
#   'ticker': 'ROP',
#   'title': 'ROPER TECHNOLOGIES INC'},
#  '251': {'cik_str': 75362, 'ticker': 'PCAR', 'title': 'PACCAR INC'},
#  '252': {'cik_str': 1393311, 'ticker': 'PSA', 'title': 'Public Storage'},
#  '253': {'cik_str': 1671933, 'ticker': 'TTD', 'title': 'Trade Desk, Inc.'},
#  '254': {'cik_str': 1524684, 'ticker': 'GLNCY', 'title': 'Glencore plc/ADR'},
#  '255': {'cik_str': 1549802, 'ticker': 'JD', 'title': 'JD.com, Inc.'},
#  '256': {'cik_str': 1703399, 'ticker': 'SE', 'title': 'Sea Ltd'},
#  '257': {'cik_str': 1032208, 'ticker': 'SRE', 'title': 'SEMPRA'},
#  '258': {'cik_str': 1099219, 'ticker': 'MET', 'title': 'METLIFE INC'},
#  '259': {'cik_str': 1086888,
#   'ticker': 'MFC',
#   'title': 'MANULIFE FINANCIAL CORP'},
#  '260': {'cik_str': 277135, 'ticker': 'GWW', 'title': 'W.W. GRAINGER, INC.'},
#  '261': {'cik_str': 1390777,
#   'ticker': 'BK',
#   'title': 'Bank of New York Mellon Corp'},
#  '262': {'cik_str': 842180,
#   'ticker': 'BBVA',
#   'title': 'BANCO BILBAO VIZCAYA ARGENTARIA, S.A.'},
#  '263': {'cik_str': 833444,
#   'ticker': 'JCI',
#   'title': 'Johnson Controls International plc'},
#  '264': {'cik_str': 1413447,
#   'ticker': 'NXPI',
#   'title': 'NXP Semiconductors N.V.'},
#  '265': {'cik_str': 1132597,
#   'ticker': 'ITUB',
#   'title': 'Itau Unibanco Holding S.A.'},
#  '266': {'cik_str': 1091667,
#   'ticker': 'CHTR',
#   'title': 'CHARTER COMMUNICATIONS, INC. /MO/'},
#  '267': {'cik_str': 814547, 'ticker': 'FICO', 'title': 'FAIR ISAAC CORP'},
#  '268': {'cik_str': 1067701, 'ticker': 'URI', 'title': 'UNITED RENTALS, INC.'},
#  '269': {'cik_str': 1110646, 'ticker': 'NTES', 'title': 'NetEase, Inc.'},
#  '270': {'cik_str': 820027,
#   'ticker': 'AMP',
#   'title': 'AMERIPRISE FINANCIAL INC'},
#  '271': {'cik_str': 1004980, 'ticker': 'PCG', 'title': 'PG&E Corp'},
#  '272': {'cik_str': 900075, 'ticker': 'CPRT', 'title': 'COPART INC'},
#  '273': {'cik_str': 1547873,
#   'ticker': 'PTCAY',
#   'title': 'PT Chandra Asri Petrochemical Tbk/ADR'},
#  '274': {'cik_str': 1534701, 'ticker': 'PSX', 'title': 'Phillips 66'},
#  '275': {'cik_str': 866787, 'ticker': 'AZO', 'title': 'AUTOZONE INC'},
#  '276': {'cik_str': 882184, 'ticker': 'DHI', 'title': 'HORTON D R INC /DE/'},
#  '277': {'cik_str': 1176948,
#   'ticker': 'ARES',
#   'title': 'Ares Management Corp'},
#  '278': {'cik_str': 899051, 'ticker': 'ALL', 'title': 'ALLSTATE CORP'},
#  '279': {'cik_str': 1539838,
#   'ticker': 'FANG',
#   'title': 'Diamondback Energy, Inc.'},
#  '280': {'cik_str': 723531, 'ticker': 'PAYX', 'title': 'PAYCHEX INC'},
#  '281': {'cik_str': 865752,
#   'ticker': 'MNST',
#   'title': 'Monster Beverage Corp'},
#  '282': {'cik_str': 30554, 'ticker': 'CTA-PA', 'title': 'EIDP, Inc.'},
#  '283': {'cik_str': 1512673, 'ticker': 'SQ', 'title': 'Block, Inc.'},
#  '284': {'cik_str': 4904,
#   'ticker': 'AEP',
#   'title': 'AMERICAN ELECTRIC POWER CO INC'},
#  '285': {'cik_str': 311337, 'ticker': 'SU', 'title': 'SUNCOR ENERGY INC'},
#  '286': {'cik_str': 1232384, 'ticker': 'TRP', 'title': 'TC ENERGY CORP'},
#  '287': {'cik_str': 1510295,
#   'ticker': 'MPC',
#   'title': 'Marathon Petroleum Corp'},
#  '288': {'cik_str': 895564,
#   'ticker': 'BAESY',
#   'title': 'BAE SYSTEMS PLC /FI/'},
#  '289': {'cik_str': 26172, 'ticker': 'CMI', 'title': 'CUMMINS INC'},
#  '290': {'cik_str': 1039765, 'ticker': 'ING', 'title': 'ING GROEP NV'},
#  '291': {'cik_str': 1588489,
#   'ticker': 'GBTC',
#   'title': 'Grayscale Bitcoin Trust ETF'},
#  '292': {'cik_str': 726728, 'ticker': 'O', 'title': 'REALTY INCOME CORP'},
#  '293': {'cik_str': 312069, 'ticker': 'BCS', 'title': 'BARCLAYS PLC'},
#  '294': {'cik_str': 715957, 'ticker': 'D', 'title': 'DOMINION ENERGY, INC'},
#  '295': {'cik_str': 1552000, 'ticker': 'MPLX', 'title': 'MPLX LP'},
#  '296': {'cik_str': 1692819, 'ticker': 'VST', 'title': 'Vistra Corp.'},
#  '297': {'cik_str': 1050915,
#   'ticker': 'PWR',
#   'title': 'QUANTA SERVICES, INC.'},
#  '298': {'cik_str': 1012037,
#   'ticker': 'CODYY',
#   'title': 'COMPAGNIE DE SAINT GOBAIN'},
#  '299': {'cik_str': 1318220,
#   'ticker': 'WCN',
#   'title': 'Waste Connections, Inc.'},
#  '300': {'cik_str': 1136893,
#   'ticker': 'FIS',
#   'title': 'Fidelity National Information Services, Inc.'},
#  '301': {'cik_str': 5272,
#   'ticker': 'AIG',
#   'title': 'AMERICAN INTERNATIONAL GROUP, INC.'},
#  '302': {'cik_str': 3570, 'ticker': 'LNG', 'title': 'Cheniere Energy, Inc.'},
#  '303': {'cik_str': 1635327,
#   'ticker': 'FLUT',
#   'title': 'Flutter Entertainment plc'},
#  '304': {'cik_str': 1278680, 'ticker': 'IAU', 'title': 'ISHARES GOLD TRUST'},
#  '305': {'cik_str': 1140859, 'ticker': 'COR', 'title': 'Cencora, Inc.'},
#  '306': {'cik_str': 815556, 'ticker': 'FAST', 'title': 'FASTENAL CO'},
#  '307': {'cik_str': 797468,
#   'ticker': 'OXY',
#   'title': 'OCCIDENTAL PETROLEUM CORP /DE/'},
#  '308': {'cik_str': 1129137,
#   'ticker': 'AMX',
#   'title': 'AMERICA MOVIL SAB DE CV/'},
#  '309': {'cik_str': 1408198, 'ticker': 'MSCI', 'title': 'MSCI Inc.'},
#  '310': {'cik_str': 202058,
#   'ticker': 'LHX',
#   'title': 'L3HARRIS TECHNOLOGIES, INC. /DE/'},
#  '311': {'cik_str': 745732, 'ticker': 'ROST', 'title': 'ROSS STORES, INC.'},
#  '312': {'cik_str': 1002242, 'ticker': 'E', 'title': 'ENI SPA'},
#  '313': {'cik_str': 1164727, 'ticker': 'NEM', 'title': 'NEWMONT Corp /DE/'},
#  '314': {'cik_str': 878927,
#   'ticker': 'ODFL',
#   'title': 'OLD DOMINION FREIGHT LINE, INC.'},
#  '315': {'cik_str': 1944048, 'ticker': 'KVUE', 'title': 'Kenvue Inc.'},
#  '316': {'cik_str': 1069183,
#   'ticker': 'AXON',
#   'title': 'AXON ENTERPRISE, INC.'},
#  '317': {'cik_str': 4281, 'ticker': 'HWM', 'title': 'Howmet Aerospace Inc.'},
#  '318': {'cik_str': 920760, 'ticker': 'LEN', 'title': 'LENNAR CORP /NEW/'},
#  '319': {'cik_str': 1137774,
#   'ticker': 'PRU',
#   'title': 'PRUDENTIAL FINANCIAL INC'},
#  '320': {'cik_str': 1120193, 'ticker': 'NDAQ', 'title': 'NASDAQ, INC.'},
#  '321': {'cik_str': 55785, 'ticker': 'KMB', 'title': 'KIMBERLY CLARK CORP'},
#  '322': {'cik_str': 1051470, 'ticker': 'CCI', 'title': 'CROWN CASTLE INC.'},
#  '323': {'cik_str': 1674101, 'ticker': 'VRT', 'title': 'Vertiv Holdings Co'},
#  '324': {'cik_str': 4447, 'ticker': 'HES', 'title': 'HESS CORP'},
#  '325': {'cik_str': 1037868, 'ticker': 'AME', 'title': 'AMETEK INC/'},
#  '326': {'cik_str': 1385157, 'ticker': 'TEL', 'title': 'TE Connectivity plc'},
#  '327': {'cik_str': 37996, 'ticker': 'F', 'title': 'FORD MOTOR CO'},
#  '328': {'cik_str': 1035002,
#   'ticker': 'VLO',
#   'title': 'VALERO ENERGY CORP/TX'},
#  '329': {'cik_str': 1393612,
#   'ticker': 'DFS',
#   'title': 'Discover Financial Services'},
#  '330': {'cik_str': 788784,
#   'ticker': 'PEG',
#   'title': 'PUBLIC SERVICE ENTERPRISE GROUP INC'},
#  '331': {'cik_str': 1834584, 'ticker': 'CPNG', 'title': 'Coupang, Inc.'},
#  '332': {'cik_str': 1446250,
#   'ticker': 'BMWKY',
#   'title': 'Bayerische Motoren Werke AG/ADR'},
#  '333': {'cik_str': 16918,
#   'ticker': 'STZ',
#   'title': 'CONSTELLATION BRANDS, INC.'},
#  '334': {'cik_str': 1395064,
#   'ticker': 'TAK',
#   'title': 'TAKEDA PHARMACEUTICAL CO LTD'},
#  '335': {'cik_str': 1160106,
#   'ticker': 'LYG',
#   'title': 'Lloyds Banking Group plc'},
#  '336': {'cik_str': 1418135,
#   'ticker': 'KDP',
#   'title': 'Keurig Dr Pepper Inc.'},
#  '337': {'cik_str': 1279967,
#   'ticker': 'CRARY',
#   'title': 'CREDIT AGRICOLE S A'},
#  '338': {'cik_str': 1561550, 'ticker': 'DDOG', 'title': 'Datadog, Inc.'},
#  '339': {'cik_str': 1446598, 'ticker': 'DNZOY', 'title': 'Denso Corp'},
#  '340': {'cik_str': 1167379, 'ticker': 'ALC', 'title': 'ALCON INC'},
#  '341': {'cik_str': 1535628, 'ticker': 'CAIXY', 'title': 'CaixaBank/ADR'},
#  '342': {'cik_str': 712515, 'ticker': 'EA', 'title': 'ELECTRONIC ARTS INC.'},
#  '343': {'cik_str': 1900304, 'ticker': 'HLN', 'title': 'Haleon plc'},
#  '344': {'cik_str': 1389170,
#   'ticker': 'TRGP',
#   'title': 'Targa Resources Corp.'},
#  '345': {'cik_str': 917851, 'ticker': 'VALE', 'title': 'Vale S.A.'},
#  '346': {'cik_str': 1158838, 'ticker': 'ATEYY', 'title': 'ADVANTEST CORP'},
#  '347': {'cik_str': 1701605, 'ticker': 'BKR', 'title': 'Baker Hughes Co'},
#  '348': {'cik_str': 56873, 'ticker': 'KR', 'title': 'KROGER CO'},
#  '349': {'cik_str': 1640147, 'ticker': 'SNOW', 'title': 'Snowflake Inc.'},
#  '350': {'cik_str': 844150, 'ticker': 'NWG', 'title': 'NatWest Group plc'},
#  '351': {'cik_str': 27904, 'ticker': 'DAL', 'title': 'DELTA AIR LINES, INC.'},
#  '352': {'cik_str': 1699150, 'ticker': 'IR', 'title': 'Ingersoll Rand Inc.'},
#  '353': {'cik_str': 1359519,
#   'ticker': 'SVNDY',
#   'title': 'SEVEN & I HOLDINGS CO LTD'},
#  '354': {'cik_str': 749251, 'ticker': 'IT', 'title': 'GARTNER INC'},
#  '355': {'cik_str': 1121788, 'ticker': 'GRMN', 'title': 'GARMIN LTD'},
#  '356': {'cik_str': 715153, 'ticker': 'HMC', 'title': 'HONDA MOTOR CO LTD'},
#  '357': {'cik_str': 2011641,
#   'ticker': 'FERG',
#   'title': 'Ferguson Enterprises Inc. /DE/'},
#  '358': {'cik_str': 1138118, 'ticker': 'CBRE', 'title': 'CBRE GROUP, INC.'},
#  '359': {'cik_str': 24741, 'ticker': 'GLW', 'title': 'CORNING INC /NY'},
#  '360': {'cik_str': 72903, 'ticker': 'XEL', 'title': 'XCEL ENERGY INC'},
#  '361': {'cik_str': 1442145,
#   'ticker': 'VRSK',
#   'title': 'Verisk Analytics, Inc.'},
#  '362': {'cik_str': 1099800,
#   'ticker': 'EW',
#   'title': 'Edwards Lifesciences Corp'},
#  '363': {'cik_str': 1397187,
#   'ticker': 'LULU',
#   'title': 'lululemon athletica inc.'},
#  '364': {'cik_str': 1781335, 'ticker': 'OTIS', 'title': 'Otis Worldwide Corp'},
#  '365': {'cik_str': 1269238, 'ticker': 'TCOM', 'title': 'Trip.com Group Ltd'},
#  '366': {'cik_str': 1109357, 'ticker': 'EXC', 'title': 'EXELON CORP'},
#  '367': {'cik_str': 49938, 'ticker': 'IMO', 'title': 'IMPERIAL OIL LTD'},
#  '368': {'cik_str': 1545460,
#   'ticker': 'OLCLY',
#   'title': 'Oriental Land Co., Ltd./ADR'},
#  '369': {'cik_str': 2809, 'ticker': 'AEM', 'title': 'AGNICO EAGLE MINES LTD'},
#  '370': {'cik_str': 1058290,
#   'ticker': 'CTSH',
#   'title': 'COGNIZANT TECHNOLOGY SOLUTIONS CORP'},
#  '371': {'cik_str': 1605484, 'ticker': 'STLA', 'title': 'Stellantis N.V.'},
#  '372': {'cik_str': 1755672, 'ticker': 'CTVA', 'title': 'Corteva, Inc.'},
#  '373': {'cik_str': 947484,
#   'ticker': 'ACGL',
#   'title': 'ARCH CAPITAL GROUP LTD.'},
#  '374': {'cik_str': 1637459, 'ticker': 'KHC', 'title': 'Kraft Heinz Co'},
#  '375': {'cik_str': 861967,
#   'ticker': 'WTKWY',
#   'title': 'WOLTERS KLUWER N V /FI'},
#  '376': {'cik_str': 1041061, 'ticker': 'YUM', 'title': 'YUM BRANDS INC'},
#  '377': {'cik_str': 1461748,
#   'ticker': 'PPERY',
#   'title': 'PT Bank Mandiri (Persero) Tbk / ADR'},
#  '378': {'cik_str': 1932393,
#   'ticker': 'GEHC',
#   'title': 'GE HealthCare Technologies Inc.'},
#  '379': {'cik_str': 96021, 'ticker': 'SYY', 'title': 'SYSCO CORP'},
#  '380': {'cik_str': 1396009, 'ticker': 'VMC', 'title': 'Vulcan Materials CO'},
#  '381': {'cik_str': 1090872,
#   'ticker': 'A',
#   'title': 'AGILENT TECHNOLOGIES, INC.'},
#  '382': {'cik_str': 1289490,
#   'ticker': 'EXR',
#   'title': 'Extra Space Storage Inc.'},
#  '383': {'cik_str': 36270, 'ticker': 'MTB', 'title': 'M&T BANK CORP'},
#  '384': {'cik_str': 916076,
#   'ticker': 'MLM',
#   'title': 'MARTIN MARIETTA MATERIALS INC'},
#  '385': {'cik_str': 47217, 'ticker': 'HPQ', 'title': 'HP INC'},
#  '386': {'cik_str': 1041130,
#   'ticker': 'DIA',
#   'title': 'SPDR DOW JONES INDUSTRIAL AVERAGE ETF TRUST'},
#  '387': {'cik_str': 1123799, 'ticker': 'WIT', 'title': 'WIPRO LTD'},
#  '388': {'cik_str': 1650107,
#   'ticker': 'CCEP',
#   'title': 'COCA-COLA EUROPACIFIC PARTNERS plc'},
#  '389': {'cik_str': 1478242, 'ticker': 'IQV', 'title': 'IQVIA HOLDINGS INC.'},
#  '390': {'cik_str': 40704, 'ticker': 'GIS', 'title': 'GENERAL MILLS INC'},
#  '391': {'cik_str': 47111, 'ticker': 'HSY', 'title': 'HERSHEY CO'},
#  '392': {'cik_str': 1300514, 'ticker': 'LVS', 'title': 'LAS VEGAS SANDS CORP'},
#  '393': {'cik_str': 1446519,
#   'ticker': 'DKILY',
#   'title': 'Daikin Industries Ltd'},
#  '394': {'cik_str': 1404655, 'ticker': 'HUBS', 'title': 'HUBSPOT INC'},
#  '395': {'cik_str': 1393052, 'ticker': 'VEEV', 'title': 'VEEVA SYSTEMS INC'},
#  '396': {'cik_str': 1565025, 'ticker': 'ABEV', 'title': 'AMBEV S.A.'},
#  '397': {'cik_str': 1097362,
#   'ticker': 'SLF',
#   'title': 'SUN LIFE FINANCIAL INC'},
#  '398': {'cik_str': 73309, 'ticker': 'NUE', 'title': 'NUCOR CORP'},
#  '399': {'cik_str': 874716,
#   'ticker': 'IDXX',
#   'title': 'IDEXX LABORATORIES INC /DE'},
#  '400': {'cik_str': 943819, 'ticker': 'RMD', 'title': 'RESMED INC'},
#  '401': {'cik_str': 1697862, 'ticker': 'ARGX', 'title': 'ARGENX SE'},
#  '402': {'cik_str': 1666700,
#   'ticker': 'DD',
#   'title': 'DuPont de Nemours, Inc.'},
#  '403': {'cik_str': 874766,
#   'ticker': 'HIG',
#   'title': 'HARTFORD FINANCIAL SERVICES GROUP, INC.'},
#  '404': {'cik_str': 827054,
#   'ticker': 'MCHP',
#   'title': 'MICROCHIP TECHNOLOGY INC'},
#  '405': {'cik_str': 1315098, 'ticker': 'RBLX', 'title': 'Roblox Corp'},
#  '406': {'cik_str': 1020569, 'ticker': 'IRM', 'title': 'IRON MOUNTAIN INC'},
#  '407': {'cik_str': 943452,
#   'ticker': 'WAB',
#   'title': 'WESTINGHOUSE AIR BRAKE TECHNOLOGIES CORP'},
#  '408': {'cik_str': 1823945,
#   'ticker': 'OWL',
#   'title': 'BLUE OWL CAPITAL INC.'},
#  '409': {'cik_str': 1471055,
#   'ticker': 'BSBR',
#   'title': 'Banco Santander (Brasil) S.A.'},
#  '410': {'cik_str': 1047862,
#   'ticker': 'ED',
#   'title': 'CONSOLIDATED EDISON INC'},
#  '411': {'cik_str': 1705696,
#   'ticker': 'VICI',
#   'title': 'VICI PROPERTIES INC.'},
#  '412': {'cik_str': 49071, 'ticker': 'HUM', 'title': 'HUMANA INC'},
#  '413': {'cik_str': 1159508,
#   'ticker': 'DB',
#   'title': 'DEUTSCHE BANK AKTIENGESELLSCHAFT'},
#  '414': {'cik_str': 720005,
#   'ticker': 'RJF',
#   'title': 'RAYMOND JAMES FINANCIAL INC'},
#  '415': {'cik_str': 915912,
#   'ticker': 'AVB',
#   'title': 'AVALONBAY COMMUNITIES INC'},
#  '416': {'cik_str': 1024478,
#   'ticker': 'ROK',
#   'title': 'ROCKWELL AUTOMATION, INC'},
#  '417': {'cik_str': 815097, 'ticker': 'CCL', 'title': 'CARNIVAL CORP'},
#  '418': {'cik_str': 936958,
#   'ticker': 'MDY',
#   'title': 'SPDR S&P MIDCAP 400 ETF TRUST'},
#  '419': {'cik_str': 46619, 'ticker': 'HEI', 'title': 'HEICO CORP'},
#  '420': {'cik_str': 827052, 'ticker': 'EIX', 'title': 'EDISON INTERNATIONAL'},
#  '421': {'cik_str': 850918,
#   'ticker': 'GWLIF',
#   'title': 'GREAT-WEST LIFECO INC.'},
#  '422': {'cik_str': 65984, 'ticker': 'ETR', 'title': 'ENTERGY CORP /DE/'},
#  '423': {'cik_str': 1700171, 'ticker': 'ANYYY', 'title': 'Aena S.A./ADR'},
#  '424': {'cik_str': 35527, 'ticker': 'FITB', 'title': 'FIFTH THIRD BANCORP'},
#  '425': {'cik_str': 1140536,
#   'ticker': 'WTW',
#   'title': 'WILLIS TOWERS WATSON PLC'},
#  '426': {'cik_str': 79282, 'ticker': 'BRO', 'title': 'BROWN & BROWN, INC.'},
#  '427': {'cik_str': 915191,
#   'ticker': 'FRFHF',
#   'title': 'FAIRFAX FINANCIAL HOLDINGS LTD/ CAN'},
#  '428': {'cik_str': 1450468,
#   'ticker': 'MRAAY',
#   'title': 'Murata Manufacturing Co., Ltd./ADR'},
#  '429': {'cik_str': 946581,
#   'ticker': 'TTWO',
#   'title': 'TAKE TWO INTERACTIVE SOFTWARE INC'},
#  '430': {'cik_str': 1811074,
#   'ticker': 'TPL',
#   'title': 'Texas Pacific Land Corp'},
#  '431': {'cik_str': 1178670,
#   'ticker': 'ALNY',
#   'title': 'ALNYLAM PHARMACEUTICALS, INC.'},
#  '432': {'cik_str': 1751788, 'ticker': 'DOW', 'title': 'DOW INC.'},
#  '433': {'cik_str': 33185, 'ticker': 'EFX', 'title': 'EQUIFAX INC'},
#  '434': {'cik_str': 783325,
#   'ticker': 'WEC',
#   'title': 'WEC ENERGY GROUP, INC.'},
#  '435': {'cik_str': 1618756,
#   'ticker': 'QSR',
#   'title': 'Restaurant Brands International Inc.'},
#  '436': {'cik_str': 1713683, 'ticker': 'ZS', 'title': 'Zscaler, Inc.'},
#  '437': {'cik_str': 1477333, 'ticker': 'NET', 'title': 'Cloudflare, Inc.'},
#  '438': {'cik_str': 798941,
#   'ticker': 'FCNCA',
#   'title': 'FIRST CITIZENS BANCSHARES INC /DE/'},
#  '439': {'cik_str': 1093557, 'ticker': 'DXCM', 'title': 'DEXCOM INC'},
#  '440': {'cik_str': 100517,
#   'ticker': 'UAL',
#   'title': 'United Airlines Holdings, Inc.'},
#  '441': {'cik_str': 1335258,
#   'ticker': 'LYV',
#   'title': 'Live Nation Entertainment, Inc.'},
#  '442': {'cik_str': 1524472, 'ticker': 'XYL', 'title': 'Xylem Inc.'},
#  '443': {'cik_str': 916365,
#   'ticker': 'TSCO',
#   'title': 'TRACTOR SUPPLY CO /DE/'},
#  '444': {'cik_str': 1123360, 'ticker': 'GPN', 'title': 'GLOBAL PAYMENTS INC'},
#  '445': {'cik_str': 1132924,
#   'ticker': 'CHT',
#   'title': 'CHUNGHWA TELECOM CO LTD'},
#  '446': {'cik_str': 1057352, 'ticker': 'CSGP', 'title': 'COSTAR GROUP, INC.'},
#  '447': {'cik_str': 1329099, 'ticker': 'BIDU', 'title': 'Baidu, Inc.'},
#  '448': {'cik_str': 1065088, 'ticker': 'EBAY', 'title': 'EBAY INC'},
#  '449': {'cik_str': 756894, 'ticker': 'GOLD', 'title': 'BARRICK GOLD CORP'},
#  '450': {'cik_str': 844551,
#   'ticker': 'WDS',
#   'title': 'WOODSIDE ENERGY GROUP LTD'},
#  '451': {'cik_str': 1013462, 'ticker': 'ANSS', 'title': 'ANSYS INC'},
#  '452': {'cik_str': 1671750,
#   'ticker': 'DSCSY',
#   'title': 'Disco Corporation/ADR'},
#  '453': {'cik_str': 1071739, 'ticker': 'CNC', 'title': 'CENTENE CORP'},
#  '454': {'cik_str': 721371, 'ticker': 'CAH', 'title': 'CARDINAL HEALTH INC'},
#  '455': {'cik_str': 906107, 'ticker': 'EQR', 'title': 'EQUITY RESIDENTIAL'},
#  '456': {'cik_str': 1445465, 'ticker': 'PPRUY', 'title': 'Kering'},
#  '457': {'cik_str': 1475260, 'ticker': 'CVE', 'title': 'CENOVUS ENERGY INC.'},
#  '458': {'cik_str': 79879, 'ticker': 'PPG', 'title': 'PPG INDUSTRIES INC'},
#  '459': {'cik_str': 1758730, 'ticker': 'TW', 'title': 'Tradeweb Markets Inc.'},
#  '460': {'cik_str': 1783879,
#   'ticker': 'HOOD',
#   'title': 'Robinhood Markets, Inc.'},
#  '461': {'cik_str': 1690820, 'ticker': 'CVNA', 'title': 'CARVANA CO.'},
#  '462': {'cik_str': 1125259, 'ticker': 'CUK', 'title': 'CARNIVAL PLC'},
#  '463': {'cik_str': 55067, 'ticker': 'K', 'title': 'KELLANOVA'},
#  '464': {'cik_str': 93751, 'ticker': 'STT', 'title': 'STATE STREET CORP'},
#  '465': {'cik_str': 1468522, 'ticker': 'FER', 'title': 'Ferrovial SE'},
#  '466': {'cik_str': 906163, 'ticker': 'NVR', 'title': 'NVR INC'},
#  '467': {'cik_str': 29905, 'ticker': 'DOV', 'title': 'DOVER Corp'},
#  '468': {'cik_str': 1642896, 'ticker': 'IOT', 'title': 'Samsara Inc.'},
#  '469': {'cik_str': 1097864, 'ticker': 'ON', 'title': 'ON SEMICONDUCTOR CORP'},
#  '470': {'cik_str': 1021020,
#   'ticker': 'OEZVY',
#   'title': 'OSTERREICHISCHE ELEKTRIZITATSWIRTSCHAFTS /FI'},
#  '471': {'cik_str': 1280452,
#   'ticker': 'MPWR',
#   'title': 'MONOLITHIC POWER SYSTEMS INC'},
#  '472': {'cik_str': 1645590,
#   'ticker': 'HPE',
#   'title': 'Hewlett Packard Enterprise Co'},
#  '473': {'cik_str': 1805284,
#   'ticker': 'RKT',
#   'title': 'Rocket Companies, Inc.'},
#  '474': {'cik_str': 1489393,
#   'ticker': 'LYB',
#   'title': 'LyondellBasell Industries N.V.'},
#  '475': {'cik_str': 717826,
#   'ticker': 'ERIC',
#   'title': 'ERICSSON LM TELEPHONE CO'},
#  '476': {'cik_str': 1131345, 'ticker': 'NVZMY', 'title': 'NOVOZYMES AS/FI'},
#  '477': {'cik_str': 1323404,
#   'ticker': 'WPM',
#   'title': 'Wheaton Precious Metals Corp.'},
#  '478': {'cik_str': 740260, 'ticker': 'VTR', 'title': 'Ventas, Inc.'},
#  '479': {'cik_str': 313927,
#   'ticker': 'CHD',
#   'title': 'CHURCH & DWIGHT CO INC /DE/'},
#  '480': {'cik_str': 910521, 'ticker': 'DECK', 'title': 'DECKERS OUTDOOR CORP'},
#  '481': {'cik_str': 2005951, 'ticker': 'SW', 'title': 'Smurfit Westrock plc'},
#  '482': {'cik_str': 1383312,
#   'ticker': 'BR',
#   'title': 'BROADRIDGE FINANCIAL SOLUTIONS, INC.'},
#  '483': {'cik_str': 822416, 'ticker': 'PHM', 'title': 'PULTEGROUP INC/MI/'},
#  '484': {'cik_str': 1113169,
#   'ticker': 'TROW',
#   'title': 'PRICE T ROWE GROUP INC'},
#  '485': {'cik_str': 45012, 'ticker': 'HAL', 'title': 'HALLIBURTON CO'},
#  '486': {'cik_str': 1410636,
#   'ticker': 'AWK',
#   'title': 'American Water Works Company, Inc.'},
#  '487': {'cik_str': 1601046,
#   'ticker': 'KEYS',
#   'title': 'Keysight Technologies, Inc.'},
#  '488': {'cik_str': 1659166, 'ticker': 'FTV', 'title': 'Fortive Corp'},
#  '489': {'cik_str': 1050952, 'ticker': 'PUBGY', 'title': 'PUBLICIS GROUPE SA'},
#  '490': {'cik_str': 800365,
#   'ticker': 'FUJIY',
#   'title': 'FUJI PHOTO FILM CO LTD /FI'},
#  '491': {'cik_str': 7084,
#   'ticker': 'ADM',
#   'title': 'Archer-Daniels-Midland Co'},
#  '492': {'cik_str': 1609711, 'ticker': 'GDDY', 'title': 'GoDaddy Inc.'},
#  '493': {'cik_str': 1383650,
#   'ticker': 'CQP',
#   'title': 'Cheniere Energy Partners, L.P.'},
#  '494': {'cik_str': 860731,
#   'ticker': 'TYL',
#   'title': 'TYLER TECHNOLOGIES INC'},
#  '495': {'cik_str': 33213, 'ticker': 'EQT', 'title': 'EQT Corp'},
#  '496': {'cik_str': 49196,
#   'ticker': 'HBAN',
#   'title': 'HUNTINGTON BANCSHARES INC /MD/'},
#  '497': {'cik_str': 1175454, 'ticker': 'CPAY', 'title': 'CORPAY, INC.'},
#  '498': {'cik_str': 1967680, 'ticker': 'VLTO', 'title': 'Veralto Corp'},
#  '499': {'cik_str': 1601712, 'ticker': 'SYF', 'title': 'Synchrony Financial'},
#  '500': {'cik_str': 814052, 'ticker': 'TEF', 'title': 'TELEFONICA S A'},
#  '501': {'cik_str': 1446705, 'ticker': 'NTDTY', 'title': 'NTT Data Corp'},
#  '502': {'cik_str': 1090012, 'ticker': 'DVN', 'title': 'DEVON ENERGY CORP/DE'},
#  '503': {'cik_str': 1037646,
#   'ticker': 'MTD',
#   'title': 'METTLER TOLEDO INTERNATIONAL INC/'},
#  '504': {'cik_str': 1585521,
#   'ticker': 'ZM',
#   'title': 'Zoom Video Communications, Inc.'},
#  '505': {'cik_str': 922224, 'ticker': 'PPL', 'title': 'PPL Corp'},
#  '506': {'cik_str': 936340, 'ticker': 'DTE', 'title': 'DTE ENERGY CO'},
#  '507': {'cik_str': 718940, 'ticker': 'BCE', 'title': 'BCE INC'},
#  '508': {'cik_str': 1070304, 'ticker': 'IX', 'title': 'ORIX CORP'},
#  '509': {'cik_str': 1446596, 'ticker': 'FANUY', 'title': 'Fanuc Ltd'},
#  '510': {'cik_str': 313216,
#   'ticker': 'PHG',
#   'title': 'KONINKLIJKE PHILIPS NV'},
#  '511': {'cik_str': 1038683,
#   'ticker': 'RYAAY',
#   'title': 'RYANAIR HOLDINGS PLC'},
#  '512': {'cik_str': 1445930,
#   'ticker': 'KB',
#   'title': 'KB Financial Group Inc.'},
#  '513': {'cik_str': 1002910, 'ticker': 'AEE', 'title': 'AMEREN CORP'},
#  '514': {'cik_str': 1061574, 'ticker': 'GIB', 'title': 'CGI INC'},
#  '515': {'cik_str': 924613, 'ticker': 'NOK', 'title': 'NOKIA CORP'},
#  '516': {'cik_str': 84839, 'ticker': 'ROL', 'title': 'ROLLINS INC'},
#  '517': {'cik_str': 1809587, 'ticker': 'BEKE', 'title': 'KE Holdings Inc.'},
#  '518': {'cik_str': 1546066,
#   'ticker': 'PBA',
#   'title': 'PEMBINA PIPELINE CORP'},
#  '519': {'cik_str': 1002047, 'ticker': 'NTAP', 'title': 'NetApp, Inc.'},
#  '520': {'cik_str': 1160330, 'ticker': 'BBD', 'title': 'BANK BRADESCO'},
#  '521': {'cik_str': 1281761,
#   'ticker': 'RF',
#   'title': 'REGIONS FINANCIAL CORP'},
#  '522': {'cik_str': 1031296, 'ticker': 'FE', 'title': 'FIRSTENERGY CORP'},
#  '523': {'cik_str': 1791706, 'ticker': 'LI', 'title': 'Li Auto Inc.'},
#  '524': {'cik_str': 20286,
#   'ticker': 'CINF',
#   'title': 'CINCINNATI FINANCIAL CORP'},
#  '525': {'cik_str': 48898, 'ticker': 'HUBB', 'title': 'HUBBELL INC'},
#  '526': {'cik_str': 1034054,
#   'ticker': 'SBAC',
#   'title': 'SBA COMMUNICATIONS CORP'},
#  '527': {'cik_str': 1776985, 'ticker': 'BNTX', 'title': 'BioNTech SE'},
#  '528': {'cik_str': 1402057, 'ticker': 'CDW', 'title': 'CDW Corp'},
#  '529': {'cik_str': 1937926,
#   'ticker': 'BAM',
#   'title': 'Brookfield Asset Management Ltd.'},
#  '530': {'cik_str': 875045, 'ticker': 'BIIB', 'title': 'BIOGEN INC.'},
#  '531': {'cik_str': 1397911,
#   'ticker': 'LPLA',
#   'title': 'LPL Financial Holdings Inc.'},
#  '532': {'cik_str': 1880661, 'ticker': 'TPG', 'title': 'TPG Inc.'},
#  '533': {'cik_str': 1009001, 'ticker': 'CCJ', 'title': 'CAMECO CORP'},
#  '534': {'cik_str': 1764757, 'ticker': 'DIDIY', 'title': 'DiDi Global Inc.'},
#  '535': {'cik_str': 1650164, 'ticker': 'TOST', 'title': 'Toast, Inc.'},
#  '536': {'cik_str': 100493, 'ticker': 'TSN', 'title': 'TYSON FOODS, INC.'},
#  '537': {'cik_str': 1324424, 'ticker': 'EXPE', 'title': 'Expedia Group, Inc.'},
#  '538': {'cik_str': 105634, 'ticker': 'EME', 'title': 'EMCOR Group, Inc.'},
#  '539': {'cik_str': 886986, 'ticker': 'TECK', 'title': 'TECK RESOURCES LTD'},
#  '540': {'cik_str': 839923,
#   'ticker': 'VOD',
#   'title': 'VODAFONE GROUP PUBLIC LTD CO'},
#  '541': {'cik_str': 105770,
#   'ticker': 'WST',
#   'title': 'WEST PHARMACEUTICAL SERVICES INC'},
#  '542': {'cik_str': 11544, 'ticker': 'WRB', 'title': 'BERKLEY W R CORP'},
#  '543': {'cik_str': 1001250,
#   'ticker': 'EL',
#   'title': 'ESTEE LAUDER COMPANIES INC'},
#  '544': {'cik_str': 1725964, 'ticker': 'NTR', 'title': 'Nutrien Ltd.'},
#  '545': {'cik_str': 1709048, 'ticker': 'GFS', 'title': 'GLOBALFOUNDRIES Inc.'},
#  '546': {'cik_str': 1400691,
#   'ticker': 'HDELY',
#   'title': 'HeidelbergCement AG'},
#  '547': {'cik_str': 857005, 'ticker': 'PTC', 'title': 'PTC INC.'},
#  '548': {'cik_str': 868675, 'ticker': 'TU', 'title': 'TELUS CORP'},
#  '549': {'cik_str': 932787,
#   'ticker': 'STM',
#   'title': 'STMicroelectronics N.V.'},
#  '550': {'cik_str': 72741, 'ticker': 'ES', 'title': 'EVERSOURCE ENERGY'},
#  '551': {'cik_str': 1437107,
#   'ticker': 'WBD',
#   'title': 'Warner Bros. Discovery, Inc.'},
#  '552': {'cik_str': 731802, 'ticker': 'ATO', 'title': 'ATMOS ENERGY CORP'},
#  '553': {'cik_str': 106535, 'ticker': 'WY', 'title': 'WEYERHAEUSER CO'},
#  '554': {'cik_str': 1136869,
#   'ticker': 'ZBH',
#   'title': 'ZIMMER BIOMET HOLDINGS, INC.'},
#  '555': {'cik_str': 51253,
#   'ticker': 'IFF',
#   'title': 'INTERNATIONAL FLAVORS & FRAGRANCES INC'},
#  '556': {'cik_str': 1456346, 'ticker': 'FNV', 'title': 'FRANCO NEVADA Corp'},
#  '557': {'cik_str': 1666175, 'ticker': 'FTS', 'title': 'Fortis Inc.'},
#  '558': {'cik_str': 895126, 'ticker': 'EXE', 'title': 'EXPAND ENERGY Corp'},
#  '559': {'cik_str': 1094285,
#   'ticker': 'TDY',
#   'title': 'TELEDYNE TECHNOLOGIES INC'},
#  '560': {'cik_str': 1096343, 'ticker': 'MKL', 'title': 'MARKEL GROUP INC.'},
#  '561': {'cik_str': 1713445, 'ticker': 'RDDT', 'title': 'Reddit, Inc.'},
#  '562': {'cik_str': 1757898, 'ticker': 'STE', 'title': 'STERIS plc'},
#  '563': {'cik_str': 1069202,
#   'ticker': 'LII',
#   'title': 'LENNOX INTERNATIONAL INC'},
#  '564': {'cik_str': 1985487,
#   'ticker': 'KSPI',
#   'title': 'Joint Stock Co Kaspi.kz'},
#  '565': {'cik_str': 1336920,
#   'ticker': 'LDOS',
#   'title': 'Leidos Holdings, Inc.'},
#  '566': {'cik_str': 106040, 'ticker': 'WDC', 'title': 'WESTERN DIGITAL CORP'},
#  '567': {'cik_str': 1110803, 'ticker': 'ILMN', 'title': 'ILLUMINA, INC.'},
#  '568': {'cik_str': 1116578, 'ticker': 'PUK', 'title': 'PRUDENTIAL PLC'},
#  '569': {'cik_str': 1000697, 'ticker': 'WAT', 'title': 'WATERS CORP /DE/'},
#  '570': {'cik_str': 1669414,
#   'ticker': 'SMPNY',
#   'title': 'Sompo Japan Nipponkoa Holdings, Inc./ADR'},
#  '571': {'cik_str': 73124, 'ticker': 'NTRS', 'title': 'NORTHERN TRUST CORP'},
#  '572': {'cik_str': 1093028,
#   'ticker': 'EJPRY',
#   'title': 'EAST JAPAN RAILWAY CO /FI'},
#  '573': {'cik_str': 1022671, 'ticker': 'STLD', 'title': 'STEEL DYNAMICS INC'},
#  '574': {'cik_str': 75677,
#   'ticker': 'PKG',
#   'title': 'PACKAGING CORP OF AMERICA'},
#  '575': {'cik_str': 922621, 'ticker': 'ERIE', 'title': 'ERIE INDEMNITY CO'},
#  '576': {'cik_str': 1374310,
#   'ticker': 'CBOE',
#   'title': 'Cboe Global Markets, Inc.'},
#  '577': {'cik_str': 1651308, 'ticker': 'BGNE', 'title': 'BeiGene, Ltd.'},
#  '578': {'cik_str': 105016, 'ticker': 'WSO', 'title': 'WATSCO INC'},
#  '579': {'cik_str': 21076, 'ticker': 'CLX', 'title': 'CLOROX CO /DE/'},
#  '580': {'cik_str': 1122411,
#   'ticker': 'ASX',
#   'title': 'ASE Technology Holding Co., Ltd.'},
#  '581': {'cik_str': 1158967, 'ticker': 'NJDCY', 'title': 'NIDEC CORP'},
#  '582': {'cik_str': 1417663,
#   'ticker': 'SNWV',
#   'title': 'SANUWAVE Health, Inc.'},
#  '583': {'cik_str': 1687229,
#   'ticker': 'INVH',
#   'title': 'Invitation Homes Inc.'},
#  '584': {'cik_str': 1274494, 'ticker': 'FSLR', 'title': 'FIRST SOLAR, INC.'},
#  '585': {'cik_str': 1190723, 'ticker': 'TS', 'title': 'TENARIS SA'},
#  '586': {'cik_str': 1511737, 'ticker': 'UI', 'title': 'Ubiquiti Inc.'},
#  '587': {'cik_str': 759944,
#   'ticker': 'CFG',
#   'title': 'CITIZENS FINANCIAL GROUP INC/RI'},
#  '588': {'cik_str': 1137789,
#   'ticker': 'STX',
#   'title': 'Seagate Technology Holdings plc'},
#  '589': {'cik_str': 811156, 'ticker': 'CMS', 'title': 'CMS ENERGY CORP'},
#  '590': {'cik_str': 1441816, 'ticker': 'MDB', 'title': 'MongoDB, Inc.'},
#  '591': {'cik_str': 1316835,
#   'ticker': 'BLDR',
#   'title': 'Builders FirstSource, Inc.'},
#  '592': {'cik_str': 790051,
#   'ticker': 'CSL',
#   'title': 'CARLISLE COMPANIES INC'},
#  '593': {'cik_str': 1754301, 'ticker': 'FOXA', 'title': 'Fox Corp'},
#  '594': {'cik_str': 1334687,
#   'ticker': 'CJPRY',
#   'title': 'CENTRAL JAPAN RAILWAY CO'},
#  '595': {'cik_str': 920522,
#   'ticker': 'ESS',
#   'title': 'ESSEX PROPERTY TRUST, INC.'},
#  '596': {'cik_str': 63754, 'ticker': 'MKC', 'title': 'MCCORMICK & CO INC'},
#  '597': {'cik_str': 764478, 'ticker': 'BBY', 'title': 'BEST BUY CO INC'},
#  '598': {'cik_str': 877212,
#   'ticker': 'ZBRA',
#   'title': 'ZEBRA TECHNOLOGIES CORP'},
#  '599': {'cik_str': 711404,
#   'ticker': 'COO',
#   'title': 'COOPER COMPANIES, INC.'},
#  '600': {'cik_str': 1130310,
#   'ticker': 'CNP',
#   'title': 'CENTERPOINT ENERGY INC'},
# ...
#  '806': {'cik_str': 1294591,
#   'ticker': 'RKUNY',
#   'title': 'Rakuten Group, Inc.'},
#  '807': {'cik_str': 1037976,
#   'ticker': 'JLL',
#   'title': 'JONES LANG LASALLE INC'},
#  '808': {'cik_str': 1810997, 'ticker': 'XPEV', 'title': 'XPENG INC.'},
#  '809': {'cik_str': 216228, 'ticker': 'ITT', 'title': 'ITT INC.'},
#  '810': {'cik_str': 1910139,
#   'ticker': 'MBLY',
#   'title': 'Mobileye Global Inc.'},
#  '811': {'cik_str': 1070750,
#   'ticker': 'HST',
#   'title': 'HOST HOTELS & RESORTS, INC.'},
#  '812': {'cik_str': 802481, 'ticker': 'PPC', 'title': 'PILGRIMS PRIDE CORP'},
#  '813': {'cik_str': 1172724, 'ticker': 'GFI', 'title': 'GOLD FIELDS LTD'},
#  '814': {'cik_str': 1043604,
#   'ticker': 'JNPR',
#   'title': 'JUNIPER NETWORKS INC'},
#  '815': {'cik_str': 1517231,
#   'ticker': 'SSMXY',
#   'title': 'Sysmex Corporation/ADR'},
#  '816': {'cik_str': 1025378, 'ticker': 'WPC', 'title': 'W. P. Carey Inc.'},
#  '817': {'cik_str': 1754581, 'ticker': 'FUTU', 'title': 'Futu Holdings Ltd'},
#  '818': {'cik_str': 1588823,
#   'ticker': 'TFII',
#   'title': 'TFI International Inc.'},
#  '819': {'cik_str': 1579241, 'ticker': 'ALLE', 'title': 'Allegion plc'},
#  '820': {'cik_str': 1070423,
#   'ticker': 'PAA',
#   'title': 'PLAINS ALL AMERICAN PIPELINE LP'},
#  '821': {'cik_str': 1504122,
#   'ticker': 'PTBRY',
#   'title': 'PT Bank Negara Indonesia (Persero) Tbk/ADR'},
#  '822': {'cik_str': 1048477,
#   'ticker': 'BMRN',
#   'title': 'BIOMARIN PHARMACEUTICAL INC'},
#  '823': {'cik_str': 1326380, 'ticker': 'GME', 'title': 'GameStop Corp.'},
#  '824': {'cik_str': 89089,
#   'ticker': 'SCI',
#   'title': 'SERVICE CORP INTERNATIONAL'},
#  '825': {'cik_str': 1170010, 'ticker': 'KMX', 'title': 'CARMAX INC'},
#  '826': {'cik_str': 915913, 'ticker': 'ALB', 'title': 'ALBEMARLE CORP'},
#  '827': {'cik_str': 1135951,
#   'ticker': 'RDY',
#   'title': 'DR REDDYS LABORATORIES LTD'},
#  '828': {'cik_str': 1600520,
#   'ticker': 'JPXGY',
#   'title': 'Japan Exchange Group, Inc./ADR'},
#  '829': {'cik_str': 1720635, 'ticker': 'NVT', 'title': 'nVent Electric plc'},
#  '830': {'cik_str': 914475,
#   'ticker': 'NBIX',
#   'title': 'NEUROCRINE BIOSCIENCES INC'},
#  '831': {'cik_str': 1681459, 'ticker': 'FTI', 'title': 'TechnipFMC plc'},
#  '832': {'cik_str': 1658566,
#   'ticker': 'PR',
#   'title': 'Permian Resources Corp'},
#  '833': {'cik_str': 1032975,
#   'ticker': 'LOGI',
#   'title': 'LOGITECH INTERNATIONAL S.A.'},
#  '834': {'cik_str': 1104506, 'ticker': 'INSM', 'title': 'INSMED Inc'},
#  '835': {'cik_str': 1725057, 'ticker': 'DAY', 'title': 'Dayforce, Inc.'},
#  '836': {'cik_str': 915389, 'ticker': 'EMN', 'title': 'EASTMAN CHEMICAL CO'},
#  '837': {'cik_str': 1281721, 'ticker': 'SGIOY', 'title': 'SHIONOGI & CO LTD'},
#  '838': {'cik_str': 720672, 'ticker': 'SF', 'title': 'STIFEL FINANCIAL CORP'},
#  '839': {'cik_str': 1531152,
#   'ticker': 'BJ',
#   'title': "BJ's Wholesale Club Holdings, Inc."},
#  '840': {'cik_str': 1964738, 'ticker': 'SOLV', 'title': 'Solventum Corp'},
#  '841': {'cik_str': 59527,
#   'ticker': 'LECO',
#   'title': 'LINCOLN ELECTRIC HOLDINGS INC'},
#  '842': {'cik_str': 4457, 'ticker': 'UHAL', 'title': 'U-Haul Holding Co /NV/'},
#  '843': {'cik_str': 1161125, 'ticker': 'BCH', 'title': 'BANK OF CHILE'},
#  '844': {'cik_str': 1513761,
#   'ticker': 'NCLH',
#   'title': 'Norwegian Cruise Line Holdings Ltd.'},
#  '845': {'cik_str': 1042046,
#   'ticker': 'AFG',
#   'title': 'AMERICAN FINANCIAL GROUP INC'},
#  '846': {'cik_str': 1170858,
#   'ticker': 'SBS',
#   'title': 'COMPANHIA DE SANEAMENTO BASICO DO ESTADO DE SAO PAULO-SABESP'},
#  '847': {'cik_str': 1486957,
#   'ticker': 'BWXT',
#   'title': 'BWX Technologies, Inc.'},
#  '848': {'cik_str': 1446444,
#   'ticker': 'TKHVY',
#   'title': 'Turk Hava Yollari A.O.'},
#  '849': {'cik_str': 1675149, 'ticker': 'AA', 'title': 'Alcoa Corp'},
#  '850': {'cik_str': 1450346,
#   'ticker': 'POAHY',
#   'title': 'Porsche Automobil Holding SE / ADR'},
#  '851': {'cik_str': 353991,
#   'ticker': 'NDEKY',
#   'title': 'NITTO DENKO CORP / ADR/'},
#  '852': {'cik_str': 91419, 'ticker': 'SJM', 'title': 'J M SMUCKER Co'},
#  '853': {'cik_str': 701818, 'ticker': 'KGC', 'title': 'KINROSS GOLD CORP'},
#  '854': {'cik_str': 1360901, 'ticker': 'EVR', 'title': 'Evercore Inc.'},
#  '855': {'cik_str': 1792580, 'ticker': 'OVV', 'title': 'Ovintiv Inc.'},
#  '856': {'cik_str': 38777, 'ticker': 'BEN', 'title': 'FRANKLIN RESOURCES INC'},
#  '857': {'cik_str': 896622, 'ticker': 'ATR', 'title': 'APTARGROUP, INC.'},
#  '858': {'cik_str': 82811, 'ticker': 'RRX', 'title': 'REGAL REXNORD CORP'},
#  '859': {'cik_str': 1483994, 'ticker': 'HTHT', 'title': 'H World Group Ltd'},
#  '860': {'cik_str': 1267238, 'ticker': 'AIZ', 'title': 'ASSURANT, INC.'},
#  '861': {'cik_str': 888491,
#   'ticker': 'OHI',
#   'title': 'OMEGA HEALTHCARE INVESTORS INC'},
#  '862': {'cik_str': 789570,
#   'ticker': 'MGM',
#   'title': 'MGM Resorts International'},
#  '863': {'cik_str': 1591698,
#   'ticker': 'PCTY',
#   'title': 'Paylocity Holding Corp'},
#  '864': {'cik_str': 806968, 'ticker': 'WPP', 'title': 'WPP plc'},
#  '865': {'cik_str': 40729, 'ticker': 'ALLY', 'title': 'Ally Financial Inc.'},
#  '866': {'cik_str': 1237831, 'ticker': 'GMED', 'title': 'GLOBUS MEDICAL INC'},
#  '867': {'cik_str': 1043219,
#   'ticker': 'NLY',
#   'title': 'ANNALY CAPITAL MANAGEMENT INC'},
#  '868': {'cik_str': 1646972,
#   'ticker': 'ACI',
#   'title': 'Albertsons Companies, Inc.'},
#  '869': {'cik_str': 1298675, 'ticker': 'CUBE', 'title': 'CubeSmart'},
#  '870': {'cik_str': 1507079,
#   'ticker': 'FND',
#   'title': 'Floor & Decor Holdings, Inc.'},
#  '871': {'cik_str': 831641, 'ticker': 'TTEK', 'title': 'TETRA TECH INC'},
#  '872': {'cik_str': 1679273,
#   'ticker': 'LW',
#   'title': 'Lamb Weston Holdings, Inc.'},
#  '873': {'cik_str': 1468608,
#   'ticker': 'VDMCY',
#   'title': 'Vodacom Group Ltd / ADR'},
#  '874': {'cik_str': 1495153, 'ticker': 'MMYT', 'title': 'MakeMyTrip Ltd'},
#  '875': {'cik_str': 1062066, 'ticker': 'ALSMY', 'title': 'ALSTOM'},
#  '876': {'cik_str': 1446656, 'ticker': 'KIKOY', 'title': 'Kikkoman Corp'},
#  '877': {'cik_str': 1003935, 'ticker': 'NICE', 'title': 'NICE Ltd.'},
#  '878': {'cik_str': 1669162,
#   'ticker': 'KNSL',
#   'title': 'Kinsale Capital Group, Inc.'},
#  '879': {'cik_str': 845982, 'ticker': 'SNN', 'title': 'SMITH & NEPHEW PLC'},
#  '880': {'cik_str': 842023, 'ticker': 'TECH', 'title': 'BIO-TECHNE Corp'},
#  '881': {'cik_str': 1596783, 'ticker': 'CTLT', 'title': 'Catalent, Inc.'},
#  '882': {'cik_str': 1649094, 'ticker': 'PCVX', 'title': 'Vaxcyte, Inc.'},
#  '883': {'cik_str': 1019849,
#   'ticker': 'PAG',
#   'title': 'PENSKE AUTOMOTIVE GROUP, INC.'},
#  '884': {'cik_str': 1219601, 'ticker': 'CCK', 'title': 'CROWN HOLDINGS, INC.'},
#  '885': {'cik_str': 1474735,
#   'ticker': 'GNRC',
#   'title': 'GENERAC HOLDINGS INC.'},
#  '886': {'cik_str': 36966, 'ticker': 'FHN', 'title': 'FIRST HORIZON CORP'},
#  '887': {'cik_str': 1573516, 'ticker': 'MUSA', 'title': 'Murphy USA Inc.'},
#  '888': {'cik_str': 15615, 'ticker': 'MTZ', 'title': 'MASTEC INC'},
#  '889': {'cik_str': 1579091, 'ticker': 'CART', 'title': 'Maplebear Inc.'},
#  '890': {'cik_str': 824142, 'ticker': 'AAON', 'title': 'AAON, INC.'},
#  '891': {'cik_str': 909037,
#   'ticker': 'SQM',
#   'title': 'CHEMICAL & MINING CO OF CHILE INC'},
#  '892': {'cik_str': 1433642, 'ticker': 'HLNE', 'title': 'Hamilton Lane INC'},
#  '893': {'cik_str': 1555812,
#   'ticker': 'SMKUY',
#   'title': 'Siam Makro Public Co Limited/ADR'},
#  '894': {'cik_str': 78128,
#   'ticker': 'WTRG',
#   'title': 'Essential Utilities, Inc.'},
#  '895': {'cik_str': 769218, 'ticker': 'AEG', 'title': 'AEGON LTD.'},
#  '896': {'cik_str': 1127248, 'ticker': 'EMRAF', 'title': 'EMERA INC'},
#  '897': {'cik_str': 1027664, 'ticker': 'ESLT', 'title': 'ELBIT SYSTEMS LTD'},
#  '898': {'cik_str': 91142, 'ticker': 'AOS', 'title': 'SMITH A O CORP'},
#  '899': {'cik_str': 317540,
#   'ticker': 'COKE',
#   'title': 'Coca-Cola Consolidated, Inc.'},
#  '900': {'cik_str': 1545772,
#   'ticker': 'BPYPP',
#   'title': 'Brookfield Property Partners L.P.'},
#  '901': {'cik_str': 871464,
#   'ticker': 'HNGKY',
#   'title': 'HONGKONG LAND HOLDINGS LTD /FI'},
#  '902': {'cik_str': 887225,
#   'ticker': 'KEP',
#   'title': 'KOREA ELECTRIC POWER CORP'},
#  '903': {'cik_str': 16058,
#   'ticker': 'CACI',
#   'title': 'CACI INTERNATIONAL INC /DE/'},
#  '904': {'cik_str': 764622,
#   'ticker': 'PNW',
#   'title': 'PINNACLE WEST CAPITAL CORP'},
#  '905': {'cik_str': 1375365,
#   'ticker': 'SMCI',
#   'title': 'Super Micro Computer, Inc.'},
#  '906': {'cik_str': 350894, 'ticker': 'SEIC', 'title': 'SEI INVESTMENTS CO'},
#  '907': {'cik_str': 1611052,
#   'ticker': 'PCOR',
#   'title': 'PROCORE TECHNOLOGIES, INC.'},
#  '908': {'cik_str': 109563,
#   'ticker': 'AIT',
#   'title': 'APPLIED INDUSTRIAL TECHNOLOGIES INC'},
#  '909': {'cik_str': 275880, 'ticker': 'PSN', 'title': 'PARSONS CORP'},
#  '910': {'cik_str': 1633931, 'ticker': 'BLD', 'title': 'TopBuild Corp'},
#  '911': {'cik_str': 20212, 'ticker': 'CHDN', 'title': 'Churchill Downs Inc'},
#  '912': {'cik_str': 1622536, 'ticker': 'TLN', 'title': 'Talen Energy Corp'},
#  '913': {'cik_str': 108312, 'ticker': 'WWD', 'title': 'Woodward, Inc.'},
#  '914': {'cik_str': 801337,
#   'ticker': 'WBS',
#   'title': 'WEBSTER FINANCIAL CORP'},
#  '915': {'cik_str': 51644,
#   'ticker': 'IPG',
#   'title': 'INTERPUBLIC GROUP OF COMPANIES, INC.'},
#  '916': {'cik_str': 1078642, 'ticker': 'CRRFY', 'title': 'CARREFOUR SA'},
#  '917': {'cik_str': 1604028,
#   'ticker': 'WMS',
#   'title': 'ADVANCED DRAINAGE SYSTEMS, INC.'},
#  '918': {'cik_str': 1144215, 'ticker': 'AYI', 'title': 'ACUITY BRANDS INC'},
#  '919': {'cik_str': 89439, 'ticker': 'MLI', 'title': 'MUELLER INDUSTRIES INC'},
#  '920': {'cik_str': 1428439, 'ticker': 'ROKU', 'title': 'ROKU, INC'},
#  '921': {'cik_str': 918646, 'ticker': 'EXP', 'title': 'EAGLE MATERIALS INC'},
#  '922': {'cik_str': 785161, 'ticker': 'EHC', 'title': 'Encompass Health Corp'},
#  '923': {'cik_str': 1874178,
#   'ticker': 'RIVN',
#   'title': 'Rivian Automotive, Inc. / DE'},
#  '924': {'cik_str': 1411207,
#   'ticker': 'ALSN',
#   'title': 'Allison Transmission Holdings Inc'},
#  '925': {'cik_str': 1783398, 'ticker': 'UWMC', 'title': 'UWM Holdings Corp'},
#  '926': {'cik_str': 1973832, 'ticker': 'AU', 'title': 'AngloGold Ashanti PLC'},
#  '927': {'cik_str': 938323, 'ticker': 'PSO', 'title': 'PEARSON PLC'},
#  '928': {'cik_str': 1541309,
#   'ticker': 'CSXXY',
#   'title': 'carsales.com Limited/ADR'},
#  '929': {'cik_str': 1065696, 'ticker': 'LKQ', 'title': 'LKQ CORP'},
#  '930': {'cik_str': 929008,
#   'ticker': 'WCC',
#   'title': 'WESCO INTERNATIONAL INC'},
#  '931': {'cik_str': 1901440, 'ticker': 'ULS', 'title': 'UL Solutions Inc.'},
#  '932': {'cik_str': 1023128, 'ticker': 'LAD', 'title': 'LITHIA MOTORS INC'},
#  '933': {'cik_str': 1944013, 'ticker': 'CR', 'title': 'Crane Co'},
#  '934': {'cik_str': 939767, 'ticker': 'EXEL', 'title': 'EXELIXIS, INC.'},
#  '935': {'cik_str': 1584509, 'ticker': 'ARMK', 'title': 'Aramark'},
#  '936': {'cik_str': 1475922, 'ticker': 'PRI', 'title': 'Primerica, Inc.'},
#  '937': {'cik_str': 1174922, 'ticker': 'WYNN', 'title': 'WYNN RESORTS LTD'},
#  '938': {'cik_str': 1212545,
#   'ticker': 'WAL',
#   'title': 'WESTERN ALLIANCE BANCORPORATION'},
#  '939': {'cik_str': 873303,
#   'ticker': 'SRPT',
#   'title': 'Sarepta Therapeutics, Inc.'},
#  '940': {'cik_str': 1576789, 'ticker': 'WIX', 'title': 'Wix.com Ltd.'},
#  '941': {'cik_str': 1278021,
#   'ticker': 'MKTX',
#   'title': 'MARKETAXESS HOLDINGS INC'},
#  '942': {'cik_str': 874761, 'ticker': 'AES', 'title': 'AES CORP'},
#  '943': {'cik_str': 1447126,
#   'ticker': 'KAIKY',
#   'title': 'Kawasaki Kisen Kaisha Ltd'},
#  '944': {'cik_str': 1668397,
#   'ticker': 'MEDP',
#   'title': 'Medpace Holdings, Inc.'},
#  '945': {'cik_str': 1324948, 'ticker': 'RBC', 'title': 'RBC Bearings INC'},
#  '946': {'cik_str': 1988894, 'ticker': 'AS', 'title': 'Amer Sports, Inc.'},
#  '947': {'cik_str': 1177394, 'ticker': 'SNX', 'title': 'TD SYNNEX CORP'},
#  '948': {'cik_str': 1842022, 'ticker': 'DTM', 'title': 'DT Midstream, Inc.'},
#  '949': {'cik_str': 1796209, 'ticker': 'APG', 'title': 'APi Group Corp'},
#  '950': {'cik_str': 34903,
#   'ticker': 'FRT',
#   'title': 'FEDERAL REALTY INVESTMENT TRUST'},
#  '951': {'cik_str': 936395, 'ticker': 'CIEN', 'title': 'CIENA CORP'},
#  '952': {'cik_str': 1062579, 'ticker': 'DOX', 'title': 'AMDOCS LTD'},
#  '953': {'cik_str': 1571283,
#   'ticker': 'REXR',
#   'title': 'Rexford Industrial Realty, Inc.'},
#  '954': {'cik_str': 1100682,
#   'ticker': 'CRL',
#   'title': 'CHARLES RIVER LABORATORIES INTERNATIONAL, INC.'},
#  '955': {'cik_str': 1973266,
#   'ticker': 'TKO',
#   'title': 'TKO Group Holdings, Inc.'},
#  '956': {'cik_str': 1602065, 'ticker': 'VNOM', 'title': 'Viper Energy, Inc.'},
#  '957': {'cik_str': 1835830, 'ticker': 'KVYO', 'title': 'Klaviyo, Inc.'},
#  '958': {'cik_str': 1050140,
#   'ticker': 'DSGX',
#   'title': 'DESCARTES SYSTEMS GROUP INC'},
#  '959': {'cik_str': 1115055,
#   'ticker': 'PNFP',
#   'title': 'PINNACLE FINANCIAL PARTNERS INC'},
#  '960': {'cik_str': 1653482, 'ticker': 'GTLB', 'title': 'Gitlab Inc.'},
#  '961': {'cik_str': 1030894, 'ticker': 'CLS', 'title': 'CELESTICA INC'},
#  '962': {'cik_str': 1736541, 'ticker': 'NIO', 'title': 'NIO Inc.'},
#  '963': {'cik_str': 74260,
#   'ticker': 'ORI',
#   'title': 'OLD REPUBLIC INTERNATIONAL CORP'},
#  '964': {'cik_str': 1206264,
#   'ticker': 'TPX',
#   'title': 'TEMPUR SEALY INTERNATIONAL, INC.'},
#  '965': {'cik_str': 1131383, 'ticker': 'STN', 'title': 'STANTEC INC'},
#  '966': {'cik_str': 1433270, 'ticker': 'AR', 'title': 'ANTERO RESOURCES Corp'},
#  '967': {'cik_str': 1330568, 'ticker': 'SLV', 'title': 'iShares Silver Trust'},
#  '968': {'cik_str': 1438654,
#   'ticker': 'RDEIY',
#   'title': 'Red Electrica Corporacion SA/ADR'},
#  '969': {'cik_str': 1481045,
#   'ticker': 'DSEEY',
#   'title': 'Daiwa Securities Group Inc.'},
#  '970': {'cik_str': 1819994,
#   'ticker': 'RKLB',
#   'title': 'Rocket Lab USA, Inc.'},
#  '971': {'cik_str': 6201,
#   'ticker': 'AAL',
#   'title': 'American Airlines Group Inc.'},
#  '972': {'cik_str': 1772016,
#   'ticker': 'BRBR',
#   'title': 'BELLRING BRANDS, INC.'},
#  '973': {'cik_str': 1440130,
#   'ticker': 'UUGRY',
#   'title': 'United Utilities Group plc'},
#  '974': {'cik_str': 2025410, 'ticker': 'SARO', 'title': 'StandardAero, Inc.'},
#  '975': {'cik_str': 1628171,
#   'ticker': 'RVMD',
#   'title': 'Revolution Medicines, Inc.'},
#  '976': {'cik_str': 1636222, 'ticker': 'WING', 'title': 'Wingstop Inc.'},
#  '977': {'cik_str': 85535, 'ticker': 'RGLD', 'title': 'ROYAL GOLD INC'},
#  '978': {'cik_str': 1519751,
#   'ticker': 'FBIN',
#   'title': 'Fortune Brands Innovations, Inc.'},
#  '979': {'cik_str': 1516513, 'ticker': 'DOCS', 'title': 'Doximity, Inc.'},
#  '980': {'cik_str': 1046257, 'ticker': 'INGR', 'title': 'Ingredion Inc'},
#  '981': {'cik_str': 1124140, 'ticker': 'EXAS', 'title': 'EXACT SCIENCES CORP'},
#  '982': {'cik_str': 29644, 'ticker': 'DCI', 'title': 'DONALDSON Co INC'},
#  '983': {'cik_str': 22356,
#   'ticker': 'CBSH',
#   'title': 'COMMERCE BANCSHARES INC /MO/'},
#  '984': {'cik_str': 1065837, 'ticker': 'SKX', 'title': 'SKECHERS USA INC'},
#  '985': {'cik_str': 1321732, 'ticker': 'PEN', 'title': 'Penumbra Inc'},
#  '986': {'cik_str': 320335, 'ticker': 'GL', 'title': 'GLOBE LIFE INC.'},
#  '987': {'cik_str': 1015820, 'ticker': 'QGEN', 'title': 'QIAGEN N.V.'},
#  '988': {'cik_str': 1372920,
#   'ticker': 'EDU',
#   'title': 'New Oriental Education & Technology Group Inc.'},
#  '989': {'cik_str': 28412, 'ticker': 'CMA', 'title': 'COMERICA INC /NEW/'},
#  '990': {'cik_str': 1027552,
#   'ticker': 'BSAC',
#   'title': 'BANCO SANTANDER CHILE'},
#  '991': {'cik_str': 1913510, 'ticker': 'VFS', 'title': 'VinFast Auto Ltd.'},
#  '992': {'cik_str': 12208,
#   'ticker': 'BIO',
#   'title': 'BIO-RAD LABORATORIES, INC.'},
#  '993': {'cik_str': 1492691,
#   'ticker': 'KNX',
#   'title': 'Knight-Swift Transportation Holdings Inc.'},
#  '994': {'cik_str': 1124198, 'ticker': 'FLR', 'title': 'FLUOR CORP'},
#  '995': {'cik_str': 1380365,
#   'ticker': 'IDKOY',
#   'title': 'IDEMITSU KOSAN CO., LTD'},
#  '996': {'cik_str': 1766363,
#   'ticker': 'EDR',
#   'title': 'Endeavor Group Holdings, Inc.'},
#  '997': {'cik_str': 1833756, 'ticker': 'DRS', 'title': 'Leonardo DRS, Inc.'},
#  '998': {'cik_str': 1493594,
#   'ticker': 'MTSI',
#   'title': 'MACOM Technology Solutions Holdings, Inc.'},
#  '999': {'cik_str': 1567514,
#   'ticker': 'ITCI',
#   'title': 'Intra-Cellular Therapies, Inc.'},
#  ...}

# %%
len(company_tickers)
# Out:
# 9998

# %%
company_tickers = dict(list(company_tickers.items())[:100])

# %%
len(company_tickers)
# Out:
# 100

# %% [markdown]
# # Inserting Stocks into Pinecone
#
# **1. Create an account on [Pinecone.io](https://app.pinecone.io/)**
#
# **2. Create a new index called "stocks" and set the dimensions to 768. Leave the rest of the settings as they are.**
#
# ![Screenshot 2024-12-02 at 4 48 03 PM](https://github.com/user-attachments/assets/13b484da-cd00-4337-a4db-4779080eb42c)
#
#
# **3. Create an API Key for Pinecone**
#
# ![Screenshot 2024-11-24 at 10 44 37 PM](https://github.com/user-attachments/assets/e7feacc6-2bd1-472a-82e5-659f65624a88)
#
#
# **4. Store your Pinecone API Key within Google Colab's secrets section, and then enable access to it (see the blue checkmark)**
#
#
# ![Screenshot 2024-11-24 at 10 45 25 PM](https://github.com/user-attachments/assets/eaf73083-0b5f-4d17-9e0c-eab84f91b0bc)

# %%
pinecone_api_key = userdata.get("PINECONE_API_KEY")
os.environ['PINECONE_API_KEY'] = pinecone_api_key

index_name = "stocks"
namespace = "stock-descriptions"

hf_embeddings = HuggingFaceEmbeddings()
vectorstore = PineconeVectorStore(index_name=index_name, embedding=hf_embeddings)
# Out:
# <ipython-input-13-8d5c0f356cf6>:7: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   hf_embeddings = HuggingFaceEmbeddings()
# <ipython-input-13-8d5c0f356cf6>:7: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   hf_embeddings = HuggingFaceEmbeddings()

# %% [markdown]
# # Sequential Processing
#
# It will take very long to process all the stocks like this!

# %% [markdown]
# [![](https://mermaid.ink/img/pako:eNqNkl1rgzAUhv9KyMXYwF74cSVjYA0rhY6WKRQWe5FqWqU1cUm8GKX_ffmwa65Gc6Hn5LxvzmM8F1jzhsIUHgUZWlCiigG9MlwoXp_AqpPqdS_esmyzCsBivV7o10fxXgagLFbZDsxmb2COi44dzxRsBK-plDoBZSsoaXbuNPeU4941qWBBv0fKVEfOvud5yejh0NWdLr1U0LnMmts2eYhDMLsZgEHa3TV5aEXbEG-zZZnasiXfLMGnaScVeNKRHDiT1DNunRGF5pMFtUaAiCKe5h4hp84jHHks9mJ8mMjBRBOMrT9G45wommis84bjYThZHuPYwzA_xqeIHUU8UZjyYxDOiOIJwhj_uRKnzhOc3FHsdHgoiUNJJhRTfgzFGVEyoRijj0JZAwPYU9GTrtFjfDHbFVQt7WkFUx02RJzMMF21joyKFz-shqkSIw2g4OOxhemBnKXOxqEhiqKO6DHt_3YHwr44v-XXX7It6B4?type=png)](https://mermaid.live/edit#pako:eNqNkl1rgzAUhv9KyMXYwF74cSVjYA0rhY6WKRQWe5FqWqU1cUm8GKX_ffmwa65Gc6Hn5LxvzmM8F1jzhsIUHgUZWlCiigG9MlwoXp_AqpPqdS_esmyzCsBivV7o10fxXgagLFbZDsxmb2COi44dzxRsBK-plDoBZSsoaXbuNPeU4941qWBBv0fKVEfOvud5yejh0NWdLr1U0LnMmts2eYhDMLsZgEHa3TV5aEXbEG-zZZnasiXfLMGnaScVeNKRHDiT1DNunRGF5pMFtUaAiCKe5h4hp84jHHks9mJ8mMjBRBOMrT9G45wommis84bjYThZHuPYwzA_xqeIHUU8UZjyYxDOiOIJwhj_uRKnzhOc3FHsdHgoiUNJJhRTfgzFGVEyoRijj0JZAwPYU9GTrtFjfDHbFVQt7WkFUx02RJzMMF21joyKFz-shqkSIw2g4OOxhemBnKXOxqEhiqKO6DHt_3YHwr44v-XXX7It6B4)

# %%
'''
for idx, stock in company_tickers.items():
    stock_ticker = stock['ticker']
    stock_data = get_stock_info(stock_ticker)
    stock_description = stock_data['Business Summary']

    print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)

    vectorstore_from_documents = PineconeVectorStore.from_documents(
        documents=[Document(page_content=stock_description, metadata=stock_data)],
        embedding=hf_embeddings,
        index_name=index_name,
        namespace=namespace
    )
'''
# Out:
# '\nfor idx, stock in company_tickers.items():\n    stock_ticker = stock[\'ticker\']\n    stock_data = get_stock_info(stock_ticker)\n    stock_description = stock_data[\'Business Summary\']\n\n    print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)\n\n    vectorstore_from_documents = PineconeVectorStore.from_documents(\n        documents=[Document(page_content=stock_description, metadata=stock_data)],\n        embedding=hf_embeddings,\n        index_name=index_name,\n        namespace=namespace\n    )\n'

# %% [markdown]
# # Parallelizing
#
# [![](https://mermaid.ink/img/pako:eNqFk0uLgzAQgP_KkMOe7MHXRZaC1baXvsDCwqqHrGarVJMSE9hS-983NnWxULceRmf4Pp2MyQVlLCfIQweOTwXsw4SCuvw4Eiw7wqpsxPsXn_r-bmXAcrtdqts6WuwN2Ecr3wB__blJYTKZwixe45JCwKjgrKoI7zwXdphjlVXwwfiR8CbVH9BxdjPbqKxlJTAlTDbVuYXAjDUNZveSHWcZaRromkj_F61etIbire8Xpt2b9tDslvpCdHrRGYrddF6Ibi-6D4vsBjqcUWDe_NCMl0TAG6gfwwmEWOA7FlgasEYBWwP2KOBowBkFXA24Y4COoW61DRklLcwvQUHUHooEFrK53hHrAbkX7WdF51nRfVLUcX4fs8y6ObawMON-phvyI2CGRVakyEA14TUuc7XnL52ZIFGQmiTIU4855scEJfSqOCwFi840Q57gkhiIM3kokPeNq0Zl8pRjQcISq4NT_1VPmH4y1ufXXwdkCM8?type=png)](https://mermaid.live/edit#pako:eNqFk0uLgzAQgP_KkMOe7MHXRZaC1baXvsDCwqqHrGarVJMSE9hS-983NnWxULceRmf4Pp2MyQVlLCfIQweOTwXsw4SCuvw4Eiw7wqpsxPsXn_r-bmXAcrtdqts6WuwN2Ecr3wB__blJYTKZwixe45JCwKjgrKoI7zwXdphjlVXwwfiR8CbVH9BxdjPbqKxlJTAlTDbVuYXAjDUNZveSHWcZaRromkj_F61etIbire8Xpt2b9tDslvpCdHrRGYrddF6Ibi-6D4vsBjqcUWDe_NCMl0TAG6gfwwmEWOA7FlgasEYBWwP2KOBowBkFXA24Y4COoW61DRklLcwvQUHUHooEFrK53hHrAbkX7WdF51nRfVLUcX4fs8y6ObawMON-phvyI2CGRVakyEA14TUuc7XnL52ZIFGQmiTIU4855scEJfSqOCwFi840Q57gkhiIM3kokPeNq0Zl8pRjQcISq4NT_1VPmH4y1ufXXwdkCM8)

# %%
# Initialize tracking lists
successful_tickers = []
unsuccessful_tickers = []

# Load existing successful/unsuccessful tickers
try:
    with open('successful_tickers.txt', 'r') as f:
        successful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(successful_tickers)} successful tickers")
except FileNotFoundError:
    print("No existing successful tickers file found")

try:
    with open('unsuccessful_tickers.txt', 'r') as f:
        unsuccessful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(unsuccessful_tickers)} unsuccessful tickers")
except FileNotFoundError:
    print("No existing unsuccessful tickers file found")
# Out:
# No existing successful tickers file found
# No existing unsuccessful tickers file found

# %%
def process_stock(stock_ticker: str) -> str:
    # Skip if already processed
    if stock_ticker in successful_tickers:
        return f"Already processed {stock_ticker}"

    try:
        # Get and store stock data
        stock_data = get_stock_info(stock_ticker)
        stock_description = stock_data['Business Summary']

        # Store stock description in Pinecone
        vectorstore_from_texts = PineconeVectorStore.from_documents(
            documents=[Document(page_content=stock_description, metadata=stock_data)],
            embedding=hf_embeddings,
            index_name=index_name,
            namespace=namespace
        )

        # Track success
        with open('successful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        successful_tickers.append(stock_ticker)

        return f"Processed {stock_ticker} successfully"

    except Exception as e:
        # Track failure
        with open('unsuccessful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        unsuccessful_tickers.append(stock_ticker)

        return f"ERROR processing {stock_ticker}: {e}"

def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_ticker = {
            executor.submit(process_stock, ticker): ticker
            for ticker in tickers
        }

        for future in concurrent.futures.as_completed(future_to_ticker):
            ticker = future_to_ticker[future]
            try:
                result = future.result()
                print(result)

                # Stop on error
                if result.startswith("ERROR"):
                    print(f"Stopping program due to error in {ticker}")
                    executor.shutdown(wait=False)
                    raise SystemExit(1)

            except Exception as exc:
                print(f'{ticker} generated an exception: {exc}')
                print("Stopping program due to exception")
                executor.shutdown(wait=False)
                raise SystemExit(1)

# Prepare your tickers
tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# Process them
parallel_process_stocks(tickers_to_process, max_workers=10)
# parallel_process_stocks(tickers_to_process, max_workers=10)
# Out:
# Processed TSM successfully
# Processed GOOGL successfully
# Processed META successfully
# Processed AMZN successfully
# Processed NVDA successfully
# Processed TSLA successfully
# Processed AVGO successfully
# Processed AAPL successfully
# Processed MSFT successfully
# Processed BRK-B successfully
# Processed SPY successfully
# Processed XOM successfully
# Processed JPM successfully
# Processed V successfully
# Processed NVO successfully
# Processed UNH successfully
# Processed LLY successfully
# Processed WMT successfully
# Processed ORCL successfully
# Processed HD successfully
# Processed MA successfully
# Processed NFLX successfully
# Processed RCIT successfully
# Processed COST successfully
# Processed BAC successfully
# Processed CVX successfully
# Processed TMUS successfully
# Processed PG successfully
# Processed CRM successfully
# Processed JNJ successfully
# Processed SAP successfully
# Processed ABBV successfully
# Processed KO successfully
# Processed ASML successfully
# Processed TM successfully
# Processed ACN successfully
# Processed WFC successfully
# Processed CSCO successfully
# Processed MRK successfully
# Processed LIN successfully
# Processed ADBE successfully
# Processed PEP successfully
# Processed MCD successfully
# Processed BX successfully
# Processed MS successfully
# Processed AMD successfully
# Processed BABA successfully
# Processed PM successfully
# Processed NVS successfully
# Processed AXP successfully
# Processed NOW successfully
# Processed QQQ successfully
# Processed GE successfully
# Processed DIS successfully
# Processed SHEL successfully
# Processed ABT successfully
# Processed AZN successfully
# Processed IBM successfully
# Processed TMO successfully
# Processed ISRG successfully
# Processed INTU successfully
# Processed GS successfully
# Processed TXN successfully
# Processed QCOM successfully
# Processed VZ successfully
# Processed HSBC successfully
# Processed CAT successfully
# Processed RY successfully
# Processed BKNG successfully
# Processed DHR successfully
# Processed PDD successfully
# Processed FMX successfully
# Processed CMCSA successfully
# Processed T successfully
# Processed NEE successfully
# Processed RTX successfully
# Processed SPGI successfully
# Processed LOW successfully
# Processed HDB successfully
# Processed UBER successfully
# Processed BLK successfully
# Processed AMGN successfully
# Processed PGR successfully
# Processed UNP successfully
# Processed HON successfully
# Processed PLTR successfully
# Processed SYK successfully
# Processed SCHW successfully
# Processed UL successfully
# Processed ETN successfully
# Processed SHOP successfully
# Processed AMAT successfully
# Processed TTE successfully
# Processed TJX successfully
# Processed PFE successfully
# Processed ARM successfully
# Processed BHP successfully
# Processed MUFG successfully
# Processed KKR successfully
# Processed C successfully

# %% [markdown]
# # Perform RAG

# %%
# Initialize Pinecone
pc = Pinecone(api_key=userdata.get("PINECONE_API_KEY"),)

# Connect to your Pinecone index
pinecone_index = pc.Index(index_name)

# %%
query = "What are some companies that manufacture consumer hardware?"

# %%
raw_query_embedding = get_huggingface_embeddings(query)

# %%
top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace=namespace)

# %%
top_matches
# Out:
# {'matches': [{'id': '21435428-6441-4145-83ab-6153a88eddfc',
#               'metadata': {'Business Summary': 'Best Buy Co., Inc. engages in '
#                                                'the retail of technology '
#                                                'products in the United States, '
#                                                'Canada, and international. Its '
#                                                'stores provide computing and '
#                                                'mobile phone products, such as '
#                                                'desktops, notebooks, and '
#                                                'peripherals; mobile phones '
#                                                'comprising related mobile '
#                                                'network carrier commissions; '
#                                                'networking products; tablets '
#                                                'covering e-readers; '
#                                                'smartwatches; and consumer '
#                                                'electronics consisting of '
#                                                'digital imaging, health and '
#                                                'fitness products, portable '
#                                                'audio comprising headphones '
#                                                'and portable speakers, and '
#                                                'smart home products, as well '
#                                                'as home theaters, which '
#                                                'includes home theater '
#                                                'accessories, soundbars, and '
#                                                "televisions. The company's "
#                                                'stores also offer appliances, '
#                                                'such as dishwashers, laundry, '
#                                                'ovens, refrigerators, '
#                                                'blenders, coffee makers, '
#                                                'vacuums, and personal care; '
#                                                'entertainment products '
#                                                'consisting of drones, '
#                                                'peripherals, movies, and toys, '
#                                                'as well as hardware and '
#                                                'software, and virtual reality '
#                                                'and other software products; '
#                                                'and other products, such as '
#                                                'baby, food and beverage, '
#                                                'luggage, outdoor living, and '
#                                                'sporting goods. In addition, '
#                                                'it provides delivery, '
#                                                'installation, memberships, '
#                                                'repair, set-up, technical '
#                                                'support, health-related, and '
#                                                'warranty-related services. The '
#                                                'company offers its products '
#                                                'through stores and websites '
#                                                'under the Best Buy, Best Buy '
#                                                'Ads, Best Buy Business, Best '
#                                                'Buy Health, Buy Mobile, CST, '
#                                                'Current Health, Geek Squad, '
#                                                'Lively, Magnolia, Pacific '
#                                                'Kitchen, Home, '
#                                                'TechLiquidators, and Yardbird '
#                                                'brands, as well as domain '
#                                                'names comprising bestbuy.com, '
#                                                'currenthealth.com, lively.com, '
#                                                'techliquidators.com, '
#                                                'yardbird.com, and bestbuy.ca. '
#                                                'The company was formerly known '
#                                                'as Sound of Music, Inc. Best '
#                                                'Buy Co., Inc. was incorporated '
#                                                'in 1966 and is headquartered '
#                                                'in Richfield, Minnesota.',
#                            'City': 'Richfield',
#                            'Country': 'United States',
#                            'Industry': 'Specialty Retail',
#                            'Name': 'Best Buy Co., Inc.',
#                            'Sector': 'Consumer Cyclical',
#                            'State': 'MN',
#                            'Ticker': 'BBY',
#                            'text': 'Best Buy Co., Inc. engages in the retail '
#                                    'of technology products in the United '
#                                    'States, Canada, and international. Its '
#                                    'stores provide computing and mobile phone '
#                                    'products, such as desktops, notebooks, and '
#                                    'peripherals; mobile phones comprising '
#                                    'related mobile network carrier '
#                                    'commissions; networking products; tablets '
#                                    'covering e-readers; smartwatches; and '
#                                    'consumer electronics consisting of digital '
#                                    'imaging, health and fitness products, '
#                                    'portable audio comprising headphones and '
#                                    'portable speakers, and smart home '
#                                    'products, as well as home theaters, which '
#                                    'includes home theater accessories, '
#                                    "soundbars, and televisions. The company's "
#                                    'stores also offer appliances, such as '
#                                    'dishwashers, laundry, ovens, '
#                                    'refrigerators, blenders, coffee makers, '
#                                    'vacuums, and personal care; entertainment '
#                                    'products consisting of drones, '
#                                    'peripherals, movies, and toys, as well as '
#                                    'hardware and software, and virtual reality '
#                                    'and other software products; and other '
#                                    'products, such as baby, food and beverage, '
#                                    'luggage, outdoor living, an'},
#               'score': 0.535241187,
#               'values': []},
#              {'id': '1331f0b5-d6f3-42cd-a290-698b9cf280b0',
#               'metadata': {'Business Summary': 'Kimball Electronics, Inc. '
#                                                'engages in the provision of '
#                                                'electronics manufacturing, '
#                                                'engineering, and supply chain '
#                                                'support services to customers '
#                                                'in the automotive, medical, '
#                                                'and industrial end markets. '
#                                                'The Company also offers '
#                                                'contract manufacturing '
#                                                'services, including '
#                                                'engineering and supply chain '
#                                                'support for the production of '
#                                                'electronic assemblies and '
#                                                'other products, including '
#                                                'non-electronic components, '
#                                                'medical devices, medical '
#                                                'disposables, and precision '
#                                                'molded plastics, as well as '
#                                                'automation, test, and '
#                                                'inspection equipment primarily '
#                                                'used in automotive, medical, '
#                                                'and industrial applications. '
#                                                'In addition, it is also '
#                                                'involved in the production and '
#                                                'testing of printed circuit '
#                                                'board assemblies, as well as '
#                                                'clean room assembly, cold '
#                                                'chain, and product '
#                                                'sterilization management '
#                                                'activities. Further, the '
#                                                'company offers design services '
#                                                'and support, supply chain '
#                                                'services and support, rapid '
#                                                'prototyping and new product '
#                                                'introduction support, product '
#                                                'design and process validation '
#                                                'and qualification, '
#                                                'industrialization and '
#                                                'automation of manufacturing '
#                                                'processes, reliability '
#                                                'testing, aftermarket services, '
#                                                'drug delivery devices and '
#                                                'solutions with and without '
#                                                'electronics, and product life '
#                                                'cycle management services, as '
#                                                'well as and assembly of '
#                                                'medical, automotive, and '
#                                                'industrial products. It '
#                                                'operates in the United States, '
#                                                'China, Mexico, Poland, '
#                                                'Romania, Thailand, India, '
#                                                'Japan, Vietnam, and '
#                                                'internationally. Kimball '
#                                                'Electronics, Inc. was founded '
#                                                'in 1961 and is headquartered '
#                                                'in Jasper, Indiana.',
#                            'City': 'Jasper',
#                            'Country': 'United States',
#                            'Industry': 'Electrical Equipment & Parts',
#                            'Name': 'Kimball Electronics, Inc.',
#                            'Sector': 'Industrials',
#                            'State': 'IN',
#                            'Ticker': 'KE',
#                            'text': 'Kimball Electronics, Inc. engages in the '
#                                    'provision of electronics manufacturing, '
#                                    'engineering, and supply chain support '
#                                    'services to customers in the automotive, '
#                                    'medical, and industrial end markets. The '
#                                    'Company also offers contract manufacturing '
#                                    'services, including engineering and supply '
#                                    'chain support for the production of '
#                                    'electronic assemblies and other products, '
#                                    'including non-electronic components, '
#                                    'medical devices, medical disposables, and '
#                                    'precision molded plastics, as well as '
#                                    'automation, test, and inspection equipment '
#                                    'primarily used in automotive, medical, and '
#                                    'industrial applications. In addition, it '
#                                    'is also involved in the production and '
#                                    'testing of printed circuit board '
#                                    'assemblies, as well as clean room '
#                                    'assembly, cold chain, and product '
#                                    'sterilization management activities. '
#                                    'Further, the company offers design '
#                                    'services and support, supply chain '
#                                    'services and support, rapid prototyping '
#                                    'and new product introduction support, '
#                                    'product design and process validation and '
#                                    'qualification, industria'},
#               'score': 0.527755618,
#               'values': []},
#              {'id': 'beeeb3c2-3ffd-45fa-a3c4-a798d89d16ac',
#               'metadata': {'Business Summary': 'Standex International '
#                                                'Corporation, together with '
#                                                'subsidiaries, engages in the '
#                                                'manufacture and sale of '
#                                                'various products and services '
#                                                'for commercial and industrial '
#                                                'markets in the United States '
#                                                'and internationally. It '
#                                                'operates through five '
#                                                'segments: Electronics, '
#                                                'Engraving, Scientific, '
#                                                'Engineering Technologies, and '
#                                                'Specialty Solutions. The '
#                                                'Electronics segment offers '
#                                                'reed relays, fluid level, '
#                                                'proximity, motion, flow, HVAC '
#                                                'condensate, and custom '
#                                                'electronics sensors; and '
#                                                'custom wound transformers and '
#                                                'inductors for low and high '
#                                                'frequency, current sense '
#                                                'technology, advanced planar '
#                                                'transformer technology, value '
#                                                'added assembly, and mechanical '
#                                                'packaging applications under '
#                                                'the Standex Electronics, '
#                                                'Renco, and Agile Magnetics. '
#                                                'The Engraving segment provides '
#                                                'mold texturizing, slush '
#                                                'molding tools, roll engraving, '
#                                                'hygiene product tooling, and '
#                                                'low observation vents, as well '
#                                                'as project management and '
#                                                'design services for stealth '
#                                                'aircraft; and process '
#                                                'machinery for various '
#                                                'industries under the Piazza '
#                                                'Rosa, World Client Services, '
#                                                'Tenibac-Graphion, GS '
#                                                'Engineering, and Innovent '
#                                                'brand names. The Scientific '
#                                                'segment offers '
#                                                'temperature-controlled '
#                                                'equipment for the medical, '
#                                                'scientific, pharmaceutical, '
#                                                'biotech, and industrial '
#                                                'markets under the American '
#                                                'BioTech Supply, Lab Research '
#                                                'Products, Corepoint, Cryosafe, '
#                                                'CryoGuard, and Scientific '
#                                                'brands. The Engineering '
#                                                'Technologies segment offers '
#                                                'net and near net formed '
#                                                'single-source customized '
#                                                'solutions that are used in the '
#                                                'manufacture of engineered '
#                                                'components for the aviation, '
#                                                'aerospace, defense, energy, '
#                                                'industrial, medical, marine, '
#                                                'oil and gas, and manned and '
#                                                'unmanned space markets under '
#                                                'the Spincraft brand. The '
#                                                'Specialty Solutions segment '
#                                                'manufactures and sells '
#                                                'refrigerated, heated, and dry '
#                                                'merchandizing display cases; '
#                                                'and single and double acting '
#                                                'telescopic, and piston rod '
#                                                'hydraulic cylinders under the '
#                                                'Federal and Custom Hoist '
#                                                'brands. The company was '
#                                                'founded in 1955 and is '
#                                                'headquartered in Salem, New '
#                                                'Hampshire.',
#                            'City': 'Salem',
#                            'Country': 'United States',
#                            'Industry': 'Specialty Industrial Machinery',
#                            'Name': 'Standex International Corporation',
#                            'Sector': 'Industrials',
#                            'State': 'NH',
#                            'Ticker': 'SXI',
#                            'text': 'Standex International Corporation, '
#                                    'together with subsidiaries, engages in the '
#                                    'manufacture and sale of various products '
#                                    'and services for commercial and industrial '
#                                    'markets in the United States and '
#                                    'internationally. It operates through five '
#                                    'segments: Electronics, Engraving, '
#                                    'Scientific, Engineering Technologies, and '
#                                    'Specialty Solutions. The Electronics '
#                                    'segment offers reed relays, fluid level, '
#                                    'proximity, motion, flow, HVAC condensate, '
#                                    'and custom electronics sensors; and custom '
#                                    'wound transformers and inductors for low '
#                                    'and high frequency, current sense '
#                                    'technology, advanced planar transformer '
#                                    'technology, value added assembly, and '
#                                    'mechanical packaging applications under '
#                                    'the Standex Electronics, Renco, and Agile '
#                                    'Magnetics. The Engraving segment provides '
#                                    'mold texturizing, slush molding tools, '
#                                    'roll engraving, hygiene product tooling, '
#                                    'and low observation vents, as well as '
#                                    'project management and design services for '
#                                    'stealth aircraft; and process machinery '
#                                    'for various industries under the Piazza '
#                                    'Rosa, World Client Services, '
#                                    'Tenibac-Graphion, GS Engineering, and '
#                                    'Innovent brand names. The Scientific '
#                                    'segment offers temperature-controlled '
#                                    'equipment for the medical, scientific, '
#                                    'pharmaceutical, biotech, and industrial '
#                                    'markets under the American BioTech Supply, '
#                                    'Lab Research Products, Corepoint, '
#                                    'Cryosafe, CryoGuard, and Scientific '
#                                    'brands. The Engineering Technologies '
#                                    'segment offers net and near net formed '
#                                    'single-source customized solutions that '
#                                    'are used in the manufacture of engineered '
#                                    'components for the aviation, aerospace, '
#                                    'defense, energy, industrial, medical, '
#                                    'marine, oil and gas, and manned and '
#                                    'unmanned space markets under the Spincraft '
#                                    'brand. The Specialty Solutions segment '
#                                    'manufactures and sells refrigerated, '
#                                    'heated, and dry merchandizing display '
#                                    'cases; and single and double acting '
#                                    'telescopic, and piston rod hydraulic '
#                                    'cylinders under the Federal and Custom '
#                                    'Hoist brands. The company was founded in '
#                                    '1955 and is headquartered in Salem, New '
#                                    'Hampshire.'},
#               'score': 0.509246945,
#               'values': []},
#              {'id': 'c0bfb07b-6128-4e34-901a-313c10399d2f',
#               'metadata': {'Business Summary': 'Standex International '
#                                                'Corporation, together with '
#                                                'subsidiaries, engages in the '
#                                                'manufacture and sale of '
#                                                'various products and services '
#                                                'for commercial and industrial '
#                                                'markets in the United States '
#                                                'and internationally. It '
#                                                'operates through five '
#                                                'segments: Electronics, '
#                                                'Engraving, Scientific, '
#                                                'Engineering Technologies, and '
#                                                'Specialty Solutions. The '
#                                                'Electronics segment offers '
#                                                'reed relays, fluid level, '
#                                                'proximity, motion, flow, HVAC '
#                                                'condensate, and custom '
#                                                'electronics sensors; and '
#                                                'custom wound transformers and '
#                                                'inductors for low and high '
#                                                'frequency, current sense '
#                                                'technology, advanced planar '
#                                                'transformer technology, value '
#                                                'added assembly, and mechanical '
#                                                'packaging applications under '
#                                                'the Standex Electronics, '
#                                                'Renco, and Agile Magnetics. '
#                                                'The Engraving segment provides '
#                                                'mold texturizing, slush '
#                                                'molding tools, roll engraving, '
#                                                'hygiene product tooling, and '
#                                                'low observation vents, as well '
#                                                'as project management and '
#                                                'design services for stealth '
#                                                'aircraft; and process '
#                                                'machinery for various '
#                                                'industries under the Piazza '
#                                                'Rosa, World Client Services, '
#                                                'Tenibac-Graphion, GS '
#                                                'Engineering, and Innovent '
#                                                'brand names. The Scientific '
#                                                'segment offers '
#                                                'temperature-controlled '
#                                                'equipment for the medical, '
#                                                'scientific, pharmaceutical, '
#                                                'biotech, and industrial '
#                                                'markets under the American '
#                                                'BioTech Supply, Lab Research '
#                                                'Products, Corepoint, Cryosafe, '
#                                                'CryoGuard, and Scientific '
#                                                'brands. The Engineering '
#                                                'Technologies segment offers '
#                                                'net and near net formed '
#                                                'single-source customized '
#                                                'solutions that are used in the '
#                                                'manufacture of engineered '
#                                                'components for the aviation, '
#                                                'aerospace, defense, energy, '
#                                                'industrial, medical, marine, '
#                                                'oil and gas, and manned and '
#                                                'unmanned space markets under '
#                                                'the Spincraft brand. The '
#                                                'Specialty Solutions segment '
#                                                'manufactures and sells '
#                                                'refrigerated, heated, and dry '
#                                                'merchandizing display cases; '
#                                                'and single and double acting '
#                                                'telescopic, and piston rod '
#                                                'hydraulic cylinders under the '
#                                                'Federal and Custom Hoist '
#                                                'brands. The company was '
#                                                'founded in 1955 and is '
#                                                'headquartered in Salem, New '
#                                                'Hampshire.',
#                            'City': 'Salem',
#                            'Country': 'United States',
#                            'Industry': 'Specialty Industrial Machinery',
#                            'Name': 'Standex International Corporation',
#                            'Sector': 'Industrials',
#                            'State': 'NH',
#                            'Ticker': 'SXI',
#                            'text': 'Standex International Corporation, '
#                                    'together with subsidiaries, engages in the '
#                                    'manufacture and sale of various products '
#                                    'and services for commercial and industrial '
#                                    'markets in the United States and '
#                                    'internationally. It operates through five '
#                                    'segments: Electronics, Engraving, '
#                                    'Scientific, Engineering Technologies, and '
#                                    'Specialty Solutions. The Electronics '
#                                    'segment offers reed relays, fluid level, '
#                                    'proximity, motion, flow, HVAC condensate, '
#                                    'and custom electronics sensors; and custom '
#                                    'wound transformers and inductors for low '
#                                    'and high frequency, current sense '
#                                    'technology, advanced planar transformer '
#                                    'technology, value added assembly, and '
#                                    'mechanical packaging applications under '
#                                    'the Standex Electronics, Renco, and Agile '
#                                    'Magnetics. The Engraving segment provides '
#                                    'mold texturizing, slush molding tools, '
#                                    'roll engraving, hygiene product tooling, '
#                                    'and low observation vents, as well as '
#                                    'project management and design services for '
#                                    'stealth aircraft; and process machinery '
#                                    'for various industries under the Piazza '
#                                    'Rosa, World Client Services, '
#                                    'Tenibac-Graphion, GS Engineering, and '
#                                    'Innovent brand names. The Scientific '
#                                    'segment offers temperature-controlled '
#                                    'equipment for the medical, scientific, '
#                                    'pharmaceutical, biotech, and industrial '
#                                    'markets under the American BioTech Supply, '
#                                    'Lab Research Products, Corepoint, '
#                                    'Cryosafe, CryoGuard, and Scientific '
#                                    'brands. The Engineering Technologies '
#                                    'segment offers net and near net formed '
#                                    'single-source customized solutions that '
#                                    'are used in the manufacture of engineered '
#                                    'components for the aviation, aerospace, '
#                                    'defense, energy, industrial, medical, '
#                                    'marine, oil and gas, and manned and '
#                                    'unmanned space markets under the Spincraft '
#                                    'brand. The Specialty Solutions segment '
#                                    'manufactures and sells refrigerated, '
#                                    'heated, and dry merchandizing display '
#                                    'cases; and single and double acting '
#                                    'telescopic, and piston rod hydraulic '
#                                    'cylinders under the Federal and Custom '
#                                    'Hoist brands. The company was founded in '
#                                    '1955 and is headquartered in Salem, New '
#                                    'Hampshire.'},
#               'score': 0.509246945,
#               'values': []},
#              {'id': '4c7320bf-1940-4656-b676-22cc20b21384',
#               'metadata': {'Business Summary': 'Worthington Enterprises, Inc. '
#                                                'operates as an industrial '
#                                                'manufacturing company. It '
#                                                'operates through two segments, '
#                                                'Consumer Products and Building '
#                                                'Products. The Consumer '
#                                                'Products segment provides '
#                                                'products in the tools, outdoor '
#                                                'living, and celebrations end '
#                                                "markets. The segment's "
#                                                'products include hand-held '
#                                                'torches, micro torches, '
#                                                'lighters, accessories, and '
#                                                'fuel for constructing, fixing '
#                                                'making, and creating; '
#                                                'precision and specialty hand, '
#                                                'digital, and safety tools; '
#                                                'drywall tools and accessories '
#                                                'used for finishing and taping, '
#                                                'cutting, siding, and roofing; '
#                                                'propane-filled cylinders for '
#                                                'torches, camping stoves and '
#                                                'other applications, '
#                                                'helium-filled balloon kits, '
#                                                'and gas grills and pizza '
#                                                'ovens. This segment sells its '
#                                                'products primarily to mass '
#                                                'merchandisers, retailers, and '
#                                                'distributors under the Balloon '
#                                                'Time, Bernzomatic, Coleman, '
#                                                'Garden-Weasel, General, Halo, '
#                                                'Hawkeye, Level5, Mag-Torch, '
#                                                'Pactool International, and '
#                                                'Worthington Pro Grade brands. '
#                                                'The Building Products segment '
#                                                'provides pressurized '
#                                                'containment solutions, such as '
#                                                'refrigerant gas cylinders used '
#                                                'in holding refrigerant gases '
#                                                'for commercial, residential, '
#                                                'and automotive air '
#                                                'conditioning, and '
#                                                'refrigeration systems; '
#                                                'liquefied petroleum gas '
#                                                'cylinders that holds fuel for '
#                                                'residential and light '
#                                                'commercial heating systems, '
#                                                'barbeque grills and '
#                                                'recreational vehicle '
#                                                'equipment, industrial '
#                                                'forklifts, and '
#                                                'commercial/residential '
#                                                'cooking; well water and '
#                                                'expansion tanks used primarily '
#                                                'in the residential and '
#                                                'commercial markets; specialty '
#                                                'products, including various '
#                                                'fire suppression tanks, '
#                                                'chemical tanks, and foam and '
#                                                'adhesive tanks; and ceiling '
#                                                'suspension systems. The '
#                                                'company was formerly known as '
#                                                'Worthington Industries, Inc. '
#                                                'Worthington Enterprises, Inc. '
#                                                'was founded in 1955 and is '
#                                                'headquartered in Columbus, '
#                                                'Ohio.',
#                            'City': 'Columbus',
#                            'Country': 'United States',
#                            'Industry': 'Metal Fabrication',
#                            'Name': 'Worthington Enterprises, Inc.',
#                            'Sector': 'Industrials',
#                            'State': 'OH',
#                            'Ticker': 'WOR',
#                            'text': 'Worthington Enterprises, Inc. operates as '
#                                    'an industrial manufacturing company. It '
#                                    'operates through two segments, Consumer '
#                                    'Products and Building Products. The '
#                                    'Consumer Products segment provides '
#                                    'products in the tools, outdoor living, and '
#                                    "celebrations end markets. The segment's "
#                                    'products include hand-held torches, micro '
#                                    'torches, lighters, accessories, and fuel '
#                                    'for constructing, fixing making, and '
#                                    'creating; precision and specialty hand, '
#                                    'digital, and safety tools; drywall tools '
#                                    'and accessories used for finishing and '
#                                    'taping, cutting, siding, and roofing; '
#                                    'propane-filled cylinders for torches, '
#                                    'camping stoves and other applications, '
#                                    'helium-filled balloon kits, and gas grills '
#                                    'and pizza ovens. This segment sells its '
#                                    'products primarily to mass merchandisers, '
#                                    'retailers, and distributors under the '
#                                    'Balloon Time, Bernzomatic, Coleman, '
#                                    'Garden-Weasel, General, Halo, Hawkeye, '
#                                    'Level5, Mag-Torch, Pactool International, '
#                                    'and Worthington Pro Grade brands. The '
#                                    'Building Products segment provides '
#                                    'pressurized cont'},
#               'score': 0.505470157,
#               'values': []},
#              {'id': '6479157c-39d5-4ef2-a487-af4c00b213d4',
#               'metadata': {'Business Summary': 'Arrow Electronics, Inc. '
#                                                'provides products, services, '
#                                                'and solutions to industrial '
#                                                'and commercial users of '
#                                                'electronic components and '
#                                                'enterprise computing solutions '
#                                                'in the Americas, Europe, the '
#                                                'Middle East, Africa, and the '
#                                                'Asia Pacific. The company '
#                                                'operates in two segments, '
#                                                'Global Components and Global '
#                                                'Enterprise Computing '
#                                                'Solutions. The Global '
#                                                'Components segment markets and '
#                                                'distributes electronic '
#                                                'components comprising '
#                                                'semiconductor products and '
#                                                'related services; '
#                                                'interconnect, passive, and '
#                                                'electromechanical products, '
#                                                'including capacitors, '
#                                                'resistors, potentiometers, '
#                                                'power supplies, relays, '
#                                                'switches, and connectors; and '
#                                                'computing and memory products, '
#                                                'as well as other products and '
#                                                'services. The Global '
#                                                'Enterprise Computing Solutions '
#                                                'segment offers computing '
#                                                'solutions, such as datacenter, '
#                                                'cloud, security, and analytics '
#                                                'solutions. This segment also '
#                                                'provides access to various '
#                                                'services, including '
#                                                'engineering and integration '
#                                                'support, warehousing and '
#                                                'logistics, marketing '
#                                                'resources, and authorized '
#                                                'hardware and software '
#                                                'training. The company serves '
#                                                'original equipment '
#                                                'manufacturers, value-added '
#                                                'resellers, managed service '
#                                                'providers, contract '
#                                                'manufacturers, and other '
#                                                'commercial customers. Arrow '
#                                                'Electronics, Inc. was founded '
#                                                'in 1935 and is based in '
#                                                'Centennial, Colorado.',
#                            'City': 'Centennial',
#                            'Country': 'United States',
#                            'Industry': 'Electronics & Computer Distribution',
#                            'Name': 'Arrow Electronics, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'CO',
#                            'Ticker': 'ARW',
#                            'text': 'Arrow Electronics, Inc. provides products, '
#                                    'services, and solutions to industrial and '
#                                    'commercial users of electronic components '
#                                    'and enterprise computing solutions in the '
#                                    'Americas, Europe, the Middle East, Africa, '
#                                    'and the Asia Pacific. The company operates '
#                                    'in two segments, Global Components and '
#                                    'Global Enterprise Computing Solutions. The '
#                                    'Global Components segment markets and '
#                                    'distributes electronic components '
#                                    'comprising semiconductor products and '
#                                    'related services; interconnect, passive, '
#                                    'and electromechanical products, including '
#                                    'capacitors, resistors, potentiometers, '
#                                    'power supplies, relays, switches, and '
#                                    'connectors; and computing and memory '
#                                    'products, as well as other products and '
#                                    'services. The Global Enterprise Computing '
#                                    'Solutions segment offers computing '
#                                    'solutions, such as datacenter, cloud, '
#                                    'security, and analytics solutions. This '
#                                    'segment also provides access to various '
#                                    'services, including engineering and '
#                                    'integration support, warehousing and '
#                                    'logistics, marketing resources, and '
#                                    'authorized hardware and software training. '
# ...
#                                                'technical design solutions; '
#                                                'engineering and technical '
#                                                'resources to support product '
#                                                'design, bill of materials '
#                                                'development, and technical '
#                                                'education and training; and '
#                                                'supply chain solutions that '
#                                                'provide support, warehousing, '
#                                                'and logistical services to '
#                                                'original equipment '
#                                                'manufacturers, electronic '
#                                                'manufacturing service '
#                                                'providers, and electronic '
#                                                'component manufacturers. In '
#                                                'addition, this segment '
#                                                'provides embedded solutions, '
#                                                'such as technical design, '
#                                                'integration, and assembly of '
#                                                'embedded products, systems, '
#                                                'and solutions, as well as '
#                                                'embedded display solutions '
#                                                'comprising touch and passive '
#                                                'displays; and develops and '
#                                                'manufactures standard board '
#                                                'and industrial subsystems, and '
#                                                'application-specific devices '
#                                                'that enable it to produce '
#                                                'systems tailored to specific '
#                                                'customer requirements. This '
#                                                'segment serves various '
#                                                'markets, such as automotive, '
#                                                'medical, defense, aerospace, '
#                                                'telecommunications, '
#                                                'industrial, and digital '
#                                                'editing. The Farnell segment '
#                                                'distributes kits, tools, and '
#                                                'electronic and industrial '
#                                                'automation components, as well '
#                                                'as test and measurement '
#                                                'products to engineers and '
#                                                'entrepreneurs. It has '
#                                                'operations in the Americas, '
#                                                'Europe, the Middle East, '
#                                                'Africa, and Asia. Avnet, Inc. '
#                                                'was founded in 1921 and is '
#                                                'headquartered in Phoenix, '
#                                                'Arizona.',
#                            'City': 'Phoenix',
#                            'Country': 'United States',
#                            'Industry': 'Electronics & Computer Distribution',
#                            'Name': 'Avnet, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'AZ',
#                            'Ticker': 'AVT',
#                            'text': 'Avnet, Inc., distributes electronic '
#                                    'component technology. The company operates '
#                                    'through two segments, Electronic '
#                                    'Components and Farnell. The Electronic '
#                                    'Components segment markets, sells, and '
#                                    'distributes semiconductors; interconnect, '
#                                    'passive, and electromechanical components; '
#                                    'and other integrated components from '
#                                    'electronic component manufacturers. It '
#                                    'also offers design chain support that '
#                                    'provides engineers with technical design '
#                                    'solutions; engineering and technical '
#                                    'resources to support product design, bill '
#                                    'of materials development, and technical '
#                                    'education and training; and supply chain '
#                                    'solutions that provide support, '
#                                    'warehousing, and logistical services to '
#                                    'original equipment manufacturers, '
#                                    'electronic manufacturing service '
#                                    'providers, and electronic component '
#                                    'manufacturers. In addition, this segment '
#                                    'provides embedded solutions, such as '
#                                    'technical design, integration, and '
#                                    'assembly of embedded products, systems, '
#                                    'and solutions, as well as embedded display '
#                                    'solutions comprising touch and passive '
#                                    'displays; and develops and manufactures '
#                                    'standard board and industrial subsystems, '
#                                    'and application-specific devices that '
#                                    'enable it to produce systems tailored to '
#                                    'specific customer requirements. This '
#                                    'segment serves various markets, such as '
#                                    'automotive, medical, defense, aerospace, '
#                                    'telecommunications, industrial, and '
#                                    'digital editing. The Farnell segment '
#                                    'distributes kits, tools, and electronic '
#                                    'and industrial automation components, as '
#                                    'well as test and measurement products to '
#                                    'engineers and entrepreneurs. It has '
#                                    'operations in the Americas, Europe, the '
#                                    'Middle East, Africa, and Asia. Avnet, Inc. '
#                                    'was founded in 1921 and is headquartered '
#                                    'in Phoenix, Arizona.'},
#               'score': 0.498096466,
#               'values': []},
#              {'id': '849076ac-c6e2-417c-9d54-77493857e246',
#               'metadata': {'Business Summary': 'Avnet, Inc., distributes '
#                                                'electronic component '
#                                                'technology. The company '
#                                                'operates through two segments, '
#                                                'Electronic Components and '
#                                                'Farnell. The Electronic '
#                                                'Components segment markets, '
#                                                'sells, and distributes '
#                                                'semiconductors; interconnect, '
#                                                'passive, and electromechanical '
#                                                'components; and other '
#                                                'integrated components from '
#                                                'electronic component '
#                                                'manufacturers. It also offers '
#                                                'design chain support that '
#                                                'provides engineers with '
#                                                'technical design solutions; '
#                                                'engineering and technical '
#                                                'resources to support product '
#                                                'design, bill of materials '
#                                                'development, and technical '
#                                                'education and training; and '
#                                                'supply chain solutions that '
#                                                'provide support, warehousing, '
#                                                'and logistical services to '
#                                                'original equipment '
#                                                'manufacturers, electronic '
#                                                'manufacturing service '
#                                                'providers, and electronic '
#                                                'component manufacturers. In '
#                                                'addition, this segment '
#                                                'provides embedded solutions, '
#                                                'such as technical design, '
#                                                'integration, and assembly of '
#                                                'embedded products, systems, '
#                                                'and solutions, as well as '
#                                                'embedded display solutions '
#                                                'comprising touch and passive '
#                                                'displays; and develops and '
#                                                'manufactures standard board '
#                                                'and industrial subsystems, and '
#                                                'application-specific devices '
#                                                'that enable it to produce '
#                                                'systems tailored to specific '
#                                                'customer requirements. This '
#                                                'segment serves various '
#                                                'markets, such as automotive, '
#                                                'medical, defense, aerospace, '
#                                                'telecommunications, '
#                                                'industrial, and digital '
#                                                'editing. The Farnell segment '
#                                                'distributes kits, tools, and '
#                                                'electronic and industrial '
#                                                'automation components, as well '
#                                                'as test and measurement '
#                                                'products to engineers and '
#                                                'entrepreneurs. It has '
#                                                'operations in the Americas, '
#                                                'Europe, the Middle East, '
#                                                'Africa, and Asia. Avnet, Inc. '
#                                                'was founded in 1921 and is '
#                                                'headquartered in Phoenix, '
#                                                'Arizona.',
#                            'City': 'Phoenix',
#                            'Country': 'United States',
#                            'Industry': 'Electronics & Computer Distribution',
#                            'Name': 'Avnet, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'AZ',
#                            'Ticker': 'AVT',
#                            'text': 'Avnet, Inc., distributes electronic '
#                                    'component technology. The company operates '
#                                    'through two segments, Electronic '
#                                    'Components and Farnell. The Electronic '
#                                    'Components segment markets, sells, and '
#                                    'distributes semiconductors; interconnect, '
#                                    'passive, and electromechanical components; '
#                                    'and other integrated components from '
#                                    'electronic component manufacturers. It '
#                                    'also offers design chain support that '
#                                    'provides engineers with technical design '
#                                    'solutions; engineering and technical '
#                                    'resources to support product design, bill '
#                                    'of materials development, and technical '
#                                    'education and training; and supply chain '
#                                    'solutions that provide support, '
#                                    'warehousing, and logistical services to '
#                                    'original equipment manufacturers, '
#                                    'electronic manufacturing service '
#                                    'providers, and electronic component '
#                                    'manufacturers. In addition, this segment '
#                                    'provides embedded solutions, such as '
#                                    'technical design, integration, and '
#                                    'assembly of embedded products, systems, '
#                                    'and solutions, as well as embedded display '
#                                    'solutions comprising touch and passive '
#                                    'displays; and develops and manufactures '
#                                    'standard board and industrial subsystems, '
#                                    'and application-specific devices that '
#                                    'enable it to produce systems tailored to '
#                                    'specific customer requirements. This '
#                                    'segment serves various markets, such as '
#                                    'automotive, medical, defense, aerospace, '
#                                    'telecommunications, industrial, and '
#                                    'digital editing. The Farnell segment '
#                                    'distributes kits, tools, and electronic '
#                                    'and industrial automation components, as '
#                                    'well as test and measurement products to '
#                                    'engineers and entrepreneurs. It has '
#                                    'operations in the Americas, Europe, the '
#                                    'Middle East, Africa, and Asia. Avnet, Inc. '
#                                    'was founded in 1921 and is headquartered '
#                                    'in Phoenix, Arizona.'},
#               'score': 0.498096466,
#               'values': []}],
#  'namespace': 'stock-descriptions',
#  'usage': {'read_units': 6}}

# %%
contexts = [item['metadata']['text'] for item in top_matches['matches']]

# %%
augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

# %%
print(augmented_query)
# Out:
# <CONTEXT>
# Best Buy Co., Inc. engages in the retail of technology products in the United States, Canada, and international. Its stores provide computing and mobile phone products, such as desktops, notebooks, and peripherals; mobile phones comprising related mobile network carrier commissions; networking products; tablets covering e-readers; smartwatches; and consumer electronics consisting of digital imaging, health and fitness products, portable audio comprising headphones and portable speakers, and smart home products, as well as home theaters, which includes home theater accessories, soundbars, and televisions. The company's stores also offer appliances, such as dishwashers, laundry, ovens, refrigerators, blenders, coffee makers, vacuums, and personal care; entertainment products consisting of drones, peripherals, movies, and toys, as well as hardware and software, and virtual reality and other software products; and other products, such as baby, food and beverage, luggage, outdoor living, an
#
# -------
#
# Kimball Electronics, Inc. engages in the provision of electronics manufacturing, engineering, and supply chain support services to customers in the automotive, medical, and industrial end markets. The Company also offers contract manufacturing services, including engineering and supply chain support for the production of electronic assemblies and other products, including non-electronic components, medical devices, medical disposables, and precision molded plastics, as well as automation, test, and inspection equipment primarily used in automotive, medical, and industrial applications. In addition, it is also involved in the production and testing of printed circuit board assemblies, as well as clean room assembly, cold chain, and product sterilization management activities. Further, the company offers design services and support, supply chain services and support, rapid prototyping and new product introduction support, product design and process validation and qualification, industria
#
# -------
#
# Standex International Corporation, together with subsidiaries, engages in the manufacture and sale of various products and services for commercial and industrial markets in the United States and internationally. It operates through five segments: Electronics, Engraving, Scientific, Engineering Technologies, and Specialty Solutions. The Electronics segment offers reed relays, fluid level, proximity, motion, flow, HVAC condensate, and custom electronics sensors; and custom wound transformers and inductors for low and high frequency, current sense technology, advanced planar transformer technology, value added assembly, and mechanical packaging applications under the Standex Electronics, Renco, and Agile Magnetics. The Engraving segment provides mold texturizing, slush molding tools, roll engraving, hygiene product tooling, and low observation vents, as well as project management and design services for stealth aircraft; and process machinery for various industries under the Piazza Rosa, World Client Services, Tenibac-Graphion, GS Engineering, and Innovent brand names. The Scientific segment offers temperature-controlled equipment for the medical, scientific, pharmaceutical, biotech, and industrial markets under the American BioTech Supply, Lab Research Products, Corepoint, Cryosafe, CryoGuard, and Scientific brands. The Engineering Technologies segment offers net and near net formed single-source customized solutions that are used in the manufacture of engineered components for the aviation, aerospace, defense, energy, industrial, medical, marine, oil and gas, and manned and unmanned space markets under the Spincraft brand. The Specialty Solutions segment manufactures and sells refrigerated, heated, and dry merchandizing display cases; and single and double acting telescopic, and piston rod hydraulic cylinders under the Federal and Custom Hoist brands. The company was founded in 1955 and is headquartered in Salem, New Hampshire.
#
# -------
#
# Standex International Corporation, together with subsidiaries, engages in the manufacture and sale of various products and services for commercial and industrial markets in the United States and internationally. It operates through five segments: Electronics, Engraving, Scientific, Engineering Technologies, and Specialty Solutions. The Electronics segment offers reed relays, fluid level, proximity, motion, flow, HVAC condensate, and custom electronics sensors; and custom wound transformers and inductors for low and high frequency, current sense technology, advanced planar transformer technology, value added assembly, and mechanical packaging applications under the Standex Electronics, Renco, and Agile Magnetics. The Engraving segment provides mold texturizing, slush molding tools, roll engraving, hygiene product tooling, and low observation vents, as well as project management and design services for stealth aircraft; and process machinery for various industries under the Piazza Rosa, World Client Services, Tenibac-Graphion, GS Engineering, and Innovent brand names. The Scientific segment offers temperature-controlled equipment for the medical, scientific, pharmaceutical, biotech, and industrial markets under the American BioTech Supply, Lab Research Products, Corepoint, Cryosafe, CryoGuard, and Scientific brands. The Engineering Technologies segment offers net and near net formed single-source customized solutions that are used in the manufacture of engineered components for the aviation, aerospace, defense, energy, industrial, medical, marine, oil and gas, and manned and unmanned space markets under the Spincraft brand. The Specialty Solutions segment manufactures and sells refrigerated, heated, and dry merchandizing display cases; and single and double acting telescopic, and piston rod hydraulic cylinders under the Federal and Custom Hoist brands. The company was founded in 1955 and is headquartered in Salem, New Hampshire.
#
# -------
#
# Worthington Enterprises, Inc. operates as an industrial manufacturing company. It operates through two segments, Consumer Products and Building Products. The Consumer Products segment provides products in the tools, outdoor living, and celebrations end markets. The segment's products include hand-held torches, micro torches, lighters, accessories, and fuel for constructing, fixing making, and creating; precision and specialty hand, digital, and safety tools; drywall tools and accessories used for finishing and taping, cutting, siding, and roofing; propane-filled cylinders for torches, camping stoves and other applications, helium-filled balloon kits, and gas grills and pizza ovens. This segment sells its products primarily to mass merchandisers, retailers, and distributors under the Balloon Time, Bernzomatic, Coleman, Garden-Weasel, General, Halo, Hawkeye, Level5, Mag-Torch, Pactool International, and Worthington Pro Grade brands. The Building Products segment provides pressurized cont
#
# -------
#
# Arrow Electronics, Inc. provides products, services, and solutions to industrial and commercial users of electronic components and enterprise computing solutions in the Americas, Europe, the Middle East, Africa, and the Asia Pacific. The company operates in two segments, Global Components and Global Enterprise Computing Solutions. The Global Components segment markets and distributes electronic components comprising semiconductor products and related services; interconnect, passive, and electromechanical products, including capacitors, resistors, potentiometers, power supplies, relays, switches, and connectors; and computing and memory products, as well as other products and services. The Global Enterprise Computing Solutions segment offers computing solutions, such as datacenter, cloud, security, and analytics solutions. This segment also provides access to various services, including engineering and integration support, warehousing and logistics, marketing resources, and authorized hardware and software training. The company serves original equipment manufacturers, value-added resellers, managed service providers, contract manufacturers, and other commercial customers. Arrow Electronics, Inc. was founded in 1935 and is based in Centennial, Colorado.
#
# -------
#
# Arrow Electronics, Inc. provides products, services, and solutions to industrial and commercial users of electronic components and enterprise computing solutions in the Americas, Europe, the Middle East, Africa, and the Asia Pacific. The company operates in two segments, Global Components and Global Enterprise Computing Solutions. The Global Components segment markets and distributes electronic components comprising semiconductor products and related services; interconnect, passive, and electromechanical products, including capacitors, resistors, potentiometers, power supplies, relays, switches, and connectors; and computing and memory products, as well as other products and services. The Global Enterprise Computing Solutions segment offers computing solutions, such as datacenter, cloud, security, and analytics solutions. This segment also provides access to various services, including engineering and integration support, warehousing and logistics, marketing resources, and authorized hardware and software training. The company serves original equipment manufacturers, value-added resellers, managed service providers, contract manufacturers, and other commercial customers. Arrow Electronics, Inc. was founded in 1935 and is based in Centennial, Colorado.
#
# -------
#
# HP Inc. provides personal computing and other digital access devices, imaging and printing products, and related technologies, solutions, and services worldwide. The company operates through three segments: Personal Systems, Printing, and Corporate Investments. The Personal Systems segment offers commercial and consumer desktops and notebooks, workstations, commercial mobility devices, thin clients, retail point-of-sale systems, displays, software, support, and services, as well as hybrid systems, such as video conferencing solutions, cameras, headsets, voice, and related software products. The Printing segment provides consumer and commercial printer hardware, supplies, solutions, and services, as well as focuses on graphics and 3D printing and personalization solutions in the commercial and industrial markets. The Corporate Investments segment is involved in the business incubation and investment projects. It serves individual consumers, small- and medium-sized businesses, and large
#
# -------
#
# Avnet, Inc., distributes electronic component technology. The company operates through two segments, Electronic Components and Farnell. The Electronic Components segment markets, sells, and distributes semiconductors; interconnect, passive, and electromechanical components; and other integrated components from electronic component manufacturers. It also offers design chain support that provides engineers with technical design solutions; engineering and technical resources to support product design, bill of materials development, and technical education and training; and supply chain solutions that provide support, warehousing, and logistical services to original equipment manufacturers, electronic manufacturing service providers, and electronic component manufacturers. In addition, this segment provides embedded solutions, such as technical design, integration, and assembly of embedded products, systems, and solutions, as well as embedded display solutions comprising touch and passive displays; and develops and manufactures standard board and industrial subsystems, and application-specific devices that enable it to produce systems tailored to specific customer requirements. This segment serves various markets, such as automotive, medical, defense, aerospace, telecommunications, industrial, and digital editing. The Farnell segment distributes kits, tools, and electronic and industrial automation components, as well as test and measurement products to engineers and entrepreneurs. It has operations in the Americas, Europe, the Middle East, Africa, and Asia. Avnet, Inc. was founded in 1921 and is headquartered in Phoenix, Arizona.
#
# -------
#
# Avnet, Inc., distributes electronic component technology. The company operates through two segments, Electronic Components and Farnell. The Electronic Components segment markets, sells, and distributes semiconductors; interconnect, passive, and electromechanical components; and other integrated components from electronic component manufacturers. It also offers design chain support that provides engineers with technical design solutions; engineering and technical resources to support product design, bill of materials development, and technical education and training; and supply chain solutions that provide support, warehousing, and logistical services to original equipment manufacturers, electronic manufacturing service providers, and electronic component manufacturers. In addition, this segment provides embedded solutions, such as technical design, integration, and assembly of embedded products, systems, and solutions, as well as embedded display solutions comprising touch and passive displays; and develops and manufactures standard board and industrial subsystems, and application-specific devices that enable it to produce systems tailored to specific customer requirements. This segment serves various markets, such as automotive, medical, defense, aerospace, telecommunications, industrial, and digital editing. The Farnell segment distributes kits, tools, and electronic and industrial automation components, as well as test and measurement products to engineers and entrepreneurs. It has operations in the Americas, Europe, the Middle East, Africa, and Asia. Avnet, Inc. was founded in 1921 and is headquartered in Phoenix, Arizona.
# -------
# </CONTEXT>
#
#
#
# MY QUESTION:
# What are some companies that manufacture consumer hardware?

# %% [markdown]
# # Setting up Groq for RAG
#
# 1. Get your Groq API Key [here](https://console.groq.com/keys). Through Groq, you get free access to various LLMs
#
# 2. Paste your Groq API Key into your Google Colab secrets, and make sure to enable permissions for it
#
# ![Screenshot 2024-11-25 at 12 00 16 AM](https://github.com/user-attachments/assets/e5525d29-bca6-4dbd-892b-cc770a6b281d)

# %%
import httpx
# Define a custom HTTP client to bypass the default proxy behavior
custom_client = httpx.Client(
    follow_redirects=True,
    timeout=60.0,  # Optional: Adjust timeout as needed
)


# Cerebras, making an API request
client = Cerebras(
    api_key=userdata.get('CEREBRAS_API_KEY'),  # This is the default and can be omitted
)

'''
# Cerebras, Configuring OpenAI to Use Cerebras API
client = openai.OpenAI(
    base_url="https://api.cerebras.ai/v1",
    api_key=userdata.get('CEREBRAS_API_KEY')
)
'''

'''
client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=userdata.get("GROQ_API_KEY"),
    http_client=custom_client,  # Use the custom httpx client
)
'''

'''
client = OpenAI(
  base_url="https://api.groq.com/openai/v1",
  api_key=userdata.get("GROQ_API_KEY")
)
'''
# Out:
# '\nclient = OpenAI(\n  base_url="https://api.groq.com/openai/v1",\n  api_key=userdata.get("GROQ_API_KEY")\n)\n'

# %%
system_prompt = f"""You are an expert at providing answers about stocks. Please answer my question provided.
"""

llm_response = client.chat.completions.create(
    model="llama-3.3-70b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": augmented_query}
    ]
)

response = llm_response.choices[0].message.content

# %%
print(response)
# Out:
# Based on the provided context, some companies that manufacture consumer hardware are:
#
# 1. Best Buy Co., Inc. - Although primarily a retailer, Best Buy also offers its own brand of consumer electronics, such as TVs, computers, and appliances.
# 2. HP Inc. - HP is a well-known manufacturer of personal computing devices, including desktops, notebooks, and mobile devices, as well as printing products and related technologies.
# 3. Worthington Enterprises, Inc. - Worthington's Consumer Products segment offers a range of consumer hardware products, including hand-held torches, precision tools, and outdoor living products.
#
# Additionally, some companies mentioned in the context that manufacture components or provide solutions for consumer hardware are:
#
# 1. Arrow Electronics, Inc. - Although primarily a distributor of electronic components, Arrow also provides computing solutions and engineering services that support the development of consumer hardware.
# 2. Avnet, Inc. - Avnet is a distributor of electronic components and also provides embedded solutions, design chain support, and supply chain solutions that can be used in the development of consumer hardware.
# 3. Kimball Electronics, Inc. - Kimball Electronics provides contract manufacturing services, including engineering and supply chain support, for the production of electronic assemblies and other products, which can include consumer hardware.
# 4. Standex International Corporation - Standex's Electronics segment offers custom electronics sensors, transformers, and inductors, which can be used in consumer hardware products.
#
# Note that some of these companies may not exclusively manufacture consumer hardware, but they do contribute to the development and production of consumer electronics and related technologies.

# %% [markdown]
# # Putting it all together

# %%
def perform_rag(query):
    '''
    custom_client = httpx.Client(
    follow_redirects=True,
    timeout=60.0,)

    client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=userdata.get("GROQ_API_KEY"),
    http_client=custom_client,  # Use the custom httpx client
    )

    # Cerebras, Configuring OpenAI to Use Cerebras API
    client = openai.OpenAI(
    base_url="https://api.cerebras.ai/v1",
    api_key=userdata.get('CEREBRAS_API_KEY')
    )
    '''
    # Cerebras, making an API request
    client = Cerebras(
        api_key=userdata.get('CEREBRAS_API_KEY'),
    )


    raw_query_embedding = get_huggingface_embeddings(query)

    top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace = "stock-descriptions")

    # Get the list of retrieved texts
    contexts = [item['metadata']['text'] for item in top_matches['matches']]

    augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

    # Modify the prompt below as need to improve the response quality
    system_prompt = f"""You are an expert at providing answers about stocks. Please answer my question provided.
    """

    llm_response = client.chat.completions.create(
      model="llama-3.3-70b",
      messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": augmented_query}
       ]
      )


    return llm_response.choices[0].message.content

# %%
response = perform_rag("What are some companies that manufacture consumer hardware?")

print(response)
# Out:
# Based on the context provided, some companies that manufacture consumer hardware include:
#
# 1. Best Buy Co., Inc. - They offer a wide range of consumer electronics, including computing and mobile phone products, consumer electronics, appliances, and entertainment products.
# 2. HP Inc. - They provide personal computing and other digital access devices, imaging and printing products, and related technologies, solutions, and services worldwide.
# 3. Worthington Enterprises, Inc. - They operate through two segments, Consumer Products and Building Products, and offer products such as hand-held torches, micro torches, lighters, accessories, and fuel for constructing, fixing, making, and creating.
#
# Additionally, companies like Arrow Electronics, Inc. and Avnet, Inc. distribute electronic components and provide solutions to industrial and commercial users, but they may not directly manufacture consumer hardware. However, they play a crucial role in the supply chain of consumer electronics.
#
# It's worth noting that Standex International Corporation also manufactures and sells various products, including refrigerated, heated, and dry merchandising display cases, which can be considered consumer hardware. However, their primary focus is on commercial and industrial markets.
#
# Kimball Electronics, Inc. is another company that provides electronics manufacturing, engineering, and supply chain support services, but they may not directly manufacture consumer hardware. They primarily serve the automotive, medical, and industrial end markets.

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.9.1-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.5.2 (from gradio)
#   Downloading gradio_client-1.5.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.26.5)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Collecting markupsafe~=2.0 (from gradio)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.3)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.8.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.42.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.2->gradio) (2024.10.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.2->gradio) (14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (4.66.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-5.9.1-py3-none-any.whl (57.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 13.8 MB/s eta 0:00:00
# Downloading gradio_client-1.5.2-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.4/320.4 kB 22.7 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.3 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.8.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 93.3 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.6 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.3 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, uvicorn, tomlkit, semantic-version, ruff, python-multipart, markupsafe, ffmpy, aiofiles, starlette, safehttpx, gradio-client, fastapi, gradio
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# Successfully installed aiofiles-23.2.1 fastapi-0.115.6 ffmpy-0.4.0 gradio-5.9.1 gradio-client-1.5.2 markupsafe-2.1.5 pydub-0.25.1 python-multipart-0.0.20 ruff-0.8.3 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.41.3 tomlkit-0.13.2 uvicorn-0.34.0

# %% [markdown]
# ## Part 2: Web app for RAG Financial Analysis & Automation with Gradio

# %%
#Ultra-Fast RAG Chatbot with Groq's LPU:
#https://github.com/mickymultani/Groq-RAG/blob/main/GROQ_RAG_Langchain.ipynb

import gradio as gr

# Setup the Gradio interface
iface = gr.Interface(fn=perform_rag,
                     inputs=gr.Textbox(lines=2, placeholder="Type your question here..."),
                     outputs=gr.Textbox(),
                     examples=["What are some companies that manufacture consumer hardware?",
                              "What are companies that build data centers?"],
                     title="RAG Financial Analysis & Automation",
                     description="Ask any question about Financial Analysis & Automation, and get an answer along with the response time.")

# Launch the interface
iface.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://8d0d848776c43de8b2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8d0d848776c43de8b2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Part 2: Web app for RAG Financial Analysis & Automation with Streamlit

# %%
# !pip install groq
# !pip install langchain-groq # Install the integration package for Groq and LangChain
# !pip install langchain_groq
# !pip install longchain --upgrade
# !pip install cerebras_cloud_sdk
# Out:
# Collecting groq
#   Downloading groq-0.13.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.10/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.1)
# Downloading groq-0.13.1-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.13.1
# Collecting langchain-groq
#   Downloading langchain_groq-0.2.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain-groq) (0.13.1)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain-groq) (0.3.25)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (0.2.3)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq) (9.0.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (3.10.12)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-groq) (2.2.3)
# Downloading langchain_groq-0.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: langchain-groq
# Successfully installed langchain-groq-0.2.1
# Requirement already satisfied: langchain_groq in /usr/local/lib/python3.10/dist-packages (0.2.1)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain_groq) (0.13.1)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain_groq) (0.3.25)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_groq) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_groq) (0.2.3)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_groq) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_groq) (9.0.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_groq) (3.10.12)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_groq) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_groq) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_groq) (2.2.3)
# Collecting longchain
#   Downloading longchain-0.4.2-py3-none-any.whl.metadata (5.5 kB)
# Downloading longchain-0.4.2-py3-none-any.whl (33 kB)
# Installing collected packages: longchain
# Successfully installed longchain-0.4.2
# Requirement already satisfied: cerebras_cloud_sdk in /usr/local/lib/python3.10/dist-packages (1.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from cerebras_cloud_sdk) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->cerebras_cloud_sdk) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->cerebras_cloud_sdk) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->cerebras_cloud_sdk) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->cerebras_cloud_sdk) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->cerebras_cloud_sdk) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->cerebras_cloud_sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->cerebras_cloud_sdk) (2.27.1)

# %%
from langchain_groq import ChatGroq

# %%
! pip install streamlit pyngrok python-dotenv
# Out:
# Collecting streamlit
#   Downloading streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting pyngrok
#   Downloading pyngrok-7.2.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (1.18.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 56.3 MB/s eta 0:00:00
# Downloading pyngrok-7.2.2-py3-none-any.whl (22 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 34.2 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: watchdog, pyngrok, pydeck, streamlit
# Successfully installed pydeck-0.9.1 pyngrok-7.2.2 streamlit-1.41.1 watchdog-6.0.0

# %%
import os # Import the os module
from google.colab import userdata

os.environ['GOOGLE_API_KEY'] = userdata.get("GOOGLE_API_KEY")
os.environ['CEREBRAS_API_KEY'] = userdata.get('CEREBRAS_API_KEY')
os.environ['PINECONE_API_KEY'] = userdata.get("PINECONE_API_KEY")

# %%
from threading import Thread
from pyngrok import ngrok
from google.colab import userdata

# %%
ngrok_token = userdata.get('NGROK_AUTH_TOKEN')

ngrok.set_auth_token(ngrok_token)

# %%
ngrok_token = userdata.get('NGROK_AUTH_TOKEN')

ngrok.set_auth_token(ngrok_token)

# %%
def run_streamlit():
    import os # Import the os module
    os.system("streamlit run /content/app.py --server.port 8501")

# %%
# %%writefile /content/app.py
from langchain_pinecone import PineconeVectorStore
from openai import OpenAI
import dotenv
import json
import yfinance as yf
import concurrent.futures
from langchain_community.embeddings import HuggingFaceEmbeddings
from google.colab import userdata
from langchain.schema import Document
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone
import numpy as np
import requests
import httpx

import streamlit as st
import os
from langchain.document_loaders import GitLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
#from langchain.vectorstores import Pinecone
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain import PromptTemplate
from cerebras.cloud.sdk import Cerebras
from dotenv import load_dotenv
#import pinecone
load_dotenv()

def get_stock_info(symbol: str) -> dict:
    """
    Retrieves and formats detailed information about a stock from Yahoo Finance.

    Args:
        symbol (str): The stock ticker symbol to look up.

    Returns:
        dict: A dictionary containing detailed stock information, including ticker, name,
              business summary, city, state, country, industry, and sector.
    """
    data = yf.Ticker(symbol)
    stock_info = data.info

    properties = {
        "Ticker": stock_info.get('symbol', 'Information not available'),
        'Name': stock_info.get('longName', 'Information not available'),
        'Business Summary': stock_info.get('longBusinessSummary'),
        'City': stock_info.get('city', 'Information not available'),
        'State': stock_info.get('state', 'Information not available'),
        'Country': stock_info.get('country', 'Information not available'),
        'Industry': stock_info.get('industry', 'Information not available'),
        'Sector': stock_info.get('sector', 'Information not available')
    }

    return properties

data = yf.Ticker("NVDA")
stock_info = data.info

aapl_info = get_stock_info('AAPL')
aapl_description = aapl_info['Business Summary']


def get_huggingface_embeddings(text, model_name="sentence-transformers/all-mpnet-base-v2"):
    """
    Generates embeddings for the given text using a specified Hugging Face model.

    Args:
        text (str): The input text to generate embeddings for.
        model_name (str): The name of the Hugging Face model to use.
                          Defaults to "sentence-transformers/all-mpnet-base-v2".

    Returns:
        np.ndarray: The generated embeddings as a NumPy array.
    """
    model = SentenceTransformer(model_name)
    return model.encode(text)



def get_company_tickers():
    """
    Downloads and parses the Stock ticker symbols from the GitHub-hosted SEC company tickers JSON file.

    Returns:
        dict: A dictionary containing company tickers and related information.

    Notes:
        The data is sourced from the official SEC website via a GitHub repository:
        https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json
    """
    # URL to fetch the raw JSON file from GitHub
    url = "https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json"

    # Making a GET request to the URL
    response = requests.get(url)

    # Checking if the request was successful
    if response.status_code == 200:
        # Parse the JSON content directly
        company_tickers = json.loads(response.content.decode('utf-8'))

        # Optionally save the content to a local file for future use
        with open("company_tickers.json", "w", encoding="utf-8") as file:
            json.dump(company_tickers, file, indent=4)

        print("File downloaded successfully and saved as 'company_tickers.json'")
        return company_tickers
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
        return None



def process_stock(stock_ticker: str) -> str:
    # Skip if already processed
    if stock_ticker in successful_tickers:
        return f"Already processed {stock_ticker}"

    try:
        # Get and store stock data
        stock_data = get_stock_info(stock_ticker)
        stock_description = stock_data['Business Summary']

        # Store stock description in Pinecone
        vectorstore_from_texts = PineconeVectorStore.from_documents(
            documents=[Document(page_content=stock_description, metadata=stock_data)],
            embedding=hf_embeddings,
            index_name=index_name,
            namespace=namespace
        )

        # Track success
        with open('successful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        successful_tickers.append(stock_ticker)

        return f"Processed {stock_ticker} successfully"

    except Exception as e:
        # Track failure
        with open('unsuccessful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        unsuccessful_tickers.append(stock_ticker)

        return f"ERROR processing {stock_ticker}: {e}"

def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_ticker = {
            executor.submit(process_stock, ticker): ticker
            for ticker in tickers
        }

        for future in concurrent.futures.as_completed(future_to_ticker):
            ticker = future_to_ticker[future]
            try:
                result = future.result()
                print(result)

                # Stop on error
                if result.startswith("ERROR"):
                    print(f"Stopping program due to error in {ticker}")
                    executor.shutdown(wait=False)
                    raise SystemExit(1)

            except Exception as exc:
                print(f'{ticker} generated an exception: {exc}')
                print("Stopping program due to exception")
                executor.shutdown(wait=False)
                raise SystemExit(1)



def perform_rag(query):

    '''
    custom_client = httpx.Client(
    follow_redirects=True,
    timeout=60.0,)

    client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=userdata.get("GROQ_API_KEY"),
    http_client=custom_client,  # Use the custom httpx client
    )

    # Cerebras, Configuring OpenAI to Use Cerebras API
    client = openai.OpenAI(
    base_url="https://api.cerebras.ai/v1",
    api_key=userdata.get('CEREBRAS_API_KEY')
    )
    '''
    # Cerebras, making an API request
    client = Cerebras(
        api_key=os.getenv('CEREBRAS_API_KEY'),
    )


    raw_query_embedding = get_huggingface_embeddings(query)

    top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace = "stock-descriptions")

    # Get the list of retrieved texts
    contexts = [item['metadata']['text'] for item in top_matches['matches']]

    augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

    # Modify the prompt below as need to improve the response quality
    system_prompt = """
    You are an expert in financial analysis and stock market trends.
    Using the context provided, answer the user's question as clearly and concisely as possible.
    When you give a response, this is the format I want you to follow:
    CompanyName(ticker):
    - Market Capitalization (Market Cap):
    - Beta:
    - Price to Earnings Ratio (Trailing Twelve Months):
    - Description:
    - Sector:
    - Industry:
    - Volume:
    """

    llm_response = client.chat.completions.create(
        model="llama-3.3-70b",
        messages=[
          {"role": "system", "content": system_prompt},
          {"role": "user", "content": augmented_query}
       ]
      )


    return llm_response.choices[0].message.content




# Streamlit UI
st.title("📊 RAG Financial Analysis & Automation or Research Automation")
st.text("Ask about Financial Analysis & Automation or Research Automation. Examples questions: What are some companies that manufacture consumer hardware?, What are companies that build data centers? and Find companies that make medical equipament.")

aapl_info = get_stock_info('AAPL')

company_tickers = get_company_tickers()
company_tickers = dict(list(company_tickers.items())[:100])


pinecone_api_key = os.getenv("PINECONE_API_KEY")
os.environ['PINECONE_API_KEY'] = pinecone_api_key

index_name = "stocks"
namespace = "stock-descriptions"

hf_embeddings = HuggingFaceEmbeddings()
vectorstore = PineconeVectorStore(index_name=index_name, embedding=hf_embeddings)


# Initialize tracking lists
successful_tickers = []
unsuccessful_tickers = []

# Load existing successful/unsuccessful tickers
try:
    with open('successful_tickers.txt', 'r') as f:
        successful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(successful_tickers)} successful tickers")
except FileNotFoundError:
    print("No existing successful tickers file found")

try:
    with open('unsuccessful_tickers.txt', 'r') as f:
        unsuccessful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(unsuccessful_tickers)} unsuccessful tickers")
except FileNotFoundError:
    print("No existing unsuccessful tickers file found")


# Prepare your tickers
tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# Process them
parallel_process_stocks(tickers_to_process, max_workers=10)

#vectorstore_from_texts=Pinecone.from_existing_index(index_name=index_name, namespace=namespace)

# Initialize Pinecone
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"),)

# Connect to your Pinecone index
pinecone_index = pc.Index(index_name)



# Initialize chat history
if "messages" not in st.session_state:
   st.session_state.messages = []

# Display chat messages
for message in st.session_state.messages:
    with st.chat_message(message["role"]):
        st.markdown(message["content"])

# Chat input
if prompt := st.chat_input("Ask about Financial Analysis & Automation or Research Automation"):
    st.session_state.messages.append({"role": "user", "content": prompt})
    with st.chat_message("user"):
        st.markdown(prompt)

    with st.chat_message("assistant"):
        response=perform_rag(prompt)
        st.markdown(response)
        st.session_state.messages.append({"role": "assistant", "content": response})
# Out:
# Writing /content/app.py

# %%
thread = Thread(target=run_streamlit)
thread.start()

# %%
# Disconnect all existing tunnels
for tunnel in ngrok.get_tunnels():
    ngrok.disconnect(tunnel.public_url)

# Now connect your new tunnel
public_url = ngrok.connect(addr='8501', proto='http')

print("Public URL:", public_url)
# Out:
# Public URL: NgrokTunnel: "https://69b0-34-85-148-230.ngrok-free.app" -> "http://localhost:8501"

# %%
'''
tunnels = ngrok.get_tunnels()
for tunnel in tunnels:
    print(f"Closing tunnel: {tunnel.public_url} -> {tunnel.config['addr']}")
    ngrok.disconnect(tunnel.public_url)
'''
# Out:
# '\ntunnels = ngrok.get_tunnels()\nfor tunnel in tunnels:\n    print(f"Closing tunnel: {tunnel.public_url} -> {tunnel.config[\'addr\']}")\n    ngrok.disconnect(tunnel.public_url)\n'

# %%
'''
def perform_rag(query):

    custom_client = httpx.Client(
    follow_redirects=True,
    timeout=60.0,)

    client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.getenv("GROQ_API_KEY"),
    http_client=custom_client,  # Use the custom httpx client
    )

    raw_query_embedding = get_huggingface_embeddings(query)

    top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace = "stock-descriptions")

    # Get the list of retrieved texts
    contexts = [item['metadata']['text'] for item in top_matches['matches']]

    augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

    # Modify the prompt below as need to improve the response quality
    system_prompt = """
        You are an expert in financial analysis and stock market trends.
        Using the context provided, answer the user's question as clearly and concisely as possible.
        When you give a response, this is the format I want you to follow:
        CompanyName(ticker):
        - Market Cap:
        - Description:
        """

    # Modify the prompt below as need to improve the response quality
    system_prompt = """
    You are an expert in financial analysis and stock market trends.
    Using the context provided, answer the user's question as clearly and concisely as possible.
    When you give a response, this is the format I want you to follow:
    CompanyName(ticker):
    - Market Capitalization (Market Cap):
    - Beta:
    - Price to Earnings Ratio (Trailing Twelve Months):
    - Description:
    - Sector:
    - Industry:
    - Volume:
    """

    # Don't works very well
    system_prompt = """
    You are an expert financial analyst with deep knowledge of stock market trends.
    Your task is to provide insightful answers to user questions based on the financial data provided in the context.

    Prioritize clarity, accuracy, and conciseness in your responses.

    Always present your answers in the following structured format:

    **Company Name (Ticker):** [Company Name] ([Ticker Symbol])
    * **Market Capitalization (Market Cap):** $[Value]
    * **Beta:** [Value]
    * **Price-to-Earnings Ratio (Trailing Twelve Months):** [Value]
    * **Description:** [Brief company description, highlighting its core business and operations]
    * **Sector:** [Sector Name]
    * **Industry:** [Industry Name]
    * **Volume:** [Average daily trading volume]


   Ensure your response is directly supported by the information given in the context.
   If the context lacks sufficient information to answer a specific aspect of the user's question, clearly state "Information not available" for that field.

   Example:

   **Apple Inc. (AAPL):**
   * **Market Capitalization (Market Cap):** $2.75 trillion
   * **Beta:** 1.20
   * **Price-to-Earnings Ratio (Trailing Twelve Months):** 28.50
   * **Description:** A global technology company that designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories. Apple is known for its innovative products and strong brand loyalty.
   * **Sector:** Technology
   * **Industry:** Consumer Electronics
   * **Volume:** 50,000,000 shares
   """

    llm_response = client.chat.completions.create(
        model="llama-3.1-70b-versatile",
        messages=[
          {"role": "system", "content": system_prompt},
          {"role": "user", "content": augmented_query}
       ]
      )


    return llm_response.choices[0].message.content
'''
# Out:
# '\ndef perform_rag(query):\n\n    custom_client = httpx.Client(\n    follow_redirects=True,\n    timeout=60.0,)\n\n    client = OpenAI(\n    base_url="https://api.groq.com/openai/v1",\n    api_key=os.getenv("GROQ_API_KEY"),\n    http_client=custom_client,  # Use the custom httpx client\n    )\n\n    raw_query_embedding = get_huggingface_embeddings(query)\n\n    top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace = "stock-descriptions")\n\n    # Get the list of retrieved texts\n    contexts = [item[\'metadata\'][\'text\'] for item in top_matches[\'matches\']]\n\n    augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query\n\n    # Modify the prompt below as need to improve the response quality\n    system_prompt = """\n        You are an expert in financial analysis and stock market trends.\n        Using the context provided, answer the user\'s question as clearly and concisely as possible.\n        When you give a response, this is the format I want you to follow:\n        CompanyName(ticker):\n        - Market Cap:\n        - Description:\n        """\n\n    # Modify the prompt below as need to improve the response quality\n    system_prompt = """\n    You are an expert in financial analysis and stock market trends.\n    Using the context provided, answer the user\'s question as clearly and concisely as possible.\n    When you give a response, this is the format I want you to follow:\n    CompanyName(ticker):\n    - Market Capitalization (Market Cap):\n    - Beta:\n    - Price to Earnings Ratio (Trailing Twelve Months):\n    - Description:\n    - Sector:\n    - Industry:\n    - Volume:\n    """\n\n    # Don\'t works very well\n    system_prompt = """\n    You are an expert financial analyst with deep knowledge of stock market trends.\n    Your task is to provide insightful answers to user questions based on the financial data provided in the context.\n\n    Prioritize clarity, accuracy, and conciseness in your responses.\n\n    Always present your answers in the following structured format:\n\n    **Company Name (Ticker):** [Company Name] ([Ticker Symbol])\n    * **Market Capitalization (Market Cap):** $[Value]\n    * **Beta:** [Value]\n    * **Price-to-Earnings Ratio (Trailing Twelve Months):** [Value]\n    * **Description:** [Brief company description, highlighting its core business and operations]\n    * **Sector:** [Sector Name]\n    * **Industry:** [Industry Name]\n    * **Volume:** [Average daily trading volume]\n\n\n   Ensure your response is directly supported by the information given in the context.\n   If the context lacks sufficient information to answer a specific aspect of the user\'s question, clearly state "Information not available" for that field.\n\n   Example:\n\n   **Apple Inc. (AAPL):**\n   * **Market Capitalization (Market Cap):** $2.75 trillion\n   * **Beta:** 1.20\n   * **Price-to-Earnings Ratio (Trailing Twelve Months):** 28.50\n   * **Description:** A global technology company that designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories. Apple is known for its innovative products and strong brand loyalty.\n   * **Sector:** Technology\n   * **Industry:** Consumer Electronics\n   * **Volume:** 50,000,000 shares\n   """\n\n    llm_response = client.chat.completions.create(\n        model="llama-3.1-70b-versatile",\n        messages=[\n          {"role": "system", "content": system_prompt},\n          {"role": "user", "content": augmented_query}\n       ]\n      )\n\n\n    return llm_response.choices[0].message.content\n'

# %%
"""
# %%writefile /content/app.py
from langchain_pinecone import PineconeVectorStore
from openai import OpenAI
import dotenv
import json
import yfinance as yf
import concurrent.futures
from langchain_community.embeddings import HuggingFaceEmbeddings
from google.colab import userdata
from langchain.schema import Document
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone
import numpy as np
import requests
import httpx

import streamlit as st
import os
from langchain.document_loaders import GitLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
#from langchain.vectorstores import Pinecone
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain import PromptTemplate
from dotenv import load_dotenv
#import pinecone
load_dotenv()

def get_stock_info(symbol: str) -> dict:
    """ """
    Retrieves and formats detailed information about a stock from Yahoo Finance.

    Args:
        symbol (str): The stock ticker symbol to look up.

    Returns:
        dict: A dictionary containing detailed stock information, including ticker, name,
              business summary, city, state, country, industry, and sector.
    """ """
    data = yf.Ticker(symbol)
    stock_info = data.info

    properties = {
        "Ticker": stock_info.get('symbol', 'Information not available'),
        'Name': stock_info.get('longName', 'Information not available'),
        'Business Summary': stock_info.get('longBusinessSummary'),
        'City': stock_info.get('city', 'Information not available'),
        'State': stock_info.get('state', 'Information not available'),
        'Country': stock_info.get('country', 'Information not available'),
        'Industry': stock_info.get('industry', 'Information not available'),
        'Sector': stock_info.get('sector', 'Information not available')
    }

    return properties

data = yf.Ticker("NVDA")
stock_info = data.info

aapl_info = get_stock_info('AAPL')
aapl_description = aapl_info['Business Summary']


def get_huggingface_embeddings(text, model_name="sentence-transformers/all-mpnet-base-v2"):
    """ """
    Generates embeddings for the given text using a specified Hugging Face model.

    Args:
        text (str): The input text to generate embeddings for.
        model_name (str): The name of the Hugging Face model to use.
                          Defaults to "sentence-transformers/all-mpnet-base-v2".

    Returns:
        np.ndarray: The generated embeddings as a NumPy array.
    """ """
    model = SentenceTransformer(model_name)
    return model.encode(text)



def get_company_tickers():
    """ """
    Downloads and parses the Stock ticker symbols from the GitHub-hosted SEC company tickers JSON file.

    Returns:
        dict: A dictionary containing company tickers and related information.

    Notes:
        The data is sourced from the official SEC website via a GitHub repository:
        https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json
    """ """
    # URL to fetch the raw JSON file from GitHub
    url = "https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json"

    # Making a GET request to the URL
    response = requests.get(url)

    # Checking if the request was successful
    if response.status_code == 200:
        # Parse the JSON content directly
        company_tickers = json.loads(response.content.decode('utf-8'))

        # Optionally save the content to a local file for future use
        with open("company_tickers.json", "w", encoding="utf-8") as file:
            json.dump(company_tickers, file, indent=4)

        print("File downloaded successfully and saved as 'company_tickers.json'")
        return company_tickers
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
        return None
'''
company_tickers = get_company_tickers()

company_tickers = dict(list(company_tickers.items())[:100])
'''


'''
# Initialize tracking lists
successful_tickers = []
unsuccessful_tickers = []


# Load existing successful/unsuccessful tickers
try:
    with open('successful_tickers.txt', 'r') as f:
        successful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(successful_tickers)} successful tickers")
except FileNotFoundError:
    print("No existing successful tickers file found")

try:
    with open('unsuccessful_tickers.txt', 'r') as f:
        unsuccessful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(unsuccessful_tickers)} unsuccessful tickers")
except FileNotFoundError:
    print("No existing unsuccessful tickers file found")
'''

def process_stock(stock_ticker: str) -> str:
    # Skip if already processed
    if stock_ticker in successful_tickers:
        return f"Already processed {stock_ticker}"

    try:
        # Get and store stock data
        stock_data = get_stock_info(stock_ticker)
        stock_description = stock_data['Business Summary']

        # Store stock description in Pinecone
        vectorstore_from_texts = PineconeVectorStore.from_documents(
            documents=[Document(page_content=stock_description, metadata=stock_data)],
            embedding=hf_embeddings,
            index_name=index_name,
            namespace=namespace
        )

        # Track success
        with open('successful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        successful_tickers.append(stock_ticker)

        return f"Processed {stock_ticker} successfully"

    except Exception as e:
        # Track failure
        with open('unsuccessful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        unsuccessful_tickers.append(stock_ticker)

        return f"ERROR processing {stock_ticker}: {e}"

def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_ticker = {
            executor.submit(process_stock, ticker): ticker
            for ticker in tickers
        }

        for future in concurrent.futures.as_completed(future_to_ticker):
            ticker = future_to_ticker[future]
            try:
                result = future.result()
                print(result)

                # Stop on error
                if result.startswith("ERROR"):
                    print(f"Stopping program due to error in {ticker}")
                    executor.shutdown(wait=False)
                    raise SystemExit(1)

            except Exception as exc:
                print(f'{ticker} generated an exception: {exc}')
                print("Stopping program due to exception")
                executor.shutdown(wait=False)
                raise SystemExit(1)
'''
# Prepare your tickers
tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# Process them
parallel_process_stocks(tickers_to_process, max_workers=10)
# parallel_process_stocks(tickers_to_process, max_workers=10)
'''


def perform_rag(query):

    custom_client = httpx.Client(
    follow_redirects=True,
    timeout=60.0,)

    client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.getenv("GROQ_API_KEY"),
    http_client=custom_client,  # Use the custom httpx client
    )

    raw_query_embedding = get_huggingface_embeddings(query)

    top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace = "stock-descriptions")

    # Get the list of retrieved texts
    contexts = [item['metadata']['text'] for item in top_matches['matches']]

    augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

    # Modify the prompt below as need to improve the response quality
    system_prompt = f""" """You are an expert at providing answers about stocks. Please answer my question provided.
    """ """

    llm_response = client.chat.completions.create(
        model="llama-3.1-70b-versatile",
        messages=[
          {"role": "system", "content": system_prompt},
          {"role": "user", "content": augmented_query}
       ]
      )


    return llm_response.choices[0].message.content




# Streamlit UI
st.title("RAG Financial Analysis & Automation or Research Automation")
st.text("Ask about Financial Analysis & Automation or Research Automation. Examples questions: What are some companies that manufacture consumer hardware?, What are companies that build data centers?")

aapl_info = get_stock_info('AAPL')

company_tickers = get_company_tickers()
company_tickers = dict(list(company_tickers.items())[:100])


pinecone_api_key = os.getenv("PINECONE_API_KEY")
os.environ['PINECONE_API_KEY'] = pinecone_api_key

index_name = "stocks"
namespace = "stock-descriptions"

hf_embeddings = HuggingFaceEmbeddings()
vectorstore = PineconeVectorStore(index_name=index_name, embedding=hf_embeddings)


# Initialize tracking lists
successful_tickers = []
unsuccessful_tickers = []

# Load existing successful/unsuccessful tickers
try:
    with open('successful_tickers.txt', 'r') as f:
        successful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(successful_tickers)} successful tickers")
except FileNotFoundError:
    print("No existing successful tickers file found")

try:
    with open('unsuccessful_tickers.txt', 'r') as f:
        unsuccessful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(unsuccessful_tickers)} unsuccessful tickers")
except FileNotFoundError:
    print("No existing unsuccessful tickers file found")


# Prepare your tickers
tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# Process them
parallel_process_stocks(tickers_to_process, max_workers=10)

#vectorstore_from_texts=Pinecone.from_existing_index(index_name=index_name, namespace=namespace)

# Initialize Pinecone
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"),)

# Connect to your Pinecone index
pinecone_index = pc.Index(index_name)


# Initialize Groq chat model
llm = ChatGroq(
      api_key=os.getenv("GROQ_API_KEY"),
      model="llama-3.1-70b-versatile",
      temperature=0)

# Define prompt template
system_prompt = """ """You are an expert at providing answers about stocks. Please answer my question provided.

        Context: {context}
        Question: {question}
        Answer:

        """ """
chat_prompt = PromptTemplate(template=system_prompt, input_variables=["context", "question"])



# Set up QA chain
qa_chain = ConversationalRetrievalChain.from_llm(
        llm, retriever=vectorstore_from_texts.as_retriever(), return_source_documents=True
        ,combine_docs_chain_kwargs={"prompt": chat_prompt}
    )




# Initialize chat history
if "messages" not in st.session_state:
   st.session_state.messages = []

# Display chat messages
for message in st.session_state.messages:
    with st.chat_message(message["role"]):
        st.markdown(message["content"])

# Chat input
if prompt := st.chat_input("Ask about Financial Analysis & Automation or Research Automation"):
    st.session_state.messages.append({"role": "user", "content": prompt})
    with st.chat_message("user"):
        st.markdown(prompt)

    with st.chat_message("assistant"):
        response=perform_rag(prompt)
        response = qa_chain({"question": prompt, "chat_history": [(m["role"], m["content"]) for m in st.session_state.messages]})
        st.markdown(response["answer"])
        st.session_state.messages.append({"role": "assistant", "content": response["answer"]})
        #st.markdown(response)
        #st.session_state.messages.append({"role": "assistant", "content": response})


        # Optionally display source documents
        with st.expander("Source Documents"):
            for doc in response["source_documents"]:
                  st.write(doc.page_content)


"""
# Out:
# '\n%%writefile /content/app.py\nfrom langchain_pinecone import PineconeVectorStore\nfrom openai import OpenAI\nimport dotenv\nimport json\nimport yfinance as yf\nimport concurrent.futures\nfrom langchain_community.embeddings import HuggingFaceEmbeddings\nfrom google.colab import userdata\nfrom langchain.schema import Document\nfrom sklearn.metrics.pairwise import cosine_similarity\nfrom sentence_transformers import SentenceTransformer\nfrom pinecone import Pinecone\nimport numpy as np\nimport requests\nimport httpx\n\nimport streamlit as st\nimport os\nfrom langchain.document_loaders import GitLoader\nfrom langchain.text_splitter import CharacterTextSplitter\nfrom langchain.embeddings import OpenAIEmbeddings\n#from langchain.vectorstores import Pinecone\nfrom langchain.chat_models import ChatOpenAI\nfrom langchain.chains import ConversationalRetrievalChain\nfrom langchain_groq import ChatGroq\nfrom langchain_core.prompts import ChatPromptTemplate\nfrom langchain import PromptTemplate\nfrom dotenv import load_dotenv\n#import pinecone\nload_dotenv()\n\ndef get_stock_info(symbol: str) -> dict:\n    \n    Retrieves and formats detailed information about a stock from Yahoo Finance.\n\n    Args:\n        symbol (str): The stock ticker symbol to look up.\n\n    Returns:\n        dict: A dictionary containing detailed stock information, including ticker, name,\n              business summary, city, state, country, industry, and sector.\n    \n    data = yf.Ticker(symbol)\n    stock_info = data.info\n\n    properties = {\n        "Ticker": stock_info.get(\'symbol\', \'Information not available\'),\n        \'Name\': stock_info.get(\'longName\', \'Information not available\'),\n        \'Business Summary\': stock_info.get(\'longBusinessSummary\'),\n        \'City\': stock_info.get(\'city\', \'Information not available\'),\n        \'State\': stock_info.get(\'state\', \'Information not available\'),\n        \'Country\': stock_info.get(\'country\', \'Information not available\'),\n        \'Industry\': stock_info.get(\'industry\', \'Information not available\'),\n        \'Sector\': stock_info.get(\'sector\', \'Information not available\')\n    }\n\n    return properties\n\ndata = yf.Ticker("NVDA")\nstock_info = data.info\n\naapl_info = get_stock_info(\'AAPL\')\naapl_description = aapl_info[\'Business Summary\']\n\n\ndef get_huggingface_embeddings(text, model_name="sentence-transformers/all-mpnet-base-v2"):\n    \n    Generates embeddings for the given text using a specified Hugging Face model.\n\n    Args:\n        text (str): The input text to generate embeddings for.\n        model_name (str): The name of the Hugging Face model to use.\n                          Defaults to "sentence-transformers/all-mpnet-base-v2".\n\n    Returns:\n        np.ndarray: The generated embeddings as a NumPy array.\n    \n    model = SentenceTransformer(model_name)\n    return model.encode(text)\n\n\n\ndef get_company_tickers():\n    \n    Downloads and parses the Stock ticker symbols from the GitHub-hosted SEC company tickers JSON file.\n\n    Returns:\n        dict: A dictionary containing company tickers and related information.\n\n    Notes:\n        The data is sourced from the official SEC website via a GitHub repository:\n        https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json\n    \n    # URL to fetch the raw JSON file from GitHub\n    url = "https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json"\n\n    # Making a GET request to the URL\n    response = requests.get(url)\n\n    # Checking if the request was successful\n    if response.status_code == 200:\n        # Parse the JSON content directly\n        company_tickers = json.loads(response.content.decode(\'utf-8\'))\n\n        # Optionally save the content to a local file for future use\n        with open("company_tickers.json", "w", encoding="utf-8") as file:\n ...
